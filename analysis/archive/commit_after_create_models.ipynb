# %%
library(lmerTest)
library(MuMIn)
library(VIF)
library(sqldf)
library(car)
library(ggplot2)
library(sjPlot)
library(sjmisc)
library(sjlabelled)
library(ggeffects)


filename <- 'generated/num_of_review_comments.csv'

data <- read.csv(file=filename, header=TRUE, sep=",")

data$LanguageType = as.factor(data$LanguageType)

data$EffectiveComments = log(data$EffectiveComments + 1)
data$Additions = log(data$Additions + 1)
data$Deletions = log(data$Deletions + 1)
data$TotalReviewComments = log(data$TotalReviewComments + 1)
data$TotalReviewCommentThreads = log(data$TotalReviewCommentThreads + 1)
data$GeneralComments = log(data$GeneralComments + 1)
data$Commits = log(data$Commits + 1)
data$Assignees = log(data$Assignees + 1)
data$ChangedFiles = log(data$ChangedFiles + 1)
data$PrOpenedDaysAfterProjectStart = log(data$PrOpenedDaysAfterProjectStart + 1)
data$NumOfUniqueUsers = log(data$NumOfUniqueUsers + 1)
data$PRsOpened = log(data$PRsOpened + 1)
data$TotalBuilds = log(data$TotalBuilds + 1)
data$AdditionsAfterCreate = log(data$AdditionsAfterCreate + 1)
data$CommitsAfterCreate = log(data$CommitsAfterCreate + 1)
data$DeletionsAfterCreate = log(data$DeletionsAfterCreate + 1)

summary(data)
# Out:
#  EffectiveComments TotalReviewComments TotalReviewCommentThreads
#  Min.   :0.00000   Min.   :0.0000      Min.   :0.0000
#  1st Qu.:0.00000   1st Qu.:0.0000      1st Qu.:0.0000
#  Median :0.00000   Median :0.0000      Median :0.0000
#  Mean   :0.07763   Mean   :0.3053      Mean   :0.2835
#  3rd Qu.:0.00000   3rd Qu.:0.0000      3rd Qu.:0.0000
#  Max.   :5.56068   Max.   :6.0039      Max.   :6.0039
#
#  ShareReviewComments GeneralComments  GeneralCommentsDiscussingBuild
#  Min.   :  0.00      Min.   :0.0000   Min.   :0
#  1st Qu.:  0.00      1st Qu.:0.0000   1st Qu.:0
#  Median :  0.00      Median :0.6931   Median :0
#  Mean   : 10.66      Mean   :0.8845   Mean   :0
#  3rd Qu.:  0.00      3rd Qu.:1.3863   3rd Qu.:0
#  Max.   :100.00      Max.   :6.9431   Max.   :0
#
#    Linter        Coverage        Additions         Deletions
#  False:138163   False:170481   Min.   : 0.0000   Min.   : 0.000
#  True :119958   True : 87640   1st Qu.: 0.6931   1st Qu.: 0.000
#                                Median : 2.1972   Median : 1.099
#                                Mean   : 2.5345   Mean   : 1.762
#                                3rd Qu.: 4.0254   3rd Qu.: 2.773
#                                Max.   :15.4460   Max.   :15.446
#
#   IsMerged         Commits         Assignees        ChangedFiles
#  False: 60470   Min.   :0.0000   Min.   :0.00000   Min.   : 0.0000
#  True :197651   1st Qu.:0.6931   1st Qu.:0.00000   1st Qu.: 0.6931
#                 Median :0.6931   Median :0.00000   Median : 0.6931
#                 Mean   :1.0998   Mean   :0.04763   Mean   : 1.1311
#                 3rd Qu.:1.3863   3rd Qu.:0.00000   3rd Qu.: 1.6094
#                 Max.   :5.5255   Max.   :1.79176   Max.   :10.1565
#
#  PrOpenedDaysAfterProjectStart   ProjectLanguage   IsAfter
#  Min.   :0.000                 C++       :42648   False:129065
#  1st Qu.:6.240                 Python    :34528   True :129056
#  Median :6.953                 JavaScript:29623
#  Mean   :6.745                 PHP       :27022
#  3rd Qu.:7.476                 Java      :25332
#  Max.   :8.255                 Ruby      :20656
#                                (Other)   :78312
#                        ProjectName     NumOfUniqueUsers NewContributor
#  caskdata/cdap               :  9624   Min.   :0.0000   False:217562
#  appcelerator/titanium_mobile:  7586   1st Qu.:0.0000   True : 40559
#  bitcoin/bitcoin             :  6074   Median :0.6931
#  symfony/symfony-docs        :  5766   Mean   :0.7596
#  DynamoDS/Dynamo             :  5554   3rd Qu.:1.0986
#  Baystation12/Baystation12   :  5422   Max.   :4.8442
#  (Other)                     :218095
#    PRsOpened      TotalBuilds     CommitsAfterCreate AdditionsAfterCreate
#  Min.   :0.000   Min.   :0.0000   Min.   :0.0000     Min.   : 0.0000
#  1st Qu.:1.099   1st Qu.:0.0000   1st Qu.:0.0000     1st Qu.: 0.0000
#  Median :3.135   Median :0.0000   Median :0.0000     Median : 0.0000
#  Mean   :3.022   Mean   :0.4104   Mean   :0.2937     Mean   : 0.8986
#  3rd Qu.:4.710   3rd Qu.:0.6931   3rd Qu.:0.0000     3rd Qu.: 0.0000
#  Max.   :8.249   Max.   :5.5255   Max.   :5.5255     Max.   :15.5569
#
#  DeletionsAfterCreate  LanguageType    FromOutsider
#  Min.   : 0.0000      dynamic:111829   False:101506
#  1st Qu.: 0.0000      static : 96468   True :156615
#  Median : 0.0000      unk    : 49824
#  Mean   : 0.7671
#  3rd Qu.: 0.0000
#  Max.   :15.4633

# %% [markdown]
# # Introduction
#
# First we model if the number of commits after opening the pull request is influenced in any way by the presence of Travis

# %%
hist(data$CommitsAfterCreate)
# Out:
# Plot with title “Histogram of data$CommitsAfterCreate”

# %%
boxplot(list(before = data[data$IsAfter == 'False' & data$CommitsAfterCreate > 0,]$CommitsAfterCreate + 1, after = data[data$IsAfter == 'True'& data$CommitsAfterCreate > 0,]$CommitsAfterCreate + 1 ), log='y')

wilcox.test(data[data$IsAfter == 'False',]$CommitsAfterCreate + 1, data[data$IsAfter == 'True',]$CommitsAfterCreate + 1 )
# Out:
# 	Wilcoxon rank sum test with continuity correction
#
# data:  data[data$IsAfter == "False", ]$CommitsAfterCreate + 1 and data[data$IsAfter == "True", ]$CommitsAfterCreate + 1
# W = 7991600000, p-value < 2.2e-16
# alternative hypothesis: true location shift is not equal to 0
# plot without title

# %% [markdown]
# From this plot it can be easily be observed that we require a hurdle model to correctly model the effect that Travis has on `CommitsAfterCreate`

# %%
hasCommitsAfterCreate <- sqldf('select * from data where CommitsAfterCreate > 0 and LanguageType != "unk"')

zerosdf <- sqldf('select * from "data" where CommitsAfterCreate = 0 and LanguageType != "unk"')

sampledZerosdf <- zerosdf[sample(nrow(zerosdf), nrow(hasCommitsAfterCreate)),]

combined <- rbind(sampledZerosdf, hasCommitsAfterCreate)

executeLmOnData <- function(formula, data) {
    model = lm(formula ,
          data= data)
    print(summary(model))
    #r.squaredGLMM(model)
    print(vif(model))
    print(anova(model))
    
    return(model)
}

# %% [markdown]
# # Base model
# This model first does a hurdle model to look at predicting whether a pull request has any commits after create. Then it does a linear regression to predict the number of commits after create.

# %%
baseHurdleModel = glm((CommitsAfterCreate > 0) ~ 
            Additions + 
            Deletions +
            IsMerged +
            Commits + 
            Linter +
            Coverage +
            Assignees + 
            ChangedFiles + 
            #NumOfUniqueUsers +
            PRsOpened + 
            TotalBuilds + 
            NewContributor + 
            PrOpenedDaysAfterProjectStart +
            FromOutsider + 
            #TotalReviewComments + 
            TotalReviewCommentThreads +
            GeneralComments + 
            LanguageType +
            IsAfter ,
          data= combined,
                 family = 'binomial')
summary(baseHurdleModel)
r.squaredGLMM(baseHurdleModel)
vif(baseHurdleModel)
anova(baseHurdleModel)
# Out:
# Call:
# glm(formula = (CommitsAfterCreate > 0) ~ Additions + Deletions +
#     IsMerged + Commits + Linter + Coverage + Assignees + ChangedFiles +
#     PRsOpened + TotalBuilds + NewContributor + PrOpenedDaysAfterProjectStart +
#     FromOutsider + TotalReviewCommentThreads + GeneralComments +
#     LanguageType + IsAfter, family = "binomial", data = combined)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -5.5378  -0.6606  -0.0534   0.6840   2.8353
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   -4.383323   0.081207 -53.977  < 2e-16 ***
# Additions                      0.120140   0.006705  17.918  < 2e-16 ***
# Deletions                     -0.023714   0.006825  -3.475 0.000511 ***
# IsMergedTrue                   0.421024   0.020620  20.419  < 2e-16 ***
# Commits                        1.997516   0.019381 103.063  < 2e-16 ***
# LinterTrue                     0.041542   0.016998   2.444 0.014527 *
# CoverageTrue                   0.024706   0.017266   1.431 0.152459
# Assignees                      0.399203   0.043641   9.148  < 2e-16 ***
# ChangedFiles                  -0.301947   0.015215 -19.846  < 2e-16 ***
# PRsOpened                      0.013852   0.006840   2.025 0.042837 *
# TotalBuilds                    1.355993   0.031965  42.421  < 2e-16 ***
# NewContributorTrue             0.025214   0.029987   0.841 0.400434
# PrOpenedDaysAfterProjectStart  0.087233   0.011089   7.867 3.64e-15 ***
# FromOutsiderTrue               0.037651   0.022656   1.662 0.096545 .
# TotalReviewCommentThreads      0.669885   0.013681  48.963  < 2e-16 ***
# GeneralComments                0.732745   0.010840  67.598  < 2e-16 ***
# LanguageTypestatic            -0.112149   0.018040  -6.217 5.08e-10 ***
# IsAfterTrue                   -1.018083   0.033569 -30.328  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 144219  on 104031  degrees of freedom
# Residual deviance:  92194  on 104014  degrees of freedom
# AIC: 92230
#
# Number of Fisher Scoring iterations: 6
#       R2m       R2c
# 0.6521759 0.6521759
#                     Additions                     Deletions
#                      2.986506                      2.494515
#                      IsMerged                       Commits
#                      1.175426                      1.232303
#                        Linter                      Coverage
#                      1.048879                      1.093785
#                     Assignees                  ChangedFiles
#                      1.025022                      3.305652
#                     PRsOpened                   TotalBuilds
#                      3.008135                      3.495126
#                NewContributor PrOpenedDaysAfterProjectStart
#                      1.760326                      1.770808
#                  FromOutsider     TotalReviewCommentThreads
#                      1.869289                      1.071339
#               GeneralComments                  LanguageType
#                      1.124861                      1.211333
#                       IsAfter
#                      4.227599
#                               Df Deviance     Resid. Df Resid. Dev
# NULL                          NA           NA 104031    144218.97
# Additions                      1 10035.016732 104030    134183.96
# Deletions                      1     3.377500 104029    134180.58
# IsMerged                       1    80.819666 104028    134099.76
# Commits                        1 27848.057396 104027    106251.70
# Linter                         1    95.445707 104026    106156.26
# Coverage                       1    30.977290 104025    106125.28
# Assignees                      1   430.202096 104024    105695.08
# ChangedFiles                   1   504.981742 104023    105190.10
# PRsOpened                      1    23.878504 104022    105166.22
# TotalBuilds                    1  2348.833720 104021    102817.38
# NewContributor                 1     5.468721 104020    102811.92
# PrOpenedDaysAfterProjectStart  1     0.380930 104019    102811.53
# FromOutsider                   1     8.600029 104018    102802.93
# TotalReviewCommentThreads      1  4863.610158 104017     97939.32
# GeneralComments                1  4759.475924 104016     93179.85
# LanguageType                   1    42.590790 104015     93137.26
# IsAfter                        1   943.461450 104014     92193.80

# %%
baseModel <- executeLmOnData(
            CommitsAfterCreate ~ 
            Additions + 
            Deletions +
            IsMerged +
            Commits + 
            Assignees + 
            Linter +
            Coverage +
            ChangedFiles + 
            NumOfUniqueUsers +
            PRsOpened + 
            TotalBuilds + 
            NewContributor + 
            PrOpenedDaysAfterProjectStart +
            FromOutsider + 
            TotalReviewComments + 
            #TotalReviewCommentThreads +
            GeneralComments +
            LanguageType +
                IsAfter ,
        hasCommitsAfterCreate
        )
# Out:
# Call:
# lm(formula = formula, data = data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -3.3972 -0.1668  0.0019  0.2198  2.1304
#
# Coefficients:
#                                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)                   -0.1418243  0.0176471  -8.037 9.42e-16 ***
# Additions                      0.0006506  0.0013423   0.485 0.627898
# Deletions                     -0.0021903  0.0012949  -1.692 0.090744 .
# IsMergedTrue                   0.0084338  0.0042558   1.982 0.047516 *
# Commits                        0.6395512  0.0028197 226.814  < 2e-16 ***
# Assignees                      0.0393918  0.0079426   4.960 7.09e-07 ***
# LinterTrue                     0.0204161  0.0036071   5.660 1.52e-08 ***
# CoverageTrue                   0.0135149  0.0036840   3.668 0.000244 ***
# ChangedFiles                  -0.0157257  0.0028756  -5.469 4.56e-08 ***
# NumOfUniqueUsers              -0.1367836  0.0060539 -22.594  < 2e-16 ***
# PRsOpened                      0.0041877  0.0014807   2.828 0.004682 **
# TotalBuilds                    0.1031097  0.0037077  27.810  < 2e-16 ***
# NewContributorTrue             0.0220690  0.0065546   3.367 0.000761 ***
# PrOpenedDaysAfterProjectStart  0.0129467  0.0024557   5.272 1.35e-07 ***
# FromOutsiderTrue               0.0226750  0.0048357   4.689 2.75e-06 ***
# TotalReviewComments            0.0834321  0.0019626  42.512  < 2e-16 ***
# GeneralComments                0.1607613  0.0032449  49.542  < 2e-16 ***
# LanguageTypestatic            -0.0003660  0.0038413  -0.095 0.924094
# IsAfterTrue                   -0.1110274  0.0065941 -16.837  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.3966 on 51997 degrees of freedom
# Multiple R-squared:  0.6818,	Adjusted R-squared:  0.6817
# F-statistic:  6189 on 18 and 51997 DF,  p-value: < 2.2e-16
#
#                     Additions                     Deletions
#                      3.374144                      2.761137
#                      IsMerged                       Commits
#                      1.138650                      1.657120
#                     Assignees                        Linter
#                      1.040279                      1.041978
#                      Coverage                  ChangedFiles
#                      1.107190                      3.981166
#              NumOfUniqueUsers                     PRsOpened
#                      3.500274                      2.947086
#                   TotalBuilds                NewContributor
#                      2.835411                      1.704403
# PrOpenedDaysAfterProjectStart                  FromOutsider
#                      1.941477                      1.897420
#           TotalReviewComments               GeneralComments
#                      1.450964                      3.073644
#                  LanguageType                       IsAfter
#                      1.206153                      3.575785
# Analysis of Variance Table
#
# Response: CommitsAfterCreate
#                                  Df  Sum Sq Mean Sq    F value    Pr(>F)
# Additions                         1  3106.1  3106.1 19750.8704 < 2.2e-16 ***
# Deletions                         1    81.9    81.9   520.5231 < 2.2e-16 ***
# IsMerged                          1   228.3   228.3  1451.9244 < 2.2e-16 ***
# Commits                           1 12947.0 12947.0 82327.9672 < 2.2e-16 ***
# Assignees                         1    24.9    24.9   158.1078 < 2.2e-16 ***
# Linter                            1    10.4    10.4    66.1348 4.303e-16 ***
# Coverage                          1     6.3     6.3    39.9788 2.588e-10 ***
# ChangedFiles                      1    18.0    18.0   114.6842 < 2.2e-16 ***
# NumOfUniqueUsers                  1   365.8   365.8  2326.0079 < 2.2e-16 ***
# PRsOpened                         1     0.3     0.3     2.0228   0.15496
# TotalBuilds                       1   108.8   108.8   691.9681 < 2.2e-16 ***
# NewContributor                    1     0.0     0.0     0.2286   0.63259
# PrOpenedDaysAfterProjectStart     1     1.5     1.5     9.4786   0.00208 **
# FromOutsider                      1     4.2     4.2    26.6725 2.419e-07 ***
# TotalReviewComments               1   179.5   179.5  1141.1231 < 2.2e-16 ***
# GeneralComments                   1   392.1   392.1  2493.3150 < 2.2e-16 ***
# LanguageType                      1     0.0     0.0     0.0059   0.93890
# IsAfter                           1    44.6    44.6   283.4934 < 2.2e-16 ***
# Residuals                     51997  8177.1     0.2
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %% [markdown]
# # Interaction between Linter, Coverage, and Travis introduction

# %%
hurdleModelInteractionCoverageLinter = glm((CommitsAfterCreate > 0) ~ 
            Additions + 
            Deletions +
            IsMerged +
            Commits + 
            Assignees + 
            ChangedFiles + 
            #NumOfUniqueUsers +
            PRsOpened + 
            TotalBuilds + 
            NewContributor + 
            PrOpenedDaysAfterProjectStart +
            FromOutsider + 
            #TotalReviewComments + 
            TotalReviewCommentThreads +
            GeneralComments + 
            LanguageType +
            Coverage *
            Linter *
            IsAfter ,
          data= combined,
                 family = 'binomial')
summary(hurdleModelInteractionCoverageLinter)
r.squaredGLMM(hurdleModelInteractionCoverageLinter)
vif(hurdleModelInteractionCoverageLinter)
anova(hurdleModelInteractionCoverageLinter)

plot_model(hurdleModelInteractionCoverageLinter, type="pred", terms=c('IsAfter', 'Coverage', 'Linter'))
# Out:
# Call:
# glm(formula = (CommitsAfterCreate > 0) ~ Additions + Deletions +
#     IsMerged + Commits + Assignees + ChangedFiles + PRsOpened +
#     TotalBuilds + NewContributor + PrOpenedDaysAfterProjectStart +
#     FromOutsider + TotalReviewCommentThreads + GeneralComments +
#     LanguageType + Coverage * Linter * IsAfter, family = "binomial",
#     data = combined)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -5.5458  -0.6603  -0.0500   0.6834   2.8320
#
# Coefficients:
#                                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)                         -4.371156   0.083030 -52.646  < 2e-16 ***
# Additions                            0.119490   0.006709  17.810  < 2e-16 ***
# Deletions                           -0.023645   0.006827  -3.463 0.000534 ***
# IsMergedTrue                         0.422641   0.020635  20.482  < 2e-16 ***
# Commits                              1.995089   0.019387 102.908  < 2e-16 ***
# Assignees                            0.402575   0.043692   9.214  < 2e-16 ***
# ChangedFiles                        -0.302015   0.015221 -19.842  < 2e-16 ***
# PRsOpened                            0.014219   0.006864   2.071 0.038320 *
# TotalBuilds                          1.366932   0.032080  42.610  < 2e-16 ***
# NewContributorTrue                   0.024531   0.030024   0.817 0.413902
# PrOpenedDaysAfterProjectStart        0.088504   0.011113   7.964 1.67e-15 ***
# FromOutsiderTrue                     0.032501   0.022800   1.425 0.154013
# TotalReviewCommentThreads            0.672743   0.013743  48.952  < 2e-16 ***
# GeneralComments                      0.735995   0.010866  67.732  < 2e-16 ***
# LanguageTypestatic                  -0.116881   0.018328  -6.377 1.80e-10 ***
# CoverageTrue                         0.094423   0.037198   2.538 0.011138 *
# LinterTrue                          -0.039978   0.031099  -1.285 0.198623
# IsAfterTrue                         -1.041926   0.043909 -23.729  < 2e-16 ***
# CoverageTrue:LinterTrue              0.006659   0.047856   0.139 0.889329
# CoverageTrue:IsAfterTrue            -0.198166   0.052029  -3.809 0.000140 ***
# LinterTrue:IsAfterTrue               0.128871   0.043725   2.947 0.003206 **
# CoverageTrue:LinterTrue:IsAfterTrue  0.075995   0.067369   1.128 0.259304
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 144219  on 104031  degrees of freedom
# Residual deviance:  92148  on 104010  degrees of freedom
# AIC: 92192
#
# Number of Fisher Scoring iterations: 6
#       R2m       R2c
# 0.6525984 0.6525984
#                     Additions                     Deletions
#                      2.987565                      2.494926
#                      IsMerged                       Commits
#                      1.175895                      1.232752
#                     Assignees                  ChangedFiles
#                      1.026625                      3.306155
#                     PRsOpened                   TotalBuilds
#                      3.028199                      3.518138
#                NewContributor PrOpenedDaysAfterProjectStart
#                      1.763922                      1.779293
#                  FromOutsider     TotalReviewCommentThreads
#                      1.891943                      1.080610
#               GeneralComments                  LanguageType
#                      1.129478                      1.249530
#                      Coverage                        Linter
#                      5.074654                      3.510034
#                       IsAfter               Coverage:Linter
#                      7.228732                      6.589537
#              Coverage:IsAfter                Linter:IsAfter
#                      6.705161                      5.962635
#       Coverage:Linter:IsAfter
#                      7.653494
#                               Df Deviance     Resid. Df Resid. Dev
# NULL                          NA           NA 104031    144218.97
# Additions                      1 1.003502e+04 104030    134183.96
# Deletions                      1 3.377500e+00 104029    134180.58
# IsMerged                       1 8.081967e+01 104028    134099.76
# Commits                        1 2.784806e+04 104027    106251.70
# Assignees                      1 3.986000e+02 104026    105853.10
# ChangedFiles                   1 4.995057e+02 104025    105353.60
# PRsOpened                      1 2.026585e+01 104024    105333.33
# TotalBuilds                    1 2.367844e+03 104023    102965.49
# NewContributor                 1 6.344356e+00 104022    102959.14
# PrOpenedDaysAfterProjectStart  1 8.934224e-03 104021    102959.13
# FromOutsider                   1 7.014734e+00 104020    102952.12
# TotalReviewCommentThreads      1 4.934504e+03 104019     98017.62
# GeneralComments                1 4.809221e+03 104018     93208.40
# LanguageType                   1 5.023070e+01 104017     93158.16
# Coverage                       1 8.274294e+00 104016     93149.89
# Linter                         1 1.263262e+01 104015     93137.26
# IsAfter                        1 9.434614e+02 104014     92193.80
# Coverage:Linter                1 1.289604e+00 104013     92192.51
# Coverage:IsAfter               1 1.976179e+01 104012     92172.75
# Linter:IsAfter                 1 2.333260e+01 104011     92149.41
# Coverage:Linter:IsAfter        1 1.272443e+00 104010     92148.14
# plot without title

# %%
modelInteractionCoverageLinter <- executeLmOnData(
            CommitsAfterCreate ~ 
            Additions + 
            Deletions +
            IsMerged +
            Commits + 
            Assignees + 
            ChangedFiles + 
            NumOfUniqueUsers +
            PRsOpened + 
            TotalBuilds + 
            NewContributor + 
            PrOpenedDaysAfterProjectStart +
            FromOutsider + 
            #TotalReviewComments + 
            TotalReviewCommentThreads +
            GeneralComments +
            LanguageType +
            Coverage *
            Linter *
                IsAfter ,
        hasCommitsAfterCreate
        )

plot_model(modelInteractionCoverageLinter, type="pred", terms=c('IsAfter', 'Coverage', 'Linter'))
# Out:
# Call:
# lm(formula = formula, data = data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -3.4376 -0.1670  0.0039  0.2209  2.1380
#
# Coefficients:
#                                       Estimate Std. Error t value Pr(>|t|)
# (Intercept)                         -0.1411698  0.0181286  -7.787 6.98e-15 ***
# Additions                            0.0007953  0.0013434   0.592  0.55383
# Deletions                           -0.0019644  0.0012955  -1.516  0.12944
# IsMergedTrue                         0.0116474  0.0042572   2.736  0.00622 **
# Commits                              0.6392651  0.0028243 226.343  < 2e-16 ***
# Assignees                            0.0422201  0.0079514   5.310 1.10e-07 ***
# ChangedFiles                        -0.0159315  0.0028772  -5.537 3.09e-08 ***
# NumOfUniqueUsers                    -0.1258020  0.0059974 -20.976  < 2e-16 ***
# PRsOpened                            0.0044153  0.0014868   2.970  0.00298 **
# TotalBuilds                          0.1054662  0.0037182  28.365  < 2e-16 ***
# NewContributorTrue                   0.0220881  0.0065668   3.364  0.00077 ***
# PrOpenedDaysAfterProjectStart        0.0140434  0.0024650   5.697 1.22e-08 ***
# FromOutsiderTrue                     0.0230344  0.0048614   4.738 2.16e-06 ***
# TotalReviewCommentThreads            0.0838870  0.0020566  40.789  < 2e-16 ***
# GeneralComments                      0.1578372  0.0032375  48.753  < 2e-16 ***
# LanguageTypestatic                   0.0016647  0.0039175   0.425  0.67089
# CoverageTrue                         0.0101614  0.0082672   1.229  0.21903
# LinterTrue                          -0.0215769  0.0070214  -3.073  0.00212 **
# IsAfterTrue                         -0.1492731  0.0090449 -16.504  < 2e-16 ***
# CoverageTrue:LinterTrue              0.0243708  0.0106643   2.285  0.02230 *
# CoverageTrue:IsAfterTrue             0.0145878  0.0109794   1.329  0.18397
# LinterTrue:IsAfterTrue               0.0851106  0.0095198   8.940  < 2e-16 ***
# CoverageTrue:LinterTrue:IsAfterTrue -0.0595941  0.0142947  -4.169 3.06e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.3967 on 51993 degrees of freedom
# Multiple R-squared:  0.6816,	Adjusted R-squared:  0.6814
# F-statistic:  5059 on 22 and 51993 DF,  p-value: < 2.2e-16
#
#                     Additions                     Deletions
#                      3.377063                      2.761601
#                      IsMerged                       Commits
#                      1.138585                      1.661339
#                     Assignees                  ChangedFiles
#                      1.041831                      3.982710
#              NumOfUniqueUsers                     PRsOpened
#                      3.432739                      2.969255
#                   TotalBuilds                NewContributor
#                      2.849548                      1.709486
# PrOpenedDaysAfterProjectStart                  FromOutsider
#                      1.954721                      1.916212
#     TotalReviewCommentThreads               GeneralComments
#                      1.436175                      3.057347
#                  LanguageType                      Coverage
#                      1.253617                      5.571535
#                        Linter                       IsAfter
#                      3.945360                      6.722746
#               Coverage:Linter              Coverage:IsAfter
#                      7.238099                      7.261995
#                Linter:IsAfter       Coverage:Linter:IsAfter
#                      6.481167                      8.278485
# Analysis of Variance Table
#
# Response: CommitsAfterCreate
#                                  Df  Sum Sq Mean Sq    F value    Pr(>F)
# Additions                         1  3106.1  3106.1 19736.6475 < 2.2e-16 ***
# Deletions                         1    81.9    81.9   520.1483 < 2.2e-16 ***
# IsMerged                          1   228.3   228.3  1450.8788 < 2.2e-16 ***
# Commits                           1 12947.0 12947.0 82268.6812 < 2.2e-16 ***
# Assignees                         1    24.9    24.9   157.9940 < 2.2e-16 ***
# ChangedFiles                      1    18.1    18.1   114.9040 < 2.2e-16 ***
# NumOfUniqueUsers                  1   373.0   373.0  2370.1805 < 2.2e-16 ***
# PRsOpened                         1     0.2     0.2     1.4378  0.230502
# TotalBuilds                       1   109.7   109.7   696.9507 < 2.2e-16 ***
# NewContributor                    1     0.1     0.1     0.3360  0.562140
# PrOpenedDaysAfterProjectStart     1     1.5     1.5     9.2950  0.002299 **
# FromOutsider                      1     4.1     4.1    26.2906 2.948e-07 ***
# TotalReviewCommentThreads         1   177.4   177.4  1127.3039 < 2.2e-16 ***
# GeneralComments                   1   377.0   377.0  2395.6069 < 2.2e-16 ***
# LanguageType                      1     0.0     0.0     0.0023  0.962002
# Coverage                          1     3.1     3.1    19.4378 1.041e-05 ***
# Linter                            1     5.5     5.5    34.9812 3.350e-09 ***
# IsAfter                           1    41.7    41.7   264.8493 < 2.2e-16 ***
# Coverage:Linter                   1     0.2     0.2     1.1562  0.282262
# Coverage:IsAfter                  1     1.3     1.3     8.2033  0.004183 **
# Linter:IsAfter                    1    10.7    10.7    68.1729 < 2.2e-16 ***
# Coverage:Linter:IsAfter           1     2.7     2.7    17.3803 3.065e-05 ***
# Residuals                     51993  8182.4     0.2
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# plot without title
