# %% [markdown]
# Contains the R models used to analyze the number of review comments before and after the introduction of Travis CI. Looks at whether a boolean variable `IsAfterTravisIntroduction` can be used to predict the number of review comments under a pull request.

# %%
filename <- 'generated/num_of_review_comments.csv'

NumOfReviewCommentsData <- read.csv(file=filename, header=TRUE, sep=",")

summary(NumOfReviewCommentsData)
# Out:
#  EffectiveComments  PseudoEffectiveBuilds TotalReviewComments
#  Min.   :  0.0000   Min.   : 0.00000      Min.   :  0.000
#  1st Qu.:  0.0000   1st Qu.: 0.00000      1st Qu.:  0.000
#  Median :  0.0000   Median : 0.00000      Median :  0.000
#  Mean   :  0.2918   Mean   : 0.07549      Mean   :  1.296
#  3rd Qu.:  0.0000   3rd Qu.: 0.00000      3rd Qu.:  0.000
#  Max.   :259.0000   Max.   :59.00000      Max.   :420.000
#
#  TotalReviewCommentThreads ShareReviewComments GeneralComments
#  Min.   :  0.000           Min.   :  0.00      Min.   :   0.000
#  1st Qu.:  0.000           1st Qu.:  0.00      1st Qu.:   0.000
#  Median :  0.000           Median :  0.00      Median :   1.000
#  Mean   :  1.104           Mean   : 10.47      Mean   :   2.752
#  3rd Qu.:  0.000           3rd Qu.:  0.00      3rd Qu.:   3.000
#  Max.   :404.000           Max.   :100.00      Max.   :1035.000
#
#  GeneralCommentsDiscussingBuild   Linter        Coverage        Additions
#  Min.   :0                      False:170460   False:207572   Min.   :      0
#  1st Qu.:0                      True :156308   True :119196   1st Qu.:      1
#  Median :0                                                    Median :      8
#  Mean   :0                                                    Mean   :   1219
#  3rd Qu.:0                                                    3rd Qu.:     55
#  Max.   :0                                                    Max.   :4146796
#
#    Deletions          IsMerged         Commits          Assignees
#  Min.   :      0.0   False: 83860   Min.   :  0.000   Min.   :0.00000
#  1st Qu.:      0.0   True :242908   1st Qu.:  1.000   1st Qu.:0.00000
#  Median :      2.0                  Median :  1.000   Median :0.00000
#  Mean   :    425.6                  Mean   :  4.385   Mean   :0.06749
#  3rd Qu.:     15.0                  3rd Qu.:  3.000   3rd Qu.:0.00000
#  Max.   :1312711.0                  Max.   :250.000   Max.   :5.00000
#
#   ChangedFiles      PrOpenedDaysAfterProjectStart   ProjectLanguage
#  Min.   :    0.00   Min.   :   0                  C++       :50922
#  1st Qu.:    1.00   1st Qu.: 526                  Python    :44210
#  Median :    1.00   Median :1073                  JavaScript:36224
#  Mean   :   12.57   Mean   :1207                  PHP       :35968
#  3rd Qu.:    4.00   3rd Qu.:1805                  Java      :32116
#  Max.   :52720.00   Max.   :3899                  Ruby      :29728
#                                                   (Other)   :97600
#   IsAfter                             ProjectName     NumOfUniqueUsers
#  False:163384   caskdata/cdap               :  9624   Min.   :  0.000
#  True :163384   appcelerator/titanium_mobile:  7586   1st Qu.:  0.000
#                 bitcoin/bitcoin             :  6074   Median :  1.000
#                 symfony/symfony-docs        :  5766   Mean   :  1.558
#                 DynamoDS/Dynamo             :  5554   3rd Qu.:  2.000
#                 Baystation12/Baystation12   :  5422   Max.   :126.000
#                 (Other)                     :286742
#  NewContributor   PRsOpened       TotalBuilds      CommitsAfterCreate
#  False:270327   Min.   :   0.0   Min.   :  0.000   Min.   :  0.000
#  True : 56441   1st Qu.:   2.0   1st Qu.:  0.000   1st Qu.:  0.000
#                 Median :  18.0   Median :  0.000   Median :  0.000
#                 Mean   : 101.1   Mean   :  1.122   Mean   :  1.029
#                 3rd Qu.:  98.0   3rd Qu.:  1.000   3rd Qu.:  1.000
#                 Max.   :3813.0   Max.   :250.000   Max.   :250.000
#
#  AdditionsAfterCreate DeletionsAfterCreate  LanguageType    FromOutsider
#  Min.   :      0      Min.   :      0      dynamic:146130   False:120535
#  1st Qu.:      0      1st Qu.:      0      static :119172   True :206233
#  Median :      0      Median :      0      unk    : 61466
#  Mean   :    876      Mean   :    770
#  3rd Qu.:      1      3rd Qu.:      0
#  Max.   :4444094      Max.   :3869240

# %%
library(lmerTest)
library(MuMIn)
library(VIF)
library(sqldf)

vif.mer <- function (fit) {
    ## adapted from rms::vif
    
    v <- vcov(fit)
    nam <- names(fixef(fit))

    ## exclude intercepts
    ns <- sum(1 * (nam == "Intercept" | nam == "(Intercept)"))
    if (ns > 0) {
        v <- v[-(1:ns), -(1:ns), drop = FALSE]
        nam <- nam[-(1:ns)]
    }
    
    d <- diag(v)^0.5
    v <- diag(solve(v/(d %o% d)))
    names(v) <- nam
    v
}

# %%
hasReviewComments <- sqldf("select *
                      from 'NumOfReviewCommentsData' 
                      where TotalReviewCommentThreads > 0")

hasReviewCommentsAndFromOutsider <- sqldf("select *
                      from 'NumOfReviewCommentsData' 
                      where TotalReviewCommentThreads > 0 and FromOutsider = 'True'
                        and ProjectName in (select ProjectName from 'NumOfReviewCommentsData'
                                            where TotalReviewCommentThreads > 0 and FromOutsider = 'True'
                                            GROUP BY ProjectName
                                            HAVING Count() > 1)")

hasReviewComments <- hasReviewComments[hasReviewComments$TotalReviewCommentThreads < quantile(hasReviewComments$TotalReviewCommentThreads, 0.95), ]
hasReviewCommentsAndFromOutsider <- hasReviewCommentsAndFromOutsider[hasReviewCommentsAndFromOutsider$TotalReviewCommentThreads < quantile(hasReviewCommentsAndFromOutsider$TotalReviewCommentThreads, 0.95), ]

# Clear unused factors
hasReviewCommentsAndFromOutsider$ProjectName <- factor(hasReviewCommentsAndFromOutsider$ProjectName)
hasReviewCommentsAndFromOutsider$ProjectLanguage <- factor(hasReviewCommentsAndFromOutsider$ProjectLanguage)
hasReviewCommentsAndFromOutsider$IsMerged <- factor(hasReviewCommentsAndFromOutsider$IsMerged)

hasGeneralComments <- sqldf("select *
                      from 'NumOfReviewCommentsData' 
                      where GeneralComments > 0")

hasGeneralCommentsAndFromOutsider <- sqldf("select *
                      from 'NumOfReviewCommentsData' 
                      where GeneralComments > 0 and FromOutsider = 'True'
                        and ProjectName in (select ProjectName from 'NumOfReviewCommentsData'
                                            where GeneralComments > 0 and FromOutsider = 'True'
                                            GROUP BY ProjectName
                                            HAVING Count() > 1)")

# Clear unused factors
hasGeneralCommentsAndFromOutsider$ProjectName <- factor(hasGeneralCommentsAndFromOutsider$ProjectName)
hasGeneralCommentsAndFromOutsider$ProjectLanguage <- factor(hasGeneralCommentsAndFromOutsider$ProjectLanguage)
hasGeneralCommentsAndFromOutsider$IsMerged <- factor(hasGeneralCommentsAndFromOutsider$IsMerged)

summary(hasGeneralCommentsAndFromOutsider)

hasEffectiveComments <- sqldf("select *
                      from 'NumOfReviewCommentsData' 
                      where EffectiveComments > 0")

print(nrow(hasEffectiveComments))

hasEffectiveCommentsAndFromOutsider <- sqldf("select *
                      from 'NumOfReviewCommentsData' 
                      where EffectiveComments > 0 and FromOutsider = 'True'
                        and ProjectName in (select ProjectName from 'NumOfReviewCommentsData'
                                            where EffectiveComments > 0 and FromOutsider = 'True'
                                            GROUP BY ProjectName
                                            HAVING Count() > 1)")

# Clear unused factors
hasEffectiveCommentsAndFromOutsider$ProjectName <- factor(hasEffectiveCommentsAndFromOutsider$ProjectName)
hasEffectiveCommentsAndFromOutsider$ProjectLanguage <- factor(hasEffectiveCommentsAndFromOutsider$ProjectLanguage)
hasEffectiveCommentsAndFromOutsider$IsMerged <- factor(hasEffectiveCommentsAndFromOutsider$IsMerged)

summary(hasEffectiveCommentsAndFromOutsider)
# Out:
#  EffectiveComments  PseudoEffectiveBuilds TotalReviewComments
#  Min.   :  0.0000   Min.   : 0.00000      Min.   :  0.000
#  1st Qu.:  0.0000   1st Qu.: 0.00000      1st Qu.:  0.000
#  Median :  0.0000   Median : 0.00000      Median :  0.000
#  Mean   :  0.3992   Mean   : 0.07476      Mean   :  1.582
#  3rd Qu.:  0.0000   3rd Qu.: 0.00000      3rd Qu.:  0.000
#  Max.   :259.0000   Max.   :59.00000      Max.   :420.000
#
#  TotalReviewCommentThreads ShareReviewComments GeneralComments
#  Min.   :  0.000           Min.   : 0.00       Min.   :   1.000
#  1st Qu.:  0.000           1st Qu.: 0.00       1st Qu.:   1.000
#  Median :  0.000           Median : 0.00       Median :   2.000
#  Mean   :  1.356           Mean   :10.07       Mean   :   4.223
#  3rd Qu.:  0.000           3rd Qu.: 0.00       3rd Qu.:   5.000
#  Max.   :351.000           Max.   :99.72       Max.   :1035.000
#
#  GeneralCommentsDiscussingBuild   Linter       Coverage       Additions
#  Min.   :0                      False:73494   False:87269   Min.   :      0
#  1st Qu.:0                      True :69574   True :55799   1st Qu.:      0
#  Median :0                                                  Median :      5
#  Mean   :0                                                  Mean   :    816
#  3rd Qu.:0                                                  3rd Qu.:     43
#  Max.   :0                                                  Max.   :4146796
#
#    Deletions          IsMerged        Commits         Assignees
#  Min.   :      0.0   False:60856   Min.   :  0.00   Min.   :0.00000
#  1st Qu.:      0.0   True :82212   1st Qu.:  1.00   1st Qu.:0.00000
#  Median :      1.0                 Median :  1.00   Median :0.00000
#  Mean   :    340.2                 Mean   :  4.48   Mean   :0.06426
#  3rd Qu.:      9.0                 3rd Qu.:  3.00   3rd Qu.:0.00000
#  Max.   :1312711.0                 Max.   :250.00   Max.   :4.00000
#
#   ChangedFiles      PrOpenedDaysAfterProjectStart   ProjectLanguage
#  Min.   :    0.00   Min.   :   0                  C++       :20596
#  1st Qu.:    0.00   1st Qu.: 532                  PHP       :20225
#  Median :    1.00   Median :1054                  JavaScript:18653
#  Mean   :    9.83   Mean   :1193                  Python    :18600
#  3rd Qu.:    3.00   3rd Qu.:1760                  Ruby      :14313
#  Max.   :52720.00   Max.   :3899                  Java      :11205
#                                                   (Other)   :39476
#   IsAfter                       ProjectName     NumOfUniqueUsers
#  False:74301   symfony/symfony-docs   :  4576   Min.   :  1.000
#  True :68767   bitcoin/bitcoin        :  3963   1st Qu.:  1.000
#                symfony/symfony        :  2304   Median :  2.000
#                TrinityCore/TrinityCore:  2274   Mean   :  2.298
#                OTRS/otrs              :  1830   3rd Qu.:  3.000
#                hrydgard/ppsspp        :  1764   Max.   :126.000
#                (Other)                :126357
#  NewContributor   PRsOpened        TotalBuilds      CommitsAfterCreate
#  False:99489    Min.   :   0.00   Min.   :  0.000   Min.   :  0.000
#  True :43579    1st Qu.:   0.00   1st Qu.:  0.000   1st Qu.:  0.000
#                 Median :   3.00   Median :  0.000   Median :  0.000
#                 Mean   :  26.75   Mean   :  1.125   Mean   :  1.257
#                 3rd Qu.:  17.00   3rd Qu.:  1.000   3rd Qu.:  1.000
#                 Max.   :3166.00   Max.   :250.000   Max.   :250.000
#
#  AdditionsAfterCreate DeletionsAfterCreate  LanguageType   FromOutsider
#  Min.   :      0      Min.   :      0      dynamic:71791   False:     0
#  1st Qu.:      0      1st Qu.:      0      static :44165   True :143068
#  Median :      0      Median :      0      unk    :27112
#  Mean   :   1226      Mean   :    915
#  3rd Qu.:      2      3rd Qu.:      1
#  Max.   :4444094      Max.   :3869240
# [1] 21451
#  EffectiveComments PseudoEffectiveBuilds TotalReviewComments
#  Min.   :  1.000   Min.   : 0.0000       Min.   :  1.0
#  1st Qu.:  1.000   1st Qu.: 0.0000       1st Qu.:  2.0
#  Median :  2.000   Median : 0.0000       Median :  5.0
#  Mean   :  4.623   Mean   : 0.2468       Mean   : 10.1
#  3rd Qu.:  4.000   3rd Qu.: 0.0000       3rd Qu.: 11.0
#  Max.   :259.000   Max.   :39.0000       Max.   :420.0
#
#  TotalReviewCommentThreads ShareReviewComments GeneralComments
#  Min.   :  1.000           Min.   :  1.19      Min.   :  0.000
#  1st Qu.:  2.000           1st Qu.: 33.33      1st Qu.:  2.000
#  Median :  4.000           Median : 54.55      Median :  4.000
#  Mean   :  8.685           Mean   : 55.93      Mean   :  7.776
#  3rd Qu.:  9.000           3rd Qu.: 77.78      3rd Qu.:  9.000
#  Max.   :343.000           Max.   :100.00      Max.   :279.000
#
#  GeneralCommentsDiscussingBuild   Linter      Coverage      Additions
#  Min.   :0                      False:6641   False:7585   Min.   :      0.0
#  1st Qu.:0                      True :6509   True :5565   1st Qu.:      4.0
#  Median :0                                                Median :     40.0
#  Mean   :0                                                Mean   :    713.1
#  3rd Qu.:0                                                3rd Qu.:    198.0
#  Max.   :0                                                Max.   :1806414.0
#
#    Deletions         IsMerged       Commits          Assignees
#  Min.   :     0.0   False:3923   Min.   :  1.000   Min.   :0.00000
#  1st Qu.:     0.0   True :9227   1st Qu.:  2.000   1st Qu.:0.00000
#  Median :     3.0                Median :  4.000   Median :0.00000
#  Mean   :   176.3                Mean   :  9.538   Mean   :0.09909
#  3rd Qu.:    29.0                3rd Qu.:  8.000   3rd Qu.:0.00000
#  Max.   :142526.0                Max.   :250.000   Max.   :3.00000
#
#   ChangedFiles     PrOpenedDaysAfterProjectStart   ProjectLanguage  IsAfter
#  Min.   :   0.00   Min.   :   0                  Python    :2201   False:5407
#  1st Qu.:   1.00   1st Qu.: 666                  PHP       :2168   True :7743
#  Median :   2.00   Median :1331                  C++       :1844
#  Mean   :  10.01   Mean   :1360                  Ruby      :1368
#  3rd Qu.:   6.00   3rd Qu.:2007                  JavaScript:1359
#  Max.   :7584.00   Max.   :3714                  Java      :1002
#                                                  (Other)   :3208
#                     ProjectName    NumOfUniqueUsers NewContributor
#  symfony/symfony-docs     :  657   Min.   : 0.000   False:10108
#  MarkUsProject/Markus     :  383   1st Qu.: 2.000   True : 3042
#  TrinityCore/TrinityCore  :  332   Median : 3.000
#  symfony/symfony          :  286   Mean   : 3.422
#  scikit-learn/scikit-learn:  244   3rd Qu.: 4.000
#  cakephp/docs             :  240   Max.   :37.000
#  (Other)                  :11008
#    PRsOpened        TotalBuilds      CommitsAfterCreate AdditionsAfterCreate
#  Min.   :   0.00   Min.   :  0.000   Min.   :  1.000    Min.   :      0
#  1st Qu.:   1.00   1st Qu.:  0.000   1st Qu.:  1.000    1st Qu.:      5
#  Median :   5.00   Median :  1.000   Median :  2.000    Median :     30
#  Mean   :  24.61   Mean   :  2.793   Mean   :  5.735    Mean   :   4217
#  3rd Qu.:  20.00   3rd Qu.:  3.000   3rd Qu.:  5.000    3rd Qu.:    216
#  Max.   :1225.00   Max.   :211.000   Max.   :250.000    Max.   :1790575
#
#  DeletionsAfterCreate  LanguageType  FromOutsider
#  Min.   :      0      dynamic:7096   False:    0
#  1st Qu.:      4      static :3989   True :13150
#  Median :     20      unk    :2065
#  Mean   :   3214
#  3rd Qu.:    127
#  Max.   :1597453

# %%
determineImpact <- function(model, trainingData, target, interested_in) {        
    numVals = 0
    
    meanVals <- data.frame()

    if(class(trainingData[[interested_in]]) != 'factor'){
        print("Cannot do this for a non-factor")
        return
    } else {
        numVals = length(levels(trainingData[[interested_in]]))

        meanVals <- data.frame(matrix(ncol=1, nrow=numVals))
        
        colnames(meanVals)<- c(interested_in)
        
        meanVals[[interested_in]] = levels(trainingData[[interested_in]])
    }
    
    
    for(columnName in all.vars(as.formula(model))) {
        if(columnName == target) {
            next
        }
        if(columnName == interested_in) {
            next
        }
        
        if(class(trainingData[[columnName]]) == 'factor') {
            meanVals[[columnName]] = rep(c(levels(trainingData[[columnName]])[1]), numVals)
        } else {
            meanVals[[columnName]] = rep(c(median(trainingData[[columnName]])), numVals)
        }
    }
    
    print(meanVals)
    
    
    print("Order is: ")
    print(meanVals[[interested_in]])
    
    print("Predict is:")
    print(predict(model, meanVals, type="response"))
}

# %%
zerosdf <- sqldf("select *
                      from 'NumOfReviewCommentsData' 
                      where EffectiveComments = 0")
print(nrow(NumOfReviewCommentsData))
print(nrow(zerosdf))

sampledZerosdf <- zerosdf[sample(nrow(zerosdf), 15000),]

print(nrow(sampledZerosdf))

combined <- rbind(sampledZerosdf, hasEffectiveComments)

print(nrow(combined))

hurdleModel = glm((EffectiveComments > 0) ~ 
            log(Additions + 1) +
            log(Deletions + 1) +
            IsMerged +
            log(Commits + 1) +
            log(Assignees + 1) + 
            #log(ChangedFiles + 1) + 
            log(NumOfUniqueUsers + 1) +    
            log(PRsOpened + 1) +
            log(TotalBuilds + 1) +
            NewContributor + 
            log(PrOpenedDaysAfterProjectStart + 1) +
            FromOutsider + 
            log(TotalReviewComments + 1) +
            log(GeneralComments + 1) +
            log(CommitsAfterCreate + 1) +
            log(AdditionsAfterCreate + 1) +
            log(DeletionsAfterCreate + 1) +
            IsAfter ,
          data= combined,
                 family = 'binomial')
summary(hurdleModel)
r.squaredGLMM(hurdleModel)
#vif(hurdleModel)
anova(hurdleModel)
# Out:
# [1] 326768
# [1] 305317
# [1] 15000
# [1] 36451
# Call:
# glm(formula = (EffectiveComments > 0) ~ log(Additions + 1) +
#     log(Deletions + 1) + IsMerged + log(Commits + 1) + log(Assignees +
#     1) + log(NumOfUniqueUsers + 1) + log(PRsOpened + 1) + log(TotalBuilds +
#     1) + NewContributor + log(PrOpenedDaysAfterProjectStart +
#     1) + FromOutsider + log(TotalReviewComments + 1) + log(GeneralComments +
#     1) + log(CommitsAfterCreate + 1) + log(AdditionsAfterCreate +
#     1) + log(DeletionsAfterCreate + 1) + IsAfter, family = "binomial",
#     data = combined)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -5.6520  -0.2013   0.0209   0.2521   2.5660
#
# Coefficients:
#                                        Estimate Std. Error z value Pr(>|z|)
# (Intercept)                            -3.85358    0.22795 -16.905  < 2e-16 ***
# log(Additions + 1)                      0.01096    0.01579   0.694  0.48752
# log(Deletions + 1)                     -0.20555    0.01702 -12.080  < 2e-16 ***
# IsMergedTrue                            0.49538    0.05432   9.119  < 2e-16 ***
# log(Commits + 1)                       -0.55558    0.05595  -9.931  < 2e-16 ***
# log(Assignees + 1)                      0.33709    0.10942   3.081  0.00206 **
# log(NumOfUniqueUsers + 1)               1.46849    0.08412  17.457  < 2e-16 ***
# log(PRsOpened + 1)                     -0.07630    0.01791  -4.261 2.04e-05 ***
# log(TotalBuilds + 1)                    0.35493    0.06502   5.458 4.80e-08 ***
# NewContributorTrue                     -0.15783    0.07760  -2.034  0.04196 *
# log(PrOpenedDaysAfterProjectStart + 1)  0.03405    0.03063   1.112  0.26631
# FromOutsiderTrue                       -0.03485    0.05980  -0.583  0.56004
# log(TotalReviewComments + 1)            2.34027    0.04039  57.945  < 2e-16 ***
# log(GeneralComments + 1)               -0.81002    0.04411 -18.366  < 2e-16 ***
# log(CommitsAfterCreate + 1)             3.42265    0.07789  43.940  < 2e-16 ***
# log(AdditionsAfterCreate + 1)          -0.25644    0.02447 -10.479  < 2e-16 ***
# log(DeletionsAfterCreate + 1)           0.13994    0.02549   5.490 4.01e-08 ***
# IsAfterTrue                            -0.35243    0.08506  -4.143 3.43e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 49384  on 36450  degrees of freedom
# Residual deviance: 14256  on 36433  degrees of freedom
# AIC: 14292
#
# Number of Fisher Scoring iterations: 7
#       R2m       R2c
# 0.8772785 0.8772785
#                                        Df Deviance     Resid. Df Resid. Dev
# NULL                                   NA           NA 36450     49384.10
# log(Additions + 1)                      1 3.659706e+03 36449     45724.39
# log(Deletions + 1)                      1 2.453343e+02 36448     45479.06
# IsMerged                                1 2.310833e+01 36447     45455.95
# log(Commits + 1)                        1 8.497836e+03 36446     36958.11
# log(Assignees + 1)                      1 1.666621e+02 36445     36791.45
# log(NumOfUniqueUsers + 1)               1 7.880760e+03 36444     28910.69
# log(PRsOpened + 1)                      1 1.225748e+00 36443     28909.47
# log(TotalBuilds + 1)                    1 2.850947e+02 36442     28624.37
# NewContributor                          1 6.550751e+01 36441     28558.86
# log(PrOpenedDaysAfterProjectStart + 1)  1 2.615200e+00 36440     28556.25
# FromOutsider                            1 3.839485e-01 36439     28555.87
# log(TotalReviewComments + 1)            1 1.067825e+04 36438     17877.61
# log(GeneralComments + 1)                1 1.341528e+02 36437     17743.46
# log(CommitsAfterCreate + 1)             1 3.334892e+03 36436     14408.57
# log(AdditionsAfterCreate + 1)           1 1.037693e+02 36435     14304.80
# log(DeletionsAfterCreate + 1)           1 3.132703e+01 36434     14273.47
# IsAfter                                 1 1.704738e+01 36433     14256.42

# %% [markdown]
# # Effective Comments

# %%
library(car)

sort(table(hasEffectiveComments$ProjectLanguage))

modelNumberEffectiveComments = lm(log(EffectiveComments) ~ 
            log(Additions + 1) +
            log(Deletions + 1) +
            IsMerged +
            log(Commits + 1) +
            log(Assignees + 1) + 
            #log(ChangedFiles + 1) + 
            log(NumOfUniqueUsers + 1) +    
            log(PRsOpened + 1) +
            log(TotalBuilds + 1) +
            NewContributor + 
            log(PrOpenedDaysAfterProjectStart + 1) +
            FromOutsider + 
            log(TotalReviewComments) +
            log(GeneralComments + 1) +
            log(CommitsAfterCreate + 1) +
            log(AdditionsAfterCreate + 1) +
            log(DeletionsAfterCreate + 1) +
            IsAfter ,
          data= hasEffectiveComments)
summary(modelNumberEffectiveComments)
#r.squaredGLMM(modelNumberEffectiveComments)
vif(modelNumberEffectiveComments)
anova(modelNumberEffectiveComments)

print("---------------------------")

modelNumberEffectiveCommentsOutsider = lmer(log(EffectiveComments) ~ 
            log(Additions + 1) +
            log(Deletions + 1) +
            #IsMerged +
            log(Commits + 1) +
            log(Assignees + 1) + 
            log(ChangedFiles + 1) + 
            log(NumOfUniqueUsers + 1) +    
            log(PRsOpened + 1) +
            log(TotalBuilds + 1) +
            NewContributor + 
            log(PrOpenedDaysAfterProjectStart + 1) +
            #FromOutsider + 
            log(TotalReviewComments) +
            log(GeneralComments + 1) +
            IsAfter +
            (1|ProjectLanguage) +
            (1|ProjectName),
          data= hasEffectiveCommentsAndFromOutsider,
          REML=FALSE)
summary(modelNumberEffectiveCommentsOutsider)
r.squaredGLMM(modelNumberEffectiveCommentsOutsider)
vif.mer(modelNumberEffectiveCommentsOutsider)
anova(modelNumberEffectiveCommentsOutsider)
# Out:
#         Rust        OCaml       Perl 6       Puppet        CMake           F#
#            3            5            7            8            9           10
#          TeX      Fortran     Assembly     CartoCSS       Racket      Haskell
#           10           12           13           17           19           20
# CoffeeScript        Swift   TypeScript   Emacs Lisp        Scala        Julia
#           21           27           37           40           43           45
#       Erlang  Objective-J                   Clojure           Go            R
#           46           49           68           69           80          124
#         Perl      PLpgSQL          Nim        Shell          Lua         HTML
#          159          173          194          203          243          318
#           DM          CSS     Makefile            C           C#  Objective-C
#          353          368          506          592          769          940
#         Java         Ruby   JavaScript          PHP          C++       Python
#         1988         2202         2305         2680         2724         3952
# Call:
# lm(formula = log(EffectiveComments) ~ log(Additions + 1) + log(Deletions +
#     1) + IsMerged + log(Commits + 1) + log(Assignees + 1) + log(NumOfUniqueUsers +
#     1) + log(PRsOpened + 1) + log(TotalBuilds + 1) + NewContributor +
#     log(PrOpenedDaysAfterProjectStart + 1) + FromOutsider + log(TotalReviewComments) +
#     log(GeneralComments + 1) + log(CommitsAfterCreate + 1) +
#     log(AdditionsAfterCreate + 1) + log(DeletionsAfterCreate +
#     1) + IsAfter, data = hasEffectiveComments)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -2.83915 -0.36261  0.06643  0.40924  2.07001
#
# Coefficients:
#                                         Estimate Std. Error t value Pr(>|t|)
# (Intercept)                             0.425709   0.045975   9.260  < 2e-16
# log(Additions + 1)                      0.037716   0.002674  14.105  < 2e-16
# log(Deletions + 1)                     -0.083544   0.002722 -30.688  < 2e-16
# IsMergedTrue                            0.003693   0.010568   0.349 0.726721
# log(Commits + 1)                       -0.007533   0.010975  -0.686 0.492477
# log(Assignees + 1)                     -0.076692   0.017986  -4.264 2.02e-05
# log(NumOfUniqueUsers + 1)              -0.127170   0.016195  -7.852 4.28e-15
# log(PRsOpened + 1)                     -0.017375   0.003536  -4.913 9.04e-07
# log(TotalBuilds + 1)                    0.027209   0.008253   3.297 0.000979
# NewContributorTrue                     -0.012676   0.015339  -0.826 0.408585
# log(PrOpenedDaysAfterProjectStart + 1) -0.051667   0.006082  -8.495  < 2e-16
# FromOutsiderTrue                       -0.016800   0.011524  -1.458 0.144926
# log(TotalReviewComments)                0.595840   0.004708 126.560  < 2e-16
# log(GeneralComments + 1)                0.022336   0.006498   3.438 0.000588
# log(CommitsAfterCreate + 1)             0.131433   0.012990  10.118  < 2e-16
# log(AdditionsAfterCreate + 1)          -0.054835   0.004586 -11.956  < 2e-16
# log(DeletionsAfterCreate + 1)           0.059291   0.004780  12.403  < 2e-16
# IsAfterTrue                            -0.137883   0.015843  -8.703  < 2e-16
#
# (Intercept)                            ***
# log(Additions + 1)                     ***
# log(Deletions + 1)                     ***
# IsMergedTrue
# log(Commits + 1)
# log(Assignees + 1)                     ***
# log(NumOfUniqueUsers + 1)              ***
# log(PRsOpened + 1)                     ***
# log(TotalBuilds + 1)                   ***
# NewContributorTrue
# log(PrOpenedDaysAfterProjectStart + 1) ***
# FromOutsiderTrue
# log(TotalReviewComments)               ***
# log(GeneralComments + 1)               ***
# log(CommitsAfterCreate + 1)            ***
# log(AdditionsAfterCreate + 1)          ***
# log(DeletionsAfterCreate + 1)          ***
# IsAfterTrue                            ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.6123 on 21433 degrees of freedom
# Multiple R-squared:  0.5757,	Adjusted R-squared:  0.5754
# F-statistic:  1711 on 17 and 21433 DF,  p-value: < 2.2e-16
#                     log(Additions + 1)                     log(Deletions + 1)
#                               2.250459                               2.071355
#                               IsMerged                       log(Commits + 1)
#                               1.109558                               4.737270
#                     log(Assignees + 1)              log(NumOfUniqueUsers + 1)
#                               1.031183                               2.095553
#                     log(PRsOpened + 1)                   log(TotalBuilds + 1)
#                               2.647239                               2.999579
#                         NewContributor log(PrOpenedDaysAfterProjectStart + 1)
#                               1.659775                               1.830728
#                           FromOutsider               log(TotalReviewComments)
#                               1.802302                               1.585515
#               log(GeneralComments + 1)            log(CommitsAfterCreate + 1)
#                               2.192327                               6.113518
#          log(AdditionsAfterCreate + 1)          log(DeletionsAfterCreate + 1)
#                               8.175377                               8.022566
#                                IsAfter
#                               3.458491
#                                        Df    Sum Sq      Mean Sq
# log(Additions + 1)                         1 1395.706207 1395.7062073
# log(Deletions + 1)                         1  206.674460  206.6744600
# IsMerged                                   1   77.758775   77.7587751
# log(Commits + 1)                           1 1817.795268 1817.7952677
# log(Assignees + 1)                         1    3.411114    3.4111140
# log(NumOfUniqueUsers + 1)                  1  598.140105  598.1401051
# log(PRsOpened + 1)                         1   42.893250   42.8932501
# log(TotalBuilds + 1)                       1   42.480764   42.4807642
# NewContributor                             1   15.612601   15.6126008
# log(PrOpenedDaysAfterProjectStart + 1)     1   59.913813   59.9138134
# FromOutsider                               1    0.506725    0.5067250
# log(TotalReviewComments)                   1 6490.368193 6490.3681934
# log(GeneralComments + 1)                   1   12.366674   12.3666740
# log(CommitsAfterCreate + 1)                1   49.952208   49.9522084
# log(AdditionsAfterCreate + 1)              1    2.594826    2.5948261
# log(DeletionsAfterCreate + 1)              1   60.067447   60.0674466
# IsAfter                                    1   28.398839   28.3988393
# Residuals                              21433 8035.820751    0.3749275
#                                        F value      Pr(>F)
# log(Additions + 1)                      3722.603088  0.000000e+00
# log(Deletions + 1)                       551.238491 2.236010e-120
# IsMerged                                 207.396839  8.402395e-47
# log(Commits + 1)                        4848.391618  0.000000e+00
# log(Assignees + 1)                         9.098063  2.561802e-03
# log(NumOfUniqueUsers + 1)               1595.348785  0.000000e+00
# log(PRsOpened + 1)                       114.404124  1.240740e-26
# log(TotalBuilds + 1)                     113.303948  2.154619e-26
# NewContributor                            41.641655  1.119770e-10
# log(PrOpenedDaysAfterProjectStart + 1)   159.801071  1.688267e-36
# FromOutsider                               1.351528  2.450241e-01
# log(TotalReviewComments)               17310.996077  0.000000e+00
# log(GeneralComments + 1)                  32.984176  9.416889e-09
# log(CommitsAfterCreate + 1)              133.231653  9.918357e-31
# log(AdditionsAfterCreate + 1)              6.920875  8.525624e-03
# log(DeletionsAfterCreate + 1)            160.210839  1.375863e-36
# IsAfter                                   75.744886  3.456778e-18
# Residuals                                        NA            NA
# [1] "---------------------------"
# Correlation matrix not shown by default, as p = 14 > 12.
# Use print(obj, correlation=TRUE)  or
# 	 vcov(obj)	 if you need it
# Linear mixed model fit by maximum likelihood t-tests use Satterthwaite
#   approximations to degrees of freedom [lmerMod]
# Formula: log(EffectiveComments) ~ log(Additions + 1) + log(Deletions +
#     1) + log(Commits + 1) + log(Assignees + 1) + log(ChangedFiles +
#     1) + log(NumOfUniqueUsers + 1) + log(PRsOpened + 1) + log(TotalBuilds +
#     1) + NewContributor + log(PrOpenedDaysAfterProjectStart +
#     1) + log(TotalReviewComments) + log(GeneralComments + 1) +
#     IsAfter + (1 | ProjectLanguage) + (1 | ProjectName)
#    Data: hasEffectiveCommentsAndFromOutsider
#
#      AIC      BIC   logLik deviance df.resid
#  24170.7  24297.9 -12068.3  24136.7    13133
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.5959 -0.5708  0.1148  0.6480  3.1762
#
# Random effects:
#  Groups          Name        Variance Std.Dev.
#  ProjectName     (Intercept) 0.013011 0.11407
#  ProjectLanguage (Intercept) 0.002019 0.04494
#  Residual                    0.360104 0.60009
# Number of obs: 13150, groups:  ProjectName, 377; ProjectLanguage, 42
#
# Fixed effects:
#                                          Estimate Std. Error         df t value
# (Intercept)                             3.280e-01  6.541e-02  2.225e+03   5.014
# log(Additions + 1)                      3.085e-02  4.203e-03  1.265e+04   7.339
# log(Deletions + 1)                     -7.629e-02  3.904e-03  1.312e+04 -19.540
# log(Commits + 1)                        9.842e-02  9.116e-03  1.265e+04  10.796
# log(Assignees + 1)                     -6.880e-02  2.853e-02  7.378e+03  -2.411
# log(ChangedFiles + 1)                  -1.248e-03  9.862e-03  1.300e+04  -0.127
# log(NumOfUniqueUsers + 1)              -1.059e-01  2.136e-02  1.160e+04  -4.958
# log(PRsOpened + 1)                     -1.297e-02  4.856e-03  1.147e+04  -2.671
# log(TotalBuilds + 1)                    4.135e-02  1.102e-02  1.210e+04   3.752
# NewContributorTrue                     -7.089e-03  1.699e-02  1.312e+04  -0.417
# log(PrOpenedDaysAfterProjectStart + 1) -6.013e-02  9.209e-03  3.493e+03  -6.530
# log(TotalReviewComments)                6.212e-01  5.951e-03  1.289e+04 104.385
# log(GeneralComments + 1)                3.931e-02  8.469e-03  1.184e+04   4.642
# IsAfterTrue                            -1.367e-01  2.122e-02  1.104e+04  -6.444
#                                        Pr(>|t|)
# (Intercept)                            5.74e-07 ***
# log(Additions + 1)                     2.28e-13 ***
# log(Deletions + 1)                      < 2e-16 ***
# log(Commits + 1)                        < 2e-16 ***
# log(Assignees + 1)                     0.015921 *
# log(ChangedFiles + 1)                  0.899330
# log(NumOfUniqueUsers + 1)              7.21e-07 ***
# log(PRsOpened + 1)                     0.007582 **
# log(TotalBuilds + 1)                   0.000176 ***
# NewContributorTrue                     0.676547
# log(PrOpenedDaysAfterProjectStart + 1) 7.54e-11 ***
# log(TotalReviewComments)                < 2e-16 ***
# log(GeneralComments + 1)               3.49e-06 ***
# IsAfterTrue                            1.21e-10 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#       R2m       R2c
# 0.5917635 0.6081205
#                     log(Additions + 1)                     log(Deletions + 1)
#                               3.368133                               2.144010
#                       log(Commits + 1)                     log(Assignees + 1)
#                               1.812635                               1.015061
#                  log(ChangedFiles + 1)              log(NumOfUniqueUsers + 1)
#                               3.946167                               2.039195
#                     log(PRsOpened + 1)                   log(TotalBuilds + 1)
#                               1.747895                               3.089787
#                     NewContributorTrue log(PrOpenedDaysAfterProjectStart + 1)
#                               1.699323                               1.976108
#               log(TotalReviewComments)               log(GeneralComments + 1)
#                               1.501368                               2.019337
#                            IsAfterTrue
#                               3.621183
#                                        Sum Sq       Mean Sq      NumDF
# log(Additions + 1)                     1.939568e+01 1.939568e+01 1
# log(Deletions + 1)                     1.374897e+02 1.374897e+02 1
# log(Commits + 1)                       4.197047e+01 4.197047e+01 1
# log(Assignees + 1)                     2.093760e+00 2.093760e+00 1
# log(ChangedFiles + 1)                  5.763430e-03 5.763430e-03 1
# log(NumOfUniqueUsers + 1)              8.853597e+00 8.853597e+00 1
# log(PRsOpened + 1)                     2.568296e+00 2.568296e+00 1
# log(TotalBuilds + 1)                   5.068526e+00 5.068526e+00 1
# NewContributor                         6.267494e-02 6.267494e-02 1
# log(PrOpenedDaysAfterProjectStart + 1) 1.535405e+01 1.535405e+01 1
# log(TotalReviewComments)               3.923778e+03 3.923778e+03 1
# log(GeneralComments + 1)               7.758674e+00 7.758674e+00 1
# IsAfter                                1.495555e+01 1.495555e+01 1
#                                        DenDF     F.value      Pr(>F)
# log(Additions + 1)                     12653.869 5.386127e+01 2.282619e-13
# log(Deletions + 1)                     13116.884 3.818051e+02 0.000000e+00
# log(Commits + 1)                       12653.045 1.165508e+02 0.000000e+00
# log(Assignees + 1)                      7378.245 5.814314e+00 1.592053e-02
# log(ChangedFiles + 1)                  13003.942 1.600489e-02 8.993299e-01
# log(NumOfUniqueUsers + 1)              11604.907 2.458620e+01 7.206408e-07
# log(PRsOpened + 1)                     11466.306 7.132088e+00 7.582331e-03
# log(TotalBuilds + 1)                   12105.311 1.407516e+01 1.764683e-04
# NewContributor                         13123.400 1.740466e-01 6.765471e-01
# log(PrOpenedDaysAfterProjectStart + 1)  3492.739 4.263778e+01 7.540235e-11
# log(TotalReviewComments)               12894.015 1.089622e+04 0.000000e+00
# log(GeneralComments + 1)               11843.956 2.154563e+01 3.492196e-06
# IsAfter                                11036.296 4.153117e+01 1.208416e-10

# %% [markdown]
# # Review comments

# %%
modelNumberReviewComments = lmer(log(TotalReviewCommentThreads) ~ 
            log(Additions + 1) +
            log(Deletions + 1) +
            IsMerged +
            log(Commits + 1) +
            log(Assignees + 1) + 
            log(ChangedFiles + 1) + 
            log(NumOfUniqueUsers + 1) +    
            log(PRsOpened + 1) +
            log(TotalBuilds + 1) +
            NewContributor + 
            log(PrOpenedDaysAfterProjectStart + 1) +
            FromOutsider + 
            IsAfter + 
            (1|ProjectLanguage) +
            (1|ProjectName),
          data= hasReviewComments,
          REML=FALSE)
summary(modelNumberReviewComments)
r.squaredGLMM(modelNumberReviewComments)
vif.mer(modelNumberReviewComments)
anova(modelNumberReviewComments)

determineImpact(modelNumberReviewComments, hasReviewComments, 'TotalReviewCommentThreads', 'IsAfter')

print("---------------------------")

modelNumberReviewCommentsOutsider = lmer(log(TotalReviewCommentThreads) ~ 
            log(Additions + 1) +
            log(Deletions + 1) +
            #IsMerged +
            log(Commits + 1) +
            log(Assignees + 1) + 
            log(ChangedFiles + 1) + 
            log(NumOfUniqueUsers + 1) +    
            log(PRsOpened + 1) +
            log(TotalBuilds + 1) +
            NewContributor + 
            log(PrOpenedDaysAfterProjectStart + 1) +
            #FromOutsider + 
            IsAfter +
            (1|ProjectLanguage) +
            (1|ProjectName),
          data= hasReviewCommentsAndFromOutsider,
          REML=FALSE)
summary(modelNumberReviewCommentsOutsider)
r.squaredGLMM(modelNumberReviewCommentsOutsider)
vif.mer(modelNumberReviewCommentsOutsider)
anova(modelNumberReviewCommentsOutsider)

determineImpact(modelNumberReviewCommentsOutsider, hasReviewCommentsAndFromOutsider, 'TotalReviewCommentThreads', 'IsAfter')
# Out:
# Correlation matrix not shown by default, as p = 14 > 12.
# Use print(obj, correlation=TRUE)  or
# 	 vcov(obj)	 if you need it
# Linear mixed model fit by maximum likelihood t-tests use Satterthwaite
#   approximations to degrees of freedom [lmerMod]
# Formula: log(TotalReviewCommentThreads) ~ log(Additions + 1) + log(Deletions +
#     1) + IsMerged + log(Commits + 1) + log(Assignees + 1) + log(ChangedFiles +
#     1) + log(NumOfUniqueUsers + 1) + log(PRsOpened + 1) + log(TotalBuilds +
#     1) + NewContributor + log(PrOpenedDaysAfterProjectStart +
#     1) + FromOutsider + IsAfter + (1 | ProjectLanguage) + (1 |
#     ProjectName)
#    Data: hasReviewComments
#
#      AIC      BIC   logLik deviance df.resid
# 131463.6 131615.9 -65714.8 131429.6    57525
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -3.3119 -0.7636 -0.0563  0.7185  3.4132
#
# Random effects:
#  Groups          Name        Variance  Std.Dev.
#  ProjectName     (Intercept) 0.0365343 0.1911
#  ProjectLanguage (Intercept) 0.0006504 0.0255
#  Residual                    0.5676426 0.7534
# Number of obs: 57542, groups:  ProjectName, 390; ProjectLanguage, 42
#
# Fixed effects:
#                                          Estimate Std. Error         df t value
# (Intercept)                            -3.687e-02  4.598e-02  1.066e+03  -0.802
# log(Additions + 1)                      9.168e-02  2.643e-03  5.743e+04  34.684
# log(Deletions + 1)                      5.201e-03  2.453e-03  5.752e+04   2.120
# IsMergedTrue                            3.434e-02  8.185e-03  5.679e+04   4.196
# log(Commits + 1)                        1.744e-01  5.557e-03  5.713e+04  31.391
# log(Assignees + 1)                      1.301e-01  1.678e-02  5.098e+04   7.756
# log(ChangedFiles + 1)                  -5.957e-02  5.743e-03  5.726e+04 -10.373
# log(NumOfUniqueUsers + 1)               7.493e-01  1.021e-02  5.625e+04  73.373
# log(PRsOpened + 1)                     -1.131e-02  2.897e-03  5.396e+04  -3.904
# log(TotalBuilds + 1)                    3.462e-02  8.001e-03  5.706e+04   4.327
# NewContributorTrue                     -6.256e-02  1.244e-02  5.750e+04  -5.030
# log(PrOpenedDaysAfterProjectStart + 1) -6.633e-02  6.467e-03  3.066e+04 -10.256
# FromOutsiderTrue                        5.834e-02  9.382e-03  5.535e+04   6.218
# IsAfterTrue                            -1.192e-01  1.257e-02  5.461e+04  -9.478
#                                        Pr(>|t|)
# (Intercept)                               0.423
# log(Additions + 1)                      < 2e-16 ***
# log(Deletions + 1)                        0.034 *
# IsMergedTrue                           2.72e-05 ***
# log(Commits + 1)                        < 2e-16 ***
# log(Assignees + 1)                     8.88e-15 ***
# log(ChangedFiles + 1)                   < 2e-16 ***
# log(NumOfUniqueUsers + 1)               < 2e-16 ***
# log(PRsOpened + 1)                     9.46e-05 ***
# log(TotalBuilds + 1)                   1.51e-05 ***
# NewContributorTrue                     4.91e-07 ***
# log(PrOpenedDaysAfterProjectStart + 1)  < 2e-16 ***
# FromOutsiderTrue                       5.06e-10 ***
# IsAfterTrue                             < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#       R2m       R2c
# 0.2015988 0.2506843
#                     log(Additions + 1)                     log(Deletions + 1)
#                               2.876676                               2.267850
#                           IsMergedTrue                       log(Commits + 1)
#                               1.065104                               1.603596
#                     log(Assignees + 1)                  log(ChangedFiles + 1)
#                               1.008250                               3.264052
#              log(NumOfUniqueUsers + 1)                     log(PRsOpened + 1)
#                               1.070585                               2.465040
#                   log(TotalBuilds + 1)                     NewContributorTrue
#                               2.700446                               1.512008
# log(PrOpenedDaysAfterProjectStart + 1)                       FromOutsiderTrue
#                               2.292416                               1.674288
#                            IsAfterTrue
#                               3.548250
#                                        Sum Sq      Mean Sq     NumDF DenDF
# log(Additions + 1)                      682.870662  682.870662 1     57432.00
# log(Deletions + 1)                        2.551695    2.551695 1     57524.45
# IsMerged                                  9.995319    9.995319 1     56786.48
# log(Commits + 1)                        559.351049  559.351049 1     57131.44
# log(Assignees + 1)                       34.146119   34.146119 1     50977.72
# log(ChangedFiles + 1)                    61.079630   61.079630 1     57257.02
# log(NumOfUniqueUsers + 1)              3055.981616 3055.981616 1     56253.61
# log(PRsOpened + 1)                        8.652601    8.652601 1     53960.16
# log(TotalBuilds + 1)                     10.629246   10.629246 1     57056.49
# NewContributor                           14.363065   14.363065 1     57503.48
# log(PrOpenedDaysAfterProjectStart + 1)   59.706174   59.706174 1     30656.77
# FromOutsider                             21.949363   21.949363 1     55350.86
# IsAfter                                  50.995750   50.995750 1     54607.94
#                                        F.value    Pr(>F)
# log(Additions + 1)                     1202.99409 0.000000e+00
# log(Deletions + 1)                        4.49525 3.399341e-02
# IsMerged                                 17.60847 2.717885e-05
# log(Commits + 1)                        985.39305 0.000000e+00
# log(Assignees + 1)                       60.15426 8.881784e-15
# log(ChangedFiles + 1)                   107.60227 0.000000e+00
# log(NumOfUniqueUsers + 1)              5383.63709 0.000000e+00
# log(PRsOpened + 1)                       15.24304 9.463909e-05
# log(TotalBuilds + 1)                     18.72524 1.512269e-05
# NewContributor                           25.30301 4.914155e-07
# log(PrOpenedDaysAfterProjectStart + 1)  105.18269 0.000000e+00
# FromOutsider                             38.66758 5.060652e-10
# IsAfter                                  89.83778 0.000000e+00
#   IsAfter Additions Deletions IsMerged Commits Assignees ChangedFiles
# 1   False        42         7    False       2         0            3
# 2    True        42         7    False       2         0            3
#   NumOfUniqueUsers PRsOpened TotalBuilds NewContributor
# 1                3        27           1          False
# 2                3        27           1          False
#   PrOpenedDaysAfterProjectStart FromOutsider ProjectLanguage
# 1                          1332        False
# 2                          1332        False
#                      ProjectName
# 1 activemerchant/active_merchant
# 2 activemerchant/active_merchant
# [1] "Order is: "
# [1] "False" "True"
# [1] "Predict is:"
#         1         2
# 1.0740252 0.9548506
# [1] "---------------------------"
# Linear mixed model fit by maximum likelihood t-tests use Satterthwaite
#   approximations to degrees of freedom [lmerMod]
# Formula: log(TotalReviewCommentThreads) ~ log(Additions + 1) + log(Deletions +
#     1) + log(Commits + 1) + log(Assignees + 1) + log(ChangedFiles +
#     1) + log(NumOfUniqueUsers + 1) + log(PRsOpened + 1) + log(TotalBuilds +
#     1) + NewContributor + log(PrOpenedDaysAfterProjectStart +
#     1) + IsAfter + (1 | ProjectLanguage) + (1 | ProjectName)
#    Data: hasReviewCommentsAndFromOutsider
#
#      AIC      BIC   logLik deviance df.resid
#  74686.9  74812.8 -37328.5  74656.9    32425
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -3.2027 -0.7708 -0.0549  0.7217  3.3180
#
# Random effects:
#  Groups          Name        Variance  Std.Dev.
#  ProjectName     (Intercept) 3.694e-02 1.922e-01
#  ProjectLanguage (Intercept) 4.930e-14 2.220e-07
#  Residual                    5.747e-01 7.581e-01
# Number of obs: 32440, groups:  ProjectName, 389; ProjectLanguage, 42
#
# Fixed effects:
#                                          Estimate Std. Error         df t value
# (Intercept)                            -4.081e-02  5.529e-02  1.222e+04  -0.738
# log(Additions + 1)                      8.391e-02  3.527e-03  3.229e+04  23.789
# log(Deletions + 1)                      4.407e-03  3.393e-03  3.243e+04   1.299
# log(Commits + 1)                        1.896e-01  7.460e-03  3.216e+04  25.418
# log(Assignees + 1)                      8.115e-02  2.462e-02  2.659e+04   3.296
# log(ChangedFiles + 1)                  -7.612e-02  8.137e-03  3.240e+04  -9.354
# log(NumOfUniqueUsers + 1)               7.040e-01  1.305e-02  3.143e+04  53.947
# log(PRsOpened + 1)                      2.141e-03  3.780e-03  3.115e+04   0.566
# log(TotalBuilds + 1)                    4.873e-02  1.085e-02  3.203e+04   4.492
# NewContributorTrue                     -3.681e-02  1.384e-02  3.244e+04  -2.659
# log(PrOpenedDaysAfterProjectStart + 1) -4.419e-02  8.036e-03  1.509e+04  -5.500
# IsAfterTrue                            -1.406e-01  1.656e-02  3.044e+04  -8.489
#                                        Pr(>|t|)
# (Intercept)                             0.46054
# log(Additions + 1)                      < 2e-16 ***
# log(Deletions + 1)                      0.19403
# log(Commits + 1)                        < 2e-16 ***
# log(Assignees + 1)                      0.00098 ***
# log(ChangedFiles + 1)                   < 2e-16 ***
# log(NumOfUniqueUsers + 1)               < 2e-16 ***
# log(PRsOpened + 1)                      0.57107
# log(TotalBuilds + 1)                   7.09e-06 ***
# NewContributorTrue                      0.00784 **
# log(PrOpenedDaysAfterProjectStart + 1) 3.87e-08 ***
# IsAfterTrue                             < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) lg(Ad+1) l(D+1) l(C+1) lg(As+1) l(CF+1 l(NO+1 l(PR+1 l(TB+1
# lg(Addtn+1) -0.050
# lg(Dltns+1)  0.009 -0.245
# lg(Cmmts+1) -0.234 -0.048   -0.063
# lg(Assgn+1)  0.025 -0.024   -0.003 -0.015
# lg(ChngF+1)  0.039 -0.613   -0.361 -0.115  0.019
# lg(NmOUU+1) -0.224 -0.063    0.032 -0.092 -0.054   -0.013
# lg(PRsOp+1) -0.105  0.009   -0.081  0.050 -0.022   -0.020  0.061
# lg(TtlBl+1)  0.172 -0.004    0.028 -0.499  0.000    0.015 -0.032  0.017
# NwCntrbtrTr -0.129  0.034    0.003  0.018 -0.018   -0.016 -0.003  0.614  0.000
# l(PODAPS+1) -0.899  0.016    0.003  0.108 -0.023   -0.027 -0.056 -0.067 -0.085
# IsAfterTrue  0.342 -0.009   -0.019  0.327 -0.023   -0.012 -0.016 -0.023 -0.635
#             NwCntT l(PO+1
# lg(Addtn+1)
# lg(Dltns+1)
# lg(Cmmts+1)
# lg(Assgn+1)
# lg(ChngF+1)
# lg(NmOUU+1)
# lg(PRsOp+1)
# lg(TtlBl+1)
# NwCntrbtrTr
# l(PODAPS+1) -0.015
# IsAfterTrue -0.013 -0.488
#       R2m       R2c
# 0.1865560 0.2356827
#                     log(Additions + 1)                     log(Deletions + 1)
#                               3.072229                               2.166184
#                       log(Commits + 1)                     log(Assignees + 1)
#                               1.576182                               1.011227
#                  log(ChangedFiles + 1)              log(NumOfUniqueUsers + 1)
#                               3.371933                               1.063712
#                     log(PRsOpened + 1)                   log(TotalBuilds + 1)
#                               1.693078                               2.877580
#                     NewContributorTrue log(PrOpenedDaysAfterProjectStart + 1)
#                               1.641352                               2.096864
#                            IsAfterTrue
#                               3.450625
#                                        Sum Sq       Mean Sq      NumDF DenDF
# log(Additions + 1)                      325.2276824  325.2276824 1     32290.61
# log(Deletions + 1)                        0.9693830    0.9693830 1     32426.68
# log(Commits + 1)                        371.2953416  371.2953416 1     32159.61
# log(Assignees + 1)                        6.2450702    6.2450702 1     26592.30
# log(ChangedFiles + 1)                    50.2884733   50.2884733 1     32399.45
# log(NumOfUniqueUsers + 1)              1672.5233548 1672.5233548 1     31425.61
# log(PRsOpened + 1)                        0.1844149    0.1844149 1     31153.12
# log(TotalBuilds + 1)                     11.5942062   11.5942062 1     32034.00
# NewContributor                            4.0630138    4.0630138 1     32438.87
# log(PrOpenedDaysAfterProjectStart + 1)   17.3814051   17.3814051 1     15088.72
# IsAfter                                  41.4183343   41.4183343 1     30437.69
#                                        F.value      Pr(>F)
# log(Additions + 1)                      565.9208275 0.000000e+00
# log(Deletions + 1)                        1.6867999 1.940326e-01
# log(Commits + 1)                        646.0820476 0.000000e+00
# log(Assignees + 1)                       10.8668958 9.802671e-04
# log(ChangedFiles + 1)                    87.5057567 0.000000e+00
# log(NumOfUniqueUsers + 1)              2910.3174555 0.000000e+00
# log(PRsOpened + 1)                        0.3208959 5.710738e-01
# log(TotalBuilds + 1)                     20.1747979 7.092470e-06
# NewContributor                            7.0699520 7.842583e-03
# log(PrOpenedDaysAfterProjectStart + 1)   30.2449628 3.869684e-08
# IsAfter                                  72.0710422 0.000000e+00
#   IsAfter Additions Deletions Commits Assignees ChangedFiles NumOfUniqueUsers
# 1   False        25         3       2         0            2                3
# 2    True        25         3       2         0            2                3
#   PRsOpened TotalBuilds NewContributor PrOpenedDaysAfterProjectStart
# 1         6           1          False                          1320
# 2         6           1          False                          1320
#   ProjectLanguage                    ProjectName
# 1                 activemerchant/active_merchant
# 2                 activemerchant/active_merchant
# [1] "Order is: "
# [1] "False" "True"
# [1] "Predict is:"
#        1        2
# 1.155534 1.014951

# %% [markdown]
# # General comments

# %%
modelNumberGeneralComments = lmer(log(GeneralComments) ~ 
            log(Additions + 1) +
            log(Deletions + 1) +
            IsMerged +
            log(Commits + 1) +
            log(Assignees + 1) + 
            log(ChangedFiles + 1) + 
            log(NumOfUniqueUsers + 1) +    
            log(PRsOpened + 1) +
            log(TotalBuilds + 1) +
            NewContributor + 
            FromOutsider + 
            #log(PrOpenedDaysAfterProjectStart + 1) +
            IsAfter + 
            (1|ProjectLanguage) +
            (1|ProjectName),
          data= hasGeneralComments, 
          REML=FALSE)
summary(modelNumberGeneralComments)
r.squaredGLMM(modelNumberGeneralComments)
vif.mer(modelNumberGeneralComments)
anova(modelNumberGeneralComments)

print("---------------------------")

modelNumberGeneralCommentsOutsider = lmer(log(GeneralComments) ~ 
            log(Additions + 1) +
            log(Deletions + 1) +
            #IsMerged +
            log(Commits + 1) +
            log(Assignees + 1) + 
            log(ChangedFiles + 1) + 
            log(NumOfUniqueUsers + 1) +    
            log(PRsOpened + 1) +
            log(TotalBuilds + 1) +
            NewContributor + 
            #log(PrOpenedDaysAfterProjectStart + 1) +
            #FromOutsider + 
            IsAfter +
            (1|ProjectLanguage) +
            (1|ProjectName),
          data= hasGeneralCommentsAndFromOutsider,
          REML=FALSE)
summary(modelNumberGeneralCommentsOutsider)
r.squaredGLMM(modelNumberGeneralCommentsOutsider)
vif.mer(modelNumberGeneralCommentsOutsider)
anova(modelNumberGeneralCommentsOutsider)
# Out:
# Correlation matrix not shown by default, as p = 13 > 12.
# Use print(obj, correlation=TRUE)  or
# 	 vcov(obj)	 if you need it
# Linear mixed model fit by maximum likelihood t-tests use Satterthwaite
#   approximations to degrees of freedom [lmerMod]
# Formula: log(GeneralComments) ~ log(Additions + 1) + log(Deletions + 1) +
#     IsMerged + log(Commits + 1) + log(Assignees + 1) + log(ChangedFiles +
#     1) + log(NumOfUniqueUsers + 1) + log(PRsOpened + 1) + log(TotalBuilds +
#     1) + NewContributor + FromOutsider + IsAfter + (1 | ProjectLanguage) +
#     (1 | ProjectName)
#    Data: hasGeneralComments
#
#       AIC       BIC    logLik  deviance  df.resid
#  299093.9  299258.7 -149530.9  299061.9    219421
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.7692 -0.4813 -0.1368  0.4291  8.8417
#
# Random effects:
#  Groups          Name        Variance  Std.Dev.
#  ProjectName     (Intercept) 1.525e-02 0.123498
#  ProjectLanguage (Intercept) 4.941e-05 0.007029
#  Residual                    2.274e-01 0.476911
# Number of obs: 219437, groups:  ProjectName, 390; ProjectLanguage, 42
#
# Fixed effects:
#                             Estimate Std. Error         df  t value Pr(>|t|)
# (Intercept)               -1.202e+00  8.936e-03  1.900e+01 -134.486  < 2e-16
# log(Additions + 1)         7.303e-03  8.413e-04  2.193e+05    8.681  < 2e-16
# log(Deletions + 1)         3.235e-03  8.587e-04  2.193e+05    3.768 0.000165
# IsMergedTrue              -4.862e-02  2.483e-03  2.184e+05  -19.577  < 2e-16
# log(Commits + 1)           6.953e-02  1.850e-03  2.193e+05   37.573  < 2e-16
# log(Assignees + 1)         1.272e-01  6.139e-03  2.127e+05   20.726  < 2e-16
# log(ChangedFiles + 1)     -1.023e-03  1.899e-03  2.193e+05   -0.539 0.590129
# log(NumOfUniqueUsers + 1)  1.892e+00  2.958e-03  2.193e+05  639.582  < 2e-16
# log(PRsOpened + 1)        -6.543e-03  9.539e-04  2.155e+05   -6.860 6.90e-12
# log(TotalBuilds + 1)       2.390e-02  2.948e-03  2.194e+05    8.108 4.44e-16
# NewContributorTrue        -1.183e-02  3.530e-03  2.193e+05   -3.352 0.000801
# FromOutsiderTrue           2.394e-02  3.245e-03  2.161e+05    7.377 1.63e-13
# IsAfterTrue               -3.713e-02  3.312e-03  2.194e+05  -11.209  < 2e-16
#
# (Intercept)               ***
# log(Additions + 1)        ***
# log(Deletions + 1)        ***
# IsMergedTrue              ***
# log(Commits + 1)          ***
# log(Assignees + 1)        ***
# log(ChangedFiles + 1)
# log(NumOfUniqueUsers + 1) ***
# log(PRsOpened + 1)        ***
# log(TotalBuilds + 1)      ***
# NewContributorTrue        ***
# FromOutsiderTrue          ***
# IsAfterTrue               ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#       R2m       R2c
# 0.6973018 0.7163821
#        log(Additions + 1)        log(Deletions + 1)              IsMergedTrue
#                  3.069092                  2.490283                  1.069582
#          log(Commits + 1)        log(Assignees + 1)     log(ChangedFiles + 1)
#                  1.642450                  1.013489                  3.413063
# log(NumOfUniqueUsers + 1)        log(PRsOpened + 1)      log(TotalBuilds + 1)
#                  1.092442                  2.458950                  2.688495
#        NewContributorTrue          FromOutsiderTrue               IsAfterTrue
#                  1.576090                  1.630422                  2.577247
#                           Sum Sq       Mean Sq      NumDF DenDF    F.value
# log(Additions + 1)        1.713863e+01 1.713863e+01 1     219348.4 7.535329e+01
# log(Deletions + 1)        3.228755e+00 3.228755e+00 1     219321.3 1.419584e+01
# IsMerged                  8.716592e+01 8.716592e+01 1     218364.9 3.832417e+02
# log(Commits + 1)          3.210871e+02 3.210871e+02 1     219270.1 1.411721e+03
# log(Assignees + 1)        9.770057e+01 9.770057e+01 1     212674.3 4.295593e+02
# log(ChangedFiles + 1)     6.599152e-02 6.599152e-02 1     219260.2 2.901444e-01
# log(NumOfUniqueUsers + 1) 9.303919e+04 9.303919e+04 1     219341.8 4.090647e+05
# log(PRsOpened + 1)        1.070356e+01 1.070356e+01 1     215510.9 4.706024e+01
# log(TotalBuilds + 1)      1.495248e+01 1.495248e+01 1     219436.0 6.574144e+01
# NewContributor            2.556085e+00 2.556085e+00 1     219343.4 1.123832e+01
# FromOutsider              1.237765e+01 1.237765e+01 1     216082.2 5.442069e+01
# IsAfter                   2.857403e+01 2.857403e+01 1     219435.4 1.256312e+02
#                           Pr(>F)
# log(Additions + 1)        0.000000e+00
# log(Deletions + 1)        1.647771e-04
# IsMerged                  0.000000e+00
# log(Commits + 1)          0.000000e+00
# log(Assignees + 1)        0.000000e+00
# log(ChangedFiles + 1)     5.901286e-01
# log(NumOfUniqueUsers + 1) 0.000000e+00
# log(PRsOpened + 1)        6.902257e-12
# log(TotalBuilds + 1)      4.440892e-16
# NewContributor            8.013925e-04
# FromOutsider              1.625367e-13
# IsAfter                   0.000000e+00
# [1] "---------------------------"
# Linear mixed model fit by maximum likelihood t-tests use Satterthwaite
#   approximations to degrees of freedom [lmerMod]
# Formula: log(GeneralComments) ~ log(Additions + 1) + log(Deletions + 1) +
#     log(Commits + 1) + log(Assignees + 1) + log(ChangedFiles +
#     1) + log(NumOfUniqueUsers + 1) + log(PRsOpened + 1) + log(TotalBuilds +
#     1) + NewContributor + IsAfter + (1 | ProjectLanguage) + (1 |
#     ProjectName)
#    Data: hasGeneralCommentsAndFromOutsider
#
#      AIC      BIC   logLik deviance df.resid
# 189385.7 189523.9 -94678.8 189357.7   143054
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -6.0620 -0.4843 -0.1673  0.4290  9.1559
#
# Random effects:
#  Groups          Name        Variance  Std.Dev.
#  ProjectName     (Intercept) 0.0139455 0.118091
#  ProjectLanguage (Intercept) 0.0000276 0.005254
#  Residual                    0.2182535 0.467176
# Number of obs: 143068, groups:  ProjectName, 390; ProjectLanguage, 42
#
# Fixed effects:
#                             Estimate Std. Error         df  t value Pr(>|t|)
# (Intercept)               -1.249e+00  8.121e-03  2.000e+01 -153.781  < 2e-16
# log(Additions + 1)         1.203e-02  1.063e-03  1.430e+05   11.321  < 2e-16
# log(Deletions + 1)         2.024e-03  1.108e-03  1.430e+05    1.827 0.067706
# log(Commits + 1)           6.989e-02  2.215e-03  1.429e+05   31.555  < 2e-16
# log(Assignees + 1)         1.282e-01  8.227e-03  1.365e+05   15.583  < 2e-16
# log(ChangedFiles + 1)     -8.729e-03  2.481e-03  1.429e+05   -3.519 0.000434
# log(NumOfUniqueUsers + 1)  1.931e+00  3.490e-03  1.430e+05  553.292  < 2e-16
# log(PRsOpened + 1)        -7.476e-03  1.172e-03  1.401e+05   -6.379 1.79e-10
# log(TotalBuilds + 1)       1.731e-02  3.656e-03  1.431e+05    4.735 2.19e-06
# NewContributorTrue        -1.211e-02  3.798e-03  1.430e+05   -3.190 0.001424
# IsAfterTrue               -2.986e-02  4.015e-03  1.431e+05   -7.436 1.04e-13
#
# (Intercept)               ***
# log(Additions + 1)        ***
# log(Deletions + 1)        .
# log(Commits + 1)          ***
# log(Assignees + 1)        ***
# log(ChangedFiles + 1)     ***
# log(NumOfUniqueUsers + 1) ***
# log(PRsOpened + 1)        ***
# log(TotalBuilds + 1)      ***
# NewContributorTrue        **
# IsAfterTrue               ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) lg(Ad+1) l(D+1) l(C+1) lg(As+1) l(CF+1 l(NO+1 l(PR+1 l(TB+1
# lg(Addtn+1) -0.004
# lg(Dltns+1)  0.016 -0.282
# lg(Cmmts+1) -0.208 -0.065   -0.065
# lg(Assgn+1)  0.011 -0.025    0.000 -0.007
# lg(ChngF+1) -0.014 -0.578   -0.374 -0.143  0.014
# lg(NmOUU+1) -0.396 -0.127    0.037 -0.107 -0.073    0.043
# lg(PRsOp+1) -0.309  0.001   -0.064  0.067 -0.021   -0.018  0.029
# lg(TtlBl+1)  0.148 -0.001    0.008 -0.421  0.002    0.003 -0.054  0.008
# NwCntrbtrTr -0.296  0.025    0.001  0.031 -0.001   -0.018  0.000  0.636 -0.010
# IsAfterTrue -0.159  0.015   -0.001  0.364 -0.046   -0.037 -0.030 -0.093 -0.767
#             NwCntT
# lg(Addtn+1)
# lg(Dltns+1)
# lg(Cmmts+1)
# lg(Assgn+1)
# lg(ChngF+1)
# lg(NmOUU+1)
# lg(PRsOp+1)
# lg(TtlBl+1)
# NwCntrbtrTr
# IsAfterTrue -0.030
#       R2m       R2c
# 0.7227737 0.7394545
#        log(Additions + 1)        log(Deletions + 1)          log(Commits + 1)
#                  3.271804                  2.433763                  1.564243
#        log(Assignees + 1)     log(ChangedFiles + 1) log(NumOfUniqueUsers + 1)
#                  1.015155                  3.543019                  1.083010
#        log(PRsOpened + 1)      log(TotalBuilds + 1)        NewContributorTrue
#                  1.756446                  2.737035                  1.703479
#               IsAfterTrue
#                  2.540241
#                           Sum Sq       Mean Sq      NumDF DenDF    F.value
# log(Additions + 1)           27.974823    27.974823 1     143006.0    128.17583
# log(Deletions + 1)            0.728491     0.728491 1     142988.4      3.33782
# log(Commits + 1)            217.314919   217.314919 1     142855.6    995.69959
# log(Assignees + 1)           52.995222    52.995222 1     136534.7    242.81500
# log(ChangedFiles + 1)         2.701968     2.701968 1     142925.9     12.37995
# log(NumOfUniqueUsers + 1) 66814.442229 66814.442229 1     142979.7 306132.28514
# log(PRsOpened + 1)            8.881650     8.881650 1     140120.1     40.69419
# log(TotalBuilds + 1)          4.893844     4.893844 1     143066.7     22.42275
# NewContributor                2.220805     2.220805 1     143010.5     10.17535
# IsAfter                      12.069133    12.069133 1     143066.1     55.29869
#                           Pr(>F)
# log(Additions + 1)        0.000000e+00
# log(Deletions + 1)        6.770632e-02
# log(Commits + 1)          0.000000e+00
# log(Assignees + 1)        0.000000e+00
# log(ChangedFiles + 1)     4.341028e-04
# log(NumOfUniqueUsers + 1) 0.000000e+00
# log(PRsOpened + 1)        1.785678e-10
# log(TotalBuilds + 1)      2.189763e-06
# NewContributor            1.423617e-03
# IsAfter                   1.041389e-13

# %%
modelShareReviewComments = lmer(log(ShareReviewComments + 1) ~ 
            log(Additions + 1) +
            log(Deletions + 1) +
            IsMerged +
            log(Commits + 1) +
            log(Assignees + 1) + 
            log(ChangedFiles + 1) +             
            log(NumOfUniqueUsers + 1) +    
            log(PRsOpened + 1) +
            log(TotalBuilds + 1) +
            NewContributor + 
            FromOutsider +
            IsAfter + 
            (1|ProjectLanguage) +
            (1|ProjectName),
          data= NumOfReviewCommentsData, 
          REML=FALSE)
summary(modelShareReviewComments)
r.squaredGLMM(modelShareReviewComments)
vif.mer(modelShareReviewComments)
anova(modelShareReviewComments)

print("---------------------------")

modelShareReviewCommentsOutsider = lmer(log(ShareReviewComments + 1) ~ 
            log(Additions + 1) +
            log(Deletions + 1) +
            #IsMerged +
            log(Commits + 1) +
            log(Assignees + 1) + 
            log(ChangedFiles + 1) + 
            log(NumOfUniqueUsers + 1) +    
            log(PRsOpened + 1) +
            log(TotalBuilds + 1) +
            NewContributor + 
            #log(PrOpenedDaysAfterProjectStart + 1) +
            #FromOutsider + 
            IsAfter +
            (1|ProjectLanguage) +
            (1|ProjectName),
          data= hasReviewCommentsAndFromOutsider,
          REML=FALSE)
summary(modelShareReviewCommentsOutsider)
r.squaredGLMM(modelShareReviewCommentsOutsider)
vif.mer(modelShareReviewCommentsOutsider)
anova(modelShareReviewCommentsOutsider)
# Out:
# Correlation matrix not shown by default, as p = 13 > 12.
# Use print(obj, correlation=TRUE)  or
# 	 vcov(obj)	 if you need it
# Linear mixed model fit by maximum likelihood t-tests use Satterthwaite
#   approximations to degrees of freedom [lmerMod]
# Formula: log(ShareReviewComments + 1) ~ log(Additions + 1) + log(Deletions +
#     1) + IsMerged + log(Commits + 1) + log(Assignees + 1) + log(ChangedFiles +
#     1) + log(NumOfUniqueUsers + 1) + log(PRsOpened + 1) + log(TotalBuilds +
#     1) + NewContributor + FromOutsider + IsAfter + (1 | ProjectLanguage) +
#     (1 | ProjectName)
#    Data: NumOfReviewCommentsData
#
#       AIC       BIC    logLik  deviance  df.resid
#  732044.3  732208.8 -366006.1  732012.3    215434
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.5813 -0.6857 -0.1697  0.3587  3.8576
#
# Random effects:
#  Groups          Name        Variance Std.Dev.
#  ProjectName     (Intercept) 0.114964 0.33906
#  ProjectLanguage (Intercept) 0.001188 0.03447
#  Residual                    1.744308 1.32072
# Number of obs: 215450, groups:  ProjectName, 180; ProjectLanguage, 33
#
# Fixed effects:
#                             Estimate Std. Error         df t value Pr(>|t|)
# (Intercept)               -9.517e-01  3.143e-02  1.600e+01 -30.275 8.88e-16 ***
# log(Additions + 1)         1.418e-01  2.371e-03  2.154e+05  59.818  < 2e-16 ***
# log(Deletions + 1)        -1.618e-02  2.416e-03  2.154e+05  -6.695 2.16e-11 ***
# IsMergedTrue               3.683e-01  7.560e-03  2.154e+05  48.713  < 2e-16 ***
# log(Commits + 1)           2.319e-01  5.255e-03  2.154e+05  44.121  < 2e-16 ***
# log(Assignees + 1)         2.352e-01  1.868e-02  2.090e+05  12.592  < 2e-16 ***
# log(ChangedFiles + 1)     -1.605e-01  5.244e-03  2.154e+05 -30.597  < 2e-16 ***
# log(NumOfUniqueUsers + 1)  1.127e+00  5.474e-03  2.150e+05 205.906  < 2e-16 ***
# log(PRsOpened + 1)        -1.714e-03  2.544e-03  2.144e+05  -0.674  0.50052
# log(TotalBuilds + 1)       1.347e-01  8.286e-03  2.154e+05  16.252  < 2e-16 ***
# NewContributorTrue        -1.219e-01  1.078e-02  2.154e+05 -11.301  < 2e-16 ***
# FromOutsiderTrue           2.379e-02  8.603e-03  2.144e+05   2.765  0.00569 **
# IsAfterTrue                4.193e-02  9.193e-03  2.154e+05   4.561 5.11e-06 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#       R2m       R2c
# 0.2623652 0.3084171
#        log(Additions + 1)        log(Deletions + 1)              IsMergedTrue
#                  3.149738                  2.588771                  1.089248
#          log(Commits + 1)        log(Assignees + 1)     log(ChangedFiles + 1)
#                  1.716832                  1.014401                  3.431867
# log(NumOfUniqueUsers + 1)        log(PRsOpened + 1)      log(TotalBuilds + 1)
#                  1.126782                  2.348013                  2.742582
#        NewContributorTrue          FromOutsiderTrue               IsAfterTrue
#                  1.497135                  1.613538                  2.609775
#                           Sum Sq       Mean Sq      NumDF DenDF    F.value
# log(Additions + 1)        6.241479e+03 6.241479e+03 1     215434.3 3.578198e+03
# log(Deletions + 1)        7.819538e+01 7.819538e+01 1     215396.5 4.482889e+01
# IsMerged                  4.139119e+03 4.139119e+03 1     215424.0 2.372929e+03
# log(Commits + 1)          3.395634e+03 3.395634e+03 1     215444.4 1.946694e+03
# log(Assignees + 1)        2.765964e+02 2.765964e+02 1     208981.5 1.585709e+02
# log(ChangedFiles + 1)     1.633009e+03 1.633009e+03 1     215433.8 9.361930e+02
# log(NumOfUniqueUsers + 1) 7.395363e+04 7.395363e+04 1     214974.7 4.239712e+04
# log(PRsOpened + 1)        7.916288e-01 7.916288e-01 1     214351.4 4.538355e-01
# log(TotalBuilds + 1)      4.607265e+02 4.607265e+02 1     215430.3 2.641314e+02
# NewContributor            2.227642e+02 2.227642e+02 1     215445.3 1.277092e+02
# FromOutsider              1.333931e+01 1.333931e+01 1     214356.9 7.647336e+00
# IsAfter                   3.627872e+01 3.627872e+01 1     215410.8 2.079835e+01
#                           Pr(>F)
# log(Additions + 1)        0.000000e+00
# log(Deletions + 1)        2.155520e-11
# IsMerged                  0.000000e+00
# log(Commits + 1)          0.000000e+00
# log(Assignees + 1)        0.000000e+00
# log(ChangedFiles + 1)     0.000000e+00
# log(NumOfUniqueUsers + 1) 0.000000e+00
# log(PRsOpened + 1)        5.005199e-01
# log(TotalBuilds + 1)      0.000000e+00
# NewContributor            0.000000e+00
# FromOutsider              5.686110e-03
# IsAfter                   5.105505e-06
# [1] "---------------------------"
# Linear mixed model fit by maximum likelihood t-tests use Satterthwaite
#   approximations to degrees of freedom [lmerMod]
# Formula: log(ShareReviewComments + 1) ~ log(Additions + 1) + log(Deletions +
#     1) + log(Commits + 1) + log(Assignees + 1) + log(ChangedFiles +
#     1) + log(NumOfUniqueUsers + 1) + log(PRsOpened + 1) + log(TotalBuilds +
#     1) + NewContributor + IsAfter + (1 | ProjectLanguage) + (1 |
#     ProjectName)
#    Data: hasReviewCommentsAndFromOutsider
#
#      AIC      BIC   logLik deviance df.resid
#  40615.7  40728.5 -20293.9  40587.7    23237
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.5711 -0.5925  0.1944  0.7373  2.8794
#
# Random effects:
#  Groups          Name        Variance Std.Dev.
#  ProjectName     (Intercept) 0.02936  0.1714
#  ProjectLanguage (Intercept) 0.00000  0.0000
#  Residual                    0.33031  0.5747
# Number of obs: 23251, groups:  ProjectName, 180; ProjectLanguage, 33
#
# Fixed effects:
#                             Estimate Std. Error         df t value Pr(>|t|)
# (Intercept)                4.456e+00  2.338e-02  1.216e+03 190.624  < 2e-16 ***
# log(Additions + 1)         2.997e-02  3.183e-03  2.325e+04   9.417  < 2e-16 ***
# log(Deletions + 1)        -1.342e-03  3.016e-03  2.323e+04  -0.445 0.656330
# log(Commits + 1)           3.761e-02  6.291e-03  2.323e+04   5.979 2.28e-09 ***
# log(Assignees + 1)        -8.677e-02  2.211e-02  2.170e+04  -3.925 8.70e-05 ***
# log(ChangedFiles + 1)     -2.867e-02  7.328e-03  2.325e+04  -3.913 9.14e-05 ***
# log(NumOfUniqueUsers + 1) -6.187e-01  1.135e-02  2.277e+04 -54.516  < 2e-16 ***
# log(PRsOpened + 1)         2.064e-02  3.317e-03  2.309e+04   6.221 5.01e-10 ***
# log(TotalBuilds + 1)       6.418e-03  9.221e-03  2.322e+04   0.696 0.486390
# NewContributorTrue        -1.720e-02  1.273e-02  2.324e+04  -1.351 0.176773
# IsAfterTrue                4.757e-02  1.294e-02  2.324e+04   3.678 0.000236 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) lg(Ad+1) l(D+1) l(C+1) lg(As+1) l(CF+1 l(NO+1 l(PR+1 l(TB+1
# lg(Addtn+1) -0.069
# lg(Dltns+1)  0.021 -0.248
# lg(Cmmts+1) -0.262 -0.055   -0.060
# lg(Assgn+1)  0.007 -0.018    0.006 -0.012
# lg(ChngF+1)  0.036 -0.622   -0.355 -0.118  0.010
# lg(NmOUU+1) -0.556 -0.079    0.032 -0.119 -0.067   -0.013
# lg(PRsOp+1) -0.348  0.015   -0.067  0.049 -0.014   -0.030  0.055
# lg(TtlBl+1)  0.198  0.002    0.039 -0.495  0.004    0.010 -0.032  0.010
# NwCntrbtrTr -0.289  0.035    0.011  0.015 -0.007   -0.018 -0.008  0.606 -0.010
# IsAfterTrue -0.240 -0.001   -0.027  0.435 -0.043   -0.028 -0.040 -0.061 -0.781
#             NwCntT
# lg(Addtn+1)
# lg(Dltns+1)
# lg(Cmmts+1)
# lg(Assgn+1)
# lg(ChngF+1)
# lg(NmOUU+1)
# lg(PRsOp+1)
# lg(TtlBl+1)
# NwCntrbtrTr
# IsAfterTrue -0.014
#       R2m       R2c
# 0.1442879 0.2141455
#        log(Additions + 1)        log(Deletions + 1)          log(Commits + 1)
#                  3.250639                  2.204962                  1.600176
#        log(Assignees + 1)     log(ChangedFiles + 1) log(NumOfUniqueUsers + 1)
#                  1.011266                  3.538512                  1.082643
#        log(PRsOpened + 1)      log(TotalBuilds + 1)        NewContributorTrue
#                  1.649844                  2.891188                  1.615011
#               IsAfterTrue
#                  2.640306
#                           Sum Sq       Mean Sq      NumDF DenDF    F.value
# log(Additions + 1)         29.28928565  29.28928565 1     23247.96   88.6719385
# log(Deletions + 1)          0.06540722   0.06540722 1     23226.35    0.1980173
# log(Commits + 1)           11.80634012  11.80634012 1     23227.20   35.7431409
# log(Assignees + 1)          5.08837456   5.08837456 1     21696.19   15.4048153
# log(ChangedFiles + 1)       5.05766343   5.05766343 1     23249.35   15.3118388
# log(NumOfUniqueUsers + 1) 981.67127259 981.67127259 1     22769.94 2971.9637321
# log(PRsOpened + 1)         12.78507641  12.78507641 1     23088.92   38.7062191
# log(TotalBuilds + 1)        0.16004122   0.16004122 1     23223.39    0.4845173
# NewContributor              0.60270384   0.60270384 1     23235.19    1.8246576
# IsAfter                     4.46807717   4.46807717 1     23235.81   13.5268941
#                           Pr(>F)
# log(Additions + 1)        0.000000e+00
# log(Deletions + 1)        6.563302e-01
# log(Commits + 1)          2.284105e-09
# log(Assignees + 1)        8.703461e-05
# log(ChangedFiles + 1)     9.140293e-05
# log(NumOfUniqueUsers + 1) 0.000000e+00
# log(PRsOpened + 1)        5.010996e-10
# log(TotalBuilds + 1)      4.863902e-01
# NewContributor            1.767730e-01
# IsAfter                   2.356992e-04

# %% [markdown]
# modelBuildDiscussionComments = lmer(log(GeneralCommentsDiscussingBuild + 1) ~
#             log(Additions + 1) +
#             log(Deletions + 1) +
#             IsMerged +
#             log(Commits + 1) +
#             log(Assignees + 1) +
#             log(ChangedFiles + 1) +
#             log(PrOpenedDaysAfterProjectStart + 1) +
#             IsAfter +
#             (1|ProjectLanguage) +
#             (1|ProjectName),
#           data= hasGeneralComments,
#           REML=FALSE)
# summary(modelBuildDiscussionComments)
# r.squaredGLMM(modelBuildDiscussionComments)
# vif.mer(modelBuildDiscussionComments)
# anova(modelBuildDiscussionComments)

# %%
library(lme4)

print(sprintf("R2c of review comments is %f", r.squaredGLMM(modelNumberReviewComments)[['R2c']]))
print(sprintf("R2c of share review comments is %f", r.squaredGLMM(modelShareReviewComments)[['R2c']]))
print(sprintf("R2c of general comments is %f", r.squaredGLMM(modelNumberGeneralComments)[['R2c']]))
# Out:
# [1] "R2c of review comments is 0.342312"
# [1] "R2c of share review comments is 0.308417"
# [1] "R2c of general comments is 0.717337"

# %% [markdown]
# # Using effective comments to make predictions

# %%
projectNames <- sqldf("select distinct(ProjectName) as ProjectName
                    from hasEffectiveComments")$ProjectName


result <- data.frame(Name = '', Actual = 0, Predicted = 0)[0,]

for(project in projectNames) {
    projectData <- sqldf(sprintf("select * from hasEffectiveComments
                            where ProjectName = '%s'", project))
    

    
    medianRow <- data.frame(Additions = median(projectData$Additions),
                           Deletions = median(projectData$Deletions),
                           IsMerged = 'True',
                           Commits = median(projectData$Commits),
                           Assignees = median(projectData$Assignees),
                           #ChangedFiles = median(projectData$ChangedFiles),
                           NumOfUniqueUsers = median(projectData$NumOfUniqueUsers),
                           PRsOpened = median(projectData$PRsOpened),
                           TotalBuilds = median(projectData$TotalBuilds),
                           NewContributor = 'False',
                           FromOutsider = 'False',
                           ReviewComments = median(projectData$ReviewComments),
                           GeneralComments = median(projectData$GeneralComments),
                           IsAfter = 'True')[1,]
    
       
    
    predicted <- predict(modelNumberEffectiveComments, medianRow)
    
    result<-rbind(result, data.frame(Name = project, Actual = median(projectData$EffectiveComments), Predicted = predicted))
}

# %%
summary(result)

head(result)

sorted <- result[order(abs(result$Actual - result$Predicted)),]

head(sorted)

tail(sorted)
# Out:
#                           Name         Actual        Predicted
#  Leaflet/Leaflet            :  1   Min.   :1.000   Min.   :-0.1797
#  MarkUsProject/Markus       :  1   1st Qu.:1.000   1st Qu.: 0.5275
#  MightyPirates/OpenComputers:  1   Median :2.000   Median : 0.7478
#  NancyFx/Nancy              :  1   Mean   :1.938   Mean   : 0.7269
#  OP2/PyOP2                  :  1   3rd Qu.:2.000   3rd Qu.: 0.9221
#  OPM/opm-core               :  1   Max.   :6.000   Max.   : 1.5877
#  (Other)                    :236
#    Name                        Actual Predicted
# 1  Leaflet/Leaflet             1      0.2811769
# 11 MarkUsProject/Markus        2      0.9227097
# 12 MightyPirates/OpenComputers 2      0.9074532
# 13 NancyFx/Nancy               2      0.8333288
# 14 OP2/PyOP2                   3      1.2019746
# 15 OPM/opm-core                2      0.9335412
#      Name                   Actual Predicted
# 1207 melpa/melpa            1      1.0181165
# 123  ImageEngine/cortex     1      1.0362102
# 1113 mozilla/shumway        1      0.9574169
# 1209 madrobby/zepto         1      0.9222987
# 146  Zarel/Pokemon-Showdown 1      0.9146175
# 1102 geotools/geotools      1      0.9131079
#      Name                           Actual Predicted
# 1178 rapid7/metasploit-framework    4.0    1.0794994
# 1216 h5bp/html5-boilerplate         4.5    0.8851724
# 1212 statsmodels/statsmodels        5.0    1.3349541
# 1223 activemerchant/active_merchant 5.0    1.0116392
# 153  bem/bem-components             5.0    0.8692513
# 138  MariaDB/server                 6.0    0.8977185

# %% [markdown]
# # Finding individual projects which are impacted by Travis

# %%
#summary(NumOfReviewCommentsData)

projectNames <- sqldf("select ProjectName, count(ProjectName) 
                    from NumOfReviewCommentsData
                    group by ProjectName 
                    having Count(ProjectName) > 200")$ProjectName

for(project in projectNames) {
    formula <- log(ReviewComments) ~ 
            log(Additions + 1) +
            log(Deletions + 1) +
            IsMerged +
            log(Commits + 1) +
            log(Assignees + 1) + 
            log(ChangedFiles + 1) + 
            log(NumOfUniqueUsers + 1) +    
            log(PRsOpened + 1) +
            log(TotalBuilds + 1) +
            NewContributor + 
            FromOutsider + 
            IsAfter
    
    data <- sqldf(sprintf("select * from NumOfReviewCommentsData
                    where ProjectName ='%s'
                        and ReviewComments > 1", project))
    
    data$IsMerged <- factor(data$IsMerged)
    data$NewContributor <- factor(data$NewContributor)
    data$FromOutsider <- factor(data$FromOutsider)
    data$IsAfter <- factor(data$IsAfter)
    
    #Skip running an analysis if there is not enough data
    if(nlevels(data$IsMerged) > 1 &
      nlevels(data$NewContributor) > 1 &
      nlevels(data$FromOutsider) > 1 &
      nlevels(data$IsAfter) > 1)
    {
        model_per_project <- lm(formula, data=data)
        
        pOfIsAfter <- tail(summary(model_per_project)$coefficients)[,4]   ##P-values 
        rsq <- summary(model_per_project)$r.squared   
        
        #print(summary(model_per_project))
        
        print(sprintf("Name: %s pval: %f rsq: %f", project, pOfIsAfter, rsq))
    }
    
}
# Out:
# [1] "Name: AFNetworking/AFNetworking pval: 0.136075 rsq: 0.947911"
# [2] "Name: AFNetworking/AFNetworking pval: 0.147730 rsq: 0.947911"
# [3] "Name: AFNetworking/AFNetworking pval: 0.719298 rsq: 0.947911"
# [4] "Name: AFNetworking/AFNetworking pval: 0.094202 rsq: 0.947911"
# [5] "Name: AFNetworking/AFNetworking pval: 0.158648 rsq: 0.947911"
# [6] "Name: AFNetworking/AFNetworking pval: 0.160747 rsq: 0.947911"
# [1] "Name: AnalyticalGraphicsInc/cesium pval: 0.000001 rsq: 0.508137"
# [2] "Name: AnalyticalGraphicsInc/cesium pval: 0.058781 rsq: 0.508137"
# [3] "Name: AnalyticalGraphicsInc/cesium pval: 0.298592 rsq: 0.508137"
# [4] "Name: AnalyticalGraphicsInc/cesium pval: 0.463259 rsq: 0.508137"
# [5] "Name: AnalyticalGraphicsInc/cesium pval: 0.000007 rsq: 0.508137"
# [6] "Name: AnalyticalGraphicsInc/cesium pval: 0.525550 rsq: 0.508137"
# [1] "Name: Automattic/_s pval: 0.240493 rsq: 0.582836"
# [2] "Name: Automattic/_s pval: 0.542499 rsq: 0.582836"
# [3] "Name: Automattic/_s pval: 0.004741 rsq: 0.582836"
# [4] "Name: Automattic/_s pval: 0.558066 rsq: 0.582836"
# [5] "Name: Automattic/_s pval: 0.975983 rsq: 0.582836"
# [6] "Name: Automattic/_s pval: 0.007217 rsq: 0.582836"
# [1] "Name: Azure/azure-sdk-for-node pval: 0.892294 rsq: 0.501226"
# [2] "Name: Azure/azure-sdk-for-node pval: 0.960048 rsq: 0.501226"
# [3] "Name: Azure/azure-sdk-for-node pval: 0.089727 rsq: 0.501226"
# [4] "Name: Azure/azure-sdk-for-node pval: 0.524778 rsq: 0.501226"
# [5] "Name: Azure/azure-sdk-for-node pval: 0.415424 rsq: 0.501226"
# [6] "Name: Azure/azure-sdk-for-node pval: 0.053526 rsq: 0.501226"
# [1] "Name: Azure/azure-xplat-cli pval: 0.033556 rsq: 0.699260"
# [2] "Name: Azure/azure-xplat-cli pval: 0.087129 rsq: 0.699260"
# [3] "Name: Azure/azure-xplat-cli pval: 0.021564 rsq: 0.699260"
# [4] "Name: Azure/azure-xplat-cli pval: 0.067491 rsq: 0.699260"
# [5] "Name: Azure/azure-xplat-cli pval: 0.122854 rsq: 0.699260"
# [6] "Name: Azure/azure-xplat-cli pval: 0.014822 rsq: 0.699260"
# [1] "Name: Baystation12/Baystation12 pval: 0.000000 rsq: 0.233675"
# [2] "Name: Baystation12/Baystation12 pval: 0.724301 rsq: 0.233675"
# [3] "Name: Baystation12/Baystation12 pval: 0.043282 rsq: 0.233675"
# [4] "Name: Baystation12/Baystation12 pval: 0.016017 rsq: 0.233675"
# [5] "Name: Baystation12/Baystation12 pval: 0.213625 rsq: 0.233675"
# [6] "Name: Baystation12/Baystation12 pval: 0.570602 rsq: 0.233675"
# [1] "Name: BuildCraft/BuildCraft pval: 0.203480 rsq: 0.433287"
# [2] "Name: BuildCraft/BuildCraft pval: 0.067188 rsq: 0.433287"
# [3] "Name: BuildCraft/BuildCraft pval: 0.165070 rsq: 0.433287"
# [4] "Name: BuildCraft/BuildCraft pval: 0.865699 rsq: 0.433287"
# [5] "Name: BuildCraft/BuildCraft pval: 0.925952 rsq: 0.433287"
# [6] "Name: BuildCraft/BuildCraft pval: 0.052774 rsq: 0.433287"
# [1] "Name: ClusterLabs/pacemaker pval: 0.119415 rsq: 0.248306"
# [2] "Name: ClusterLabs/pacemaker pval: 0.916842 rsq: 0.248306"
# [3] "Name: ClusterLabs/pacemaker pval: 0.569528 rsq: 0.248306"
# [4] "Name: ClusterLabs/pacemaker pval: 0.447185 rsq: 0.248306"
# [5] "Name: ClusterLabs/pacemaker pval: 0.344750 rsq: 0.248306"
# [6] "Name: ClusterLabs/pacemaker pval: 0.182438 rsq: 0.248306"
# [1] "Name: ClusterLabs/resource-agents pval: 0.085673 rsq: 0.381370"
# [2] "Name: ClusterLabs/resource-agents pval: 0.965751 rsq: 0.381370"
# [3] "Name: ClusterLabs/resource-agents pval: 0.819727 rsq: 0.381370"
# [4] "Name: ClusterLabs/resource-agents pval: 0.693977 rsq: 0.381370"
# [5] "Name: ClusterLabs/resource-agents pval: 0.427809 rsq: 0.381370"
# [6] "Name: ClusterLabs/resource-agents pval: 0.863628 rsq: 0.381370"
# [1] "Name: DGtal-team/DGtal pval: 0.017753 rsq: 0.578705"
# [2] "Name: DGtal-team/DGtal pval: 0.610402 rsq: 0.578705"
# [3] "Name: DGtal-team/DGtal pval: 0.202724 rsq: 0.578705"
# [4] "Name: DGtal-team/DGtal pval: 0.505128 rsq: 0.578705"
# [5] "Name: DGtal-team/DGtal pval: 0.884740 rsq: 0.578705"
# [6] "Name: DGtal-team/DGtal pval: 0.809694 rsq: 0.578705"
# [1] "Name: DarkstarProject/darkstar pval: 0.000000 rsq: 0.201862"
# [2] "Name: DarkstarProject/darkstar pval: 0.253962 rsq: 0.201862"
# [3] "Name: DarkstarProject/darkstar pval: 0.130440 rsq: 0.201862"
# [4] "Name: DarkstarProject/darkstar pval: 0.645341 rsq: 0.201862"
# [5] "Name: DarkstarProject/darkstar pval: 0.927162 rsq: 0.201862"
# [6] "Name: DarkstarProject/darkstar pval: 0.677586 rsq: 0.201862"
# [1] "Name: Dolibarr/dolibarr pval: 0.462475 rsq: 0.325128"
# [2] "Name: Dolibarr/dolibarr pval: 0.338104 rsq: 0.325128"
# [3] "Name: Dolibarr/dolibarr pval: 0.068366 rsq: 0.325128"
# [4] "Name: Dolibarr/dolibarr pval: 0.236642 rsq: 0.325128"
# [5] "Name: Dolibarr/dolibarr pval: 0.083873 rsq: 0.325128"
# [6] "Name: Dolibarr/dolibarr pval: 0.166039 rsq: 0.325128"
# [1] "Name: DynamoDS/Dynamo pval: 0.000000 rsq: 0.296651"
# [2] "Name: DynamoDS/Dynamo pval: 0.012069 rsq: 0.296651"
# [3] "Name: DynamoDS/Dynamo pval: 0.038871 rsq: 0.296651"
# [4] "Name: DynamoDS/Dynamo pval: 0.055970 rsq: 0.296651"
# [5] "Name: DynamoDS/Dynamo pval: 0.347855 rsq: 0.296651"
# [6] "Name: DynamoDS/Dynamo pval: 0.180277 rsq: 0.296651"
# [1] "Name: EFForg/https-everywhere pval: 0.121786 rsq: 0.267702"
# [2] "Name: EFForg/https-everywhere pval: 0.333141 rsq: 0.267702"
# [3] "Name: EFForg/https-everywhere pval: 0.615387 rsq: 0.267702"
# [4] "Name: EFForg/https-everywhere pval: 0.534133 rsq: 0.267702"
# [5] "Name: EFForg/https-everywhere pval: 0.179026 rsq: 0.267702"
# [6] "Name: EFForg/https-everywhere pval: 0.504629 rsq: 0.267702"
# [1] "Name: GeoNode/geonode pval: 0.036648 rsq: 0.800275"
# [2] "Name: GeoNode/geonode pval: 0.699571 rsq: 0.800275"
# [3] "Name: GeoNode/geonode pval: 0.276043 rsq: 0.800275"
# [4] "Name: GeoNode/geonode pval: 0.776014 rsq: 0.800275"
# [5] "Name: GeoNode/geonode pval: 0.568271 rsq: 0.800275"
# [6] "Name: GeoNode/geonode pval: 0.806547 rsq: 0.800275"
# [1] "Name: ImageEngine/cortex pval: 0.026277 rsq: 0.423033"
# [2] "Name: ImageEngine/cortex pval: 0.256067 rsq: 0.423033"
# [3] "Name: ImageEngine/cortex pval: 0.162122 rsq: 0.423033"
# [4] "Name: ImageEngine/cortex pval: 0.047521 rsq: 0.423033"
# [5] "Name: ImageEngine/cortex pval: 0.732822 rsq: 0.423033"
# [6] "Name: ImageEngine/cortex pval: 0.989335 rsq: 0.423033"
# [1] "Name: JuliaLang/julia pval: 0.000040 rsq: 0.379011"
# [2] "Name: JuliaLang/julia pval: 0.322937 rsq: 0.379011"
# [3] "Name: JuliaLang/julia pval: 0.255484 rsq: 0.379011"
# [4] "Name: JuliaLang/julia pval: 0.321649 rsq: 0.379011"
# [5] "Name: JuliaLang/julia pval: 0.174423 rsq: 0.379011"
# [6] "Name: JuliaLang/julia pval: 0.090836 rsq: 0.379011"
# [1] "Name: KSP-KOS/KOS pval: 0.173206 rsq: 0.348498"
# [2] "Name: KSP-KOS/KOS pval: 0.449276 rsq: 0.348498"
# [3] "Name: KSP-KOS/KOS pval: 0.172381 rsq: 0.348498"
# [4] "Name: KSP-KOS/KOS pval: 0.374095 rsq: 0.348498"
# [5] "Name: KSP-KOS/KOS pval: 0.090715 rsq: 0.348498"
# [6] "Name: KSP-KOS/KOS pval: 0.039018 rsq: 0.348498"
# [1] "Name: Leaflet/Leaflet pval: 0.080123 rsq: 0.290543"
# [2] "Name: Leaflet/Leaflet pval: 0.558652 rsq: 0.290543"
# [3] "Name: Leaflet/Leaflet pval: 0.518373 rsq: 0.290543"
# [4] "Name: Leaflet/Leaflet pval: 0.627955 rsq: 0.290543"
# [5] "Name: Leaflet/Leaflet pval: 0.511724 rsq: 0.290543"
# [6] "Name: Leaflet/Leaflet pval: 0.564849 rsq: 0.290543"
# [1] "Name: MarkUsProject/Markus pval: 0.000000 rsq: 0.242178"
# [2] "Name: MarkUsProject/Markus pval: 0.596078 rsq: 0.242178"
# [3] "Name: MarkUsProject/Markus pval: 0.004149 rsq: 0.242178"
# [4] "Name: MarkUsProject/Markus pval: 0.156827 rsq: 0.242178"
# [5] "Name: MarkUsProject/Markus pval: 0.938210 rsq: 0.242178"
# [6] "Name: MarkUsProject/Markus pval: 0.147884 rsq: 0.242178"
# [1] "Name: NancyFx/Nancy pval: 0.001344 rsq: 0.194332"
# [2] "Name: NancyFx/Nancy pval: 0.270173 rsq: 0.194332"
# [3] "Name: NancyFx/Nancy pval: 0.589083 rsq: 0.194332"
# [4] "Name: NancyFx/Nancy pval: 0.308505 rsq: 0.194332"
# [5] "Name: NancyFx/Nancy pval: 0.642317 rsq: 0.194332"
# [6] "Name: NancyFx/Nancy pval: 0.866538 rsq: 0.194332"
# [1] "Name: OP2/PyOP2 pval: 0.002592 rsq: 0.559707"
# [2] "Name: OP2/PyOP2 pval: 0.226342 rsq: 0.559707"
# [3] "Name: OP2/PyOP2 pval: 0.243169 rsq: 0.559707"
# [4] "Name: OP2/PyOP2 pval: 0.797181 rsq: 0.559707"
# [5] "Name: OP2/PyOP2 pval: 0.176083 rsq: 0.559707"
# [6] "Name: OP2/PyOP2 pval: 0.669970 rsq: 0.559707"
# [1] "Name: OPM/opm-parser pval: 0.002394 rsq: 0.343868"
# [2] "Name: OPM/opm-parser pval: 0.759231 rsq: 0.343868"
# [3] "Name: OPM/opm-parser pval: 0.410963 rsq: 0.343868"
# [4] "Name: OPM/opm-parser pval: 0.717501 rsq: 0.343868"
# [5] "Name: OPM/opm-parser pval: 0.093453 rsq: 0.343868"
# [6] "Name: OPM/opm-parser pval: 0.744836 rsq: 0.343868"
# [1] "Name: PCSX2/pcsx2 pval: 0.000000 rsq: 0.379174"
# [2] "Name: PCSX2/pcsx2 pval: 0.146368 rsq: 0.379174"
# [3] "Name: PCSX2/pcsx2 pval: 0.335104 rsq: 0.379174"
# [4] "Name: PCSX2/pcsx2 pval: 0.332439 rsq: 0.379174"
# [5] "Name: PCSX2/pcsx2 pval: 0.020315 rsq: 0.379174"
# [6] "Name: PCSX2/pcsx2 pval: 0.052608 rsq: 0.379174"
# [1] "Name: PX4/Firmware pval: 0.000001 rsq: 0.211053"
# [2] "Name: PX4/Firmware pval: 0.105710 rsq: 0.211053"
# [3] "Name: PX4/Firmware pval: 0.010312 rsq: 0.211053"
# [4] "Name: PX4/Firmware pval: 0.721127 rsq: 0.211053"
# [5] "Name: PX4/Firmware pval: 0.740014 rsq: 0.211053"
# [6] "Name: PX4/Firmware pval: 0.288757 rsq: 0.211053"
# [1] "Name: ParadiseSS13/Paradise pval: 0.133254 rsq: 0.290726"
# [2] "Name: ParadiseSS13/Paradise pval: 0.751879 rsq: 0.290726"
# [3] "Name: ParadiseSS13/Paradise pval: 0.170278 rsq: 0.290726"
# [4] "Name: ParadiseSS13/Paradise pval: 0.841586 rsq: 0.290726"
# [5] "Name: ParadiseSS13/Paradise pval: 0.093319 rsq: 0.290726"
# [6] "Name: ParadiseSS13/Paradise pval: 0.098994 rsq: 0.290726"
# [1] "Name: PecanProject/pecan pval: 0.000000 rsq: 0.551338"
# [2] "Name: PecanProject/pecan pval: 0.413506 rsq: 0.551338"
# [3] "Name: PecanProject/pecan pval: 0.005388 rsq: 0.551338"
# [4] "Name: PecanProject/pecan pval: 0.832834 rsq: 0.551338"
# [5] "Name: PecanProject/pecan pval: 0.481809 rsq: 0.551338"
# [6] "Name: PecanProject/pecan pval: 0.353822 rsq: 0.551338"
# [1] "Name: Pylons/pyramid pval: 0.000034 rsq: 0.482646"
# [2] "Name: Pylons/pyramid pval: 0.105382 rsq: 0.482646"
# [3] "Name: Pylons/pyramid pval: 0.981666 rsq: 0.482646"
# [4] "Name: Pylons/pyramid pval: 0.352403 rsq: 0.482646"
# [5] "Name: Pylons/pyramid pval: 0.020103 rsq: 0.482646"
# [6] "Name: Pylons/pyramid pval: 0.113210 rsq: 0.482646"
# [1] "Name: ReactiveX/RxJava pval: 0.000004 rsq: 0.148574"
# [2] "Name: ReactiveX/RxJava pval: 0.353310 rsq: 0.148574"
# [3] "Name: ReactiveX/RxJava pval: 0.000263 rsq: 0.148574"
# [4] "Name: ReactiveX/RxJava pval: 0.835516 rsq: 0.148574"
# [5] "Name: ReactiveX/RxJava pval: 0.604992 rsq: 0.148574"
# [6] "Name: ReactiveX/RxJava pval: 0.151744 rsq: 0.148574"
# [1] "Name: RestKit/RestKit pval: 0.756707 rsq: 0.367703"
# [2] "Name: RestKit/RestKit pval: 0.011006 rsq: 0.367703"
# [3] "Name: RestKit/RestKit pval: 0.580258 rsq: 0.367703"
# [4] "Name: RestKit/RestKit pval: 0.138351 rsq: 0.367703"
# [5] "Name: RestKit/RestKit pval: 0.341112 rsq: 0.367703"
# [6] "Name: RestKit/RestKit pval: 0.806444 rsq: 0.367703"
# [1] "Name: Smoothieware/Smoothieware pval: 0.457452 rsq: 0.577192"
# [2] "Name: Smoothieware/Smoothieware pval: 0.036536 rsq: 0.577192"
# [3] "Name: Smoothieware/Smoothieware pval: 0.533214 rsq: 0.577192"
# [4] "Name: Smoothieware/Smoothieware pval: 0.038301 rsq: 0.577192"
# [5] "Name: Smoothieware/Smoothieware pval: 0.577041 rsq: 0.577192"
# [6] "Name: Smoothieware/Smoothieware pval: 0.933528 rsq: 0.577192"
# [1] "Name: Theano/Theano pval: 0.000000 rsq: 0.358904"
# [2] "Name: Theano/Theano pval: 0.990827 rsq: 0.358904"
# [3] "Name: Theano/Theano pval: 0.251031 rsq: 0.358904"
# [4] "Name: Theano/Theano pval: 0.623663 rsq: 0.358904"
# [5] "Name: Theano/Theano pval: 0.309693 rsq: 0.358904"
# [6] "Name: Theano/Theano pval: 0.165615 rsq: 0.358904"
# [1] "Name: TrinityCore/TrinityCore pval: 0.000000 rsq: 0.396127"
# [2] "Name: TrinityCore/TrinityCore pval: 0.202583 rsq: 0.396127"
# [3] "Name: TrinityCore/TrinityCore pval: 0.007973 rsq: 0.396127"
# [4] "Name: TrinityCore/TrinityCore pval: 0.805447 rsq: 0.396127"
# [5] "Name: TrinityCore/TrinityCore pval: 0.398449 rsq: 0.396127"
# [6] "Name: TrinityCore/TrinityCore pval: 0.782132 rsq: 0.396127"
# [1] "Name: UniversalMediaServer/UniversalMediaServer pval: 0.096274 rsq: 0.472892"
# [2] "Name: UniversalMediaServer/UniversalMediaServer pval: 0.556594 rsq: 0.472892"
# [3] "Name: UniversalMediaServer/UniversalMediaServer pval: 0.281573 rsq: 0.472892"
# [4] "Name: UniversalMediaServer/UniversalMediaServer pval: 0.181787 rsq: 0.472892"
# [5] "Name: UniversalMediaServer/UniversalMediaServer pval: 0.080017 rsq: 0.472892"
# [6] "Name: UniversalMediaServer/UniversalMediaServer pval: 0.001824 rsq: 0.472892"
# [1] "Name: Vauxoo/addons-vauxoo pval: 0.034038 rsq: 0.394369"
# [2] "Name: Vauxoo/addons-vauxoo pval: 0.534701 rsq: 0.394369"
# [3] "Name: Vauxoo/addons-vauxoo pval: 0.037534 rsq: 0.394369"
# [4] "Name: Vauxoo/addons-vauxoo pval: 0.933491 rsq: 0.394369"
# [5] "Name: Vauxoo/addons-vauxoo pval: 0.274151 rsq: 0.394369"
# [6] "Name: Vauxoo/addons-vauxoo pval: 0.068497 rsq: 0.394369"
# [1] "Name: WoltLab/WCF pval: 0.008062 rsq: 0.575451"
# [2] "Name: WoltLab/WCF pval: 0.567542 rsq: 0.575451"
# [3] "Name: WoltLab/WCF pval: 0.047277 rsq: 0.575451"
# [4] "Name: WoltLab/WCF pval: 0.018261 rsq: 0.575451"
# [5] "Name: WoltLab/WCF pval: 0.551070 rsq: 0.575451"
# [6] "Name: WoltLab/WCF pval: 0.109988 rsq: 0.575451"
# [1] "Name: Zarel/Pokemon-Showdown pval: 0.000000 rsq: 0.291750"
# [2] "Name: Zarel/Pokemon-Showdown pval: 0.605047 rsq: 0.291750"
# [3] "Name: Zarel/Pokemon-Showdown pval: 0.310963 rsq: 0.291750"
# [4] "Name: Zarel/Pokemon-Showdown pval: 0.411543 rsq: 0.291750"
# [5] "Name: Zarel/Pokemon-Showdown pval: 0.369033 rsq: 0.291750"
# [6] "Name: Zarel/Pokemon-Showdown pval: 0.631829 rsq: 0.291750"
# [1] "Name: adobe/brackets pval: 0.000000 rsq: 0.424084"
# [2] "Name: adobe/brackets pval: 0.294795 rsq: 0.424084"
# [3] "Name: adobe/brackets pval: 0.146403 rsq: 0.424084"
# [4] "Name: adobe/brackets pval: 0.372736 rsq: 0.424084"
# [5] "Name: adobe/brackets pval: 0.915096 rsq: 0.424084"
# [6] "Name: adobe/brackets pval: 0.360075 rsq: 0.424084"
# [1] "Name: ajaxorg/ace pval: 0.507321 rsq: 0.499158"
# [2] "Name: ajaxorg/ace pval: 0.412587 rsq: 0.499158"
# [3] "Name: ajaxorg/ace pval: 0.005996 rsq: 0.499158"
# [4] "Name: ajaxorg/ace pval: 0.017802 rsq: 0.499158"
# [5] "Name: ajaxorg/ace pval: 0.102752 rsq: 0.499158"
# [6] "Name: ajaxorg/ace pval: 0.480214 rsq: 0.499158"
# [1] "Name: ansible/ansible-modules-core pval: 0.053588 rsq: 0.258739"
# [2] "Name: ansible/ansible-modules-core pval: 0.472406 rsq: 0.258739"
# [3] "Name: ansible/ansible-modules-core pval: 0.852075 rsq: 0.258739"
# [4] "Name: ansible/ansible-modules-core pval: 0.898619 rsq: 0.258739"
# [5] "Name: ansible/ansible-modules-core pval: 0.489181 rsq: 0.258739"
# [6] "Name: ansible/ansible-modules-core pval: 0.856407 rsq: 0.258739"
# [1] "Name: ansible/ansible-modules-extras pval: 0.000002 rsq: 0.307261"
# [2] "Name: ansible/ansible-modules-extras pval: 0.588544 rsq: 0.307261"
# [3] "Name: ansible/ansible-modules-extras pval: 0.607599 rsq: 0.307261"
# [4] "Name: ansible/ansible-modules-extras pval: 0.437185 rsq: 0.307261"
# [5] "Name: ansible/ansible-modules-extras pval: 0.360917 rsq: 0.307261"
# [6] "Name: ansible/ansible-modules-extras pval: 0.698843 rsq: 0.307261"
# [1] "Name: antlr/antlr4 pval: 0.035663 rsq: 0.319360"
# [2] "Name: antlr/antlr4 pval: 0.805971 rsq: 0.319360"
# [3] "Name: antlr/antlr4 pval: 0.594702 rsq: 0.319360"
# [4] "Name: antlr/antlr4 pval: 0.954056 rsq: 0.319360"
# [5] "Name: antlr/antlr4 pval: 0.932759 rsq: 0.319360"
# [6] "Name: antlr/antlr4 pval: 0.316301 rsq: 0.319360"
# [1] "Name: appcelerator/titanium_mobile pval: 0.000000 rsq: 0.265229"
# [2] "Name: appcelerator/titanium_mobile pval: 0.006177 rsq: 0.265229"
# [3] "Name: appcelerator/titanium_mobile pval: 0.000630 rsq: 0.265229"
# [4] "Name: appcelerator/titanium_mobile pval: 0.902083 rsq: 0.265229"
# [5] "Name: appcelerator/titanium_mobile pval: 0.568028 rsq: 0.265229"
# [6] "Name: appcelerator/titanium_mobile pval: 0.000000 rsq: 0.265229"
# [1] "Name: appleseedhq/appleseed pval: 0.000013 rsq: 0.491235"
# [2] "Name: appleseedhq/appleseed pval: 0.432349 rsq: 0.491235"
# [3] "Name: appleseedhq/appleseed pval: 0.020987 rsq: 0.491235"
# [4] "Name: appleseedhq/appleseed pval: 0.392501 rsq: 0.491235"
# [5] "Name: appleseedhq/appleseed pval: 0.524168 rsq: 0.491235"
# [6] "Name: appleseedhq/appleseed pval: 0.106738 rsq: 0.491235"
# [1] "Name: astaxie/beego pval: 0.000036 rsq: 0.326340"
# [2] "Name: astaxie/beego pval: 0.591496 rsq: 0.326340"
# [3] "Name: astaxie/beego pval: 0.060831 rsq: 0.326340"
# [4] "Name: astaxie/beego pval: 0.934703 rsq: 0.326340"
# [5] "Name: astaxie/beego pval: 0.011867 rsq: 0.326340"
# [6] "Name: astaxie/beego pval: 0.026081 rsq: 0.326340"
# [1] "Name: astropy/astropy pval: 0.000004 rsq: 0.371974"
# [2] "Name: astropy/astropy pval: 0.802387 rsq: 0.371974"
# [3] "Name: astropy/astropy pval: 0.299322 rsq: 0.371974"
# [4] "Name: astropy/astropy pval: 0.621873 rsq: 0.371974"
# [5] "Name: astropy/astropy pval: 0.656293 rsq: 0.371974"
# [6] "Name: astropy/astropy pval: 0.486462 rsq: 0.371974"
# [1] "Name: bem/bem-components pval: 0.002365 rsq: 0.388253"
# [2] "Name: bem/bem-components pval: 0.118814 rsq: 0.388253"
# [3] "Name: bem/bem-components pval: 0.073844 rsq: 0.388253"
# [4] "Name: bem/bem-components pval: 0.102903 rsq: 0.388253"
# [5] "Name: bem/bem-components pval: 0.846395 rsq: 0.388253"
# [6] "Name: bem/bem-components pval: 0.010346 rsq: 0.388253"
# [1] "Name: bitcoin-dot-org/bitcoin.org pval: 0.045020 rsq: 0.257416"
# [2] "Name: bitcoin-dot-org/bitcoin.org pval: 0.488566 rsq: 0.257416"
# [3] "Name: bitcoin-dot-org/bitcoin.org pval: 0.200684 rsq: 0.257416"
# [4] "Name: bitcoin-dot-org/bitcoin.org pval: 0.472057 rsq: 0.257416"
# [5] "Name: bitcoin-dot-org/bitcoin.org pval: 0.645800 rsq: 0.257416"
# [6] "Name: bitcoin-dot-org/bitcoin.org pval: 0.762224 rsq: 0.257416"
# [1] "Name: bitcoin/bitcoin pval: 0.000000 rsq: 0.333512"
# [2] "Name: bitcoin/bitcoin pval: 0.090837 rsq: 0.333512"
# [3] "Name: bitcoin/bitcoin pval: 0.000441 rsq: 0.333512"
# [4] "Name: bitcoin/bitcoin pval: 0.933890 rsq: 0.333512"
# [5] "Name: bitcoin/bitcoin pval: 0.000001 rsq: 0.333512"
# [6] "Name: bitcoin/bitcoin pval: 0.000003 rsq: 0.333512"
# [1] "Name: bokeh/bokeh pval: 0.023740 rsq: 0.402313"
# [2] "Name: bokeh/bokeh pval: 0.563011 rsq: 0.402313"
# [3] "Name: bokeh/bokeh pval: 0.581146 rsq: 0.402313"
# [4] "Name: bokeh/bokeh pval: 0.827200 rsq: 0.402313"
# [5] "Name: bokeh/bokeh pval: 0.985476 rsq: 0.402313"
# [6] "Name: bokeh/bokeh pval: 0.923181 rsq: 0.402313"
# [1] "Name: bosun-monitor/bosun pval: 0.018468 rsq: 0.231947"
# [2] "Name: bosun-monitor/bosun pval: 0.888647 rsq: 0.231947"
# [3] "Name: bosun-monitor/bosun pval: 0.691554 rsq: 0.231947"
# [4] "Name: bosun-monitor/bosun pval: 0.910727 rsq: 0.231947"
# [5] "Name: bosun-monitor/bosun pval: 0.692846 rsq: 0.231947"
# [6] "Name: bosun-monitor/bosun pval: 0.941904 rsq: 0.231947"
# [1] "Name: boto/boto pval: 0.817851 rsq: 0.358002"
# [2] "Name: boto/boto pval: 0.145580 rsq: 0.358002"
# [3] "Name: boto/boto pval: 0.015392 rsq: 0.358002"
# [4] "Name: boto/boto pval: 0.295110 rsq: 0.358002"
# [5] "Name: boto/boto pval: 0.035862 rsq: 0.358002"
# [6] "Name: boto/boto pval: 0.055951 rsq: 0.358002"
# [1] "Name: buildbot/buildbot pval: 0.000000 rsq: 0.290247"
# [2] "Name: buildbot/buildbot pval: 0.631236 rsq: 0.290247"
# [3] "Name: buildbot/buildbot pval: 0.363513 rsq: 0.290247"
# [4] "Name: buildbot/buildbot pval: 0.515376 rsq: 0.290247"
# [5] "Name: buildbot/buildbot pval: 0.052746 rsq: 0.290247"
# [6] "Name: buildbot/buildbot pval: 0.974456 rsq: 0.290247"
# [1] "Name: cakephp/cakephp pval: 0.000000 rsq: 0.353454"
# [2] "Name: cakephp/cakephp pval: 0.140985 rsq: 0.353454"
# [3] "Name: cakephp/cakephp pval: 0.707020 rsq: 0.353454"
# [4] "Name: cakephp/cakephp pval: 0.000872 rsq: 0.353454"
# [5] "Name: cakephp/cakephp pval: 0.479709 rsq: 0.353454"
# [6] "Name: cakephp/cakephp pval: 0.117236 rsq: 0.353454"
# [1] "Name: cakephp/docs pval: 0.000000 rsq: 0.332049"
# [2] "Name: cakephp/docs pval: 0.550383 rsq: 0.332049"
# [3] "Name: cakephp/docs pval: 0.275623 rsq: 0.332049"
# [4] "Name: cakephp/docs pval: 0.718296 rsq: 0.332049"
# [5] "Name: cakephp/docs pval: 0.830926 rsq: 0.332049"
# [6] "Name: cakephp/docs pval: 0.838233 rsq: 0.332049"
# [1] "Name: camptocamp/c2cgeoportal pval: 0.041902 rsq: 0.260402"
# [2] "Name: camptocamp/c2cgeoportal pval: 0.792503 rsq: 0.260402"
# [3] "Name: camptocamp/c2cgeoportal pval: 0.098191 rsq: 0.260402"
# [4] "Name: camptocamp/c2cgeoportal pval: 0.960710 rsq: 0.260402"
# [5] "Name: camptocamp/c2cgeoportal pval: 0.358842 rsq: 0.260402"
# [6] "Name: camptocamp/c2cgeoportal pval: 0.143831 rsq: 0.260402"
# [1] "Name: camptocamp/cgxp pval: 0.001056 rsq: 0.499799"
# [2] "Name: camptocamp/cgxp pval: 0.626029 rsq: 0.499799"
# [3] "Name: camptocamp/cgxp pval: 0.011441 rsq: 0.499799"
# [4] "Name: camptocamp/cgxp pval: 0.200731 rsq: 0.499799"
# [5] "Name: camptocamp/cgxp pval: 0.324636 rsq: 0.499799"
# [6] "Name: camptocamp/cgxp pval: 0.016634 rsq: 0.499799"
# [1] "Name: cappuccino/cappuccino pval: 0.677769 rsq: 0.301721"
# [2] "Name: cappuccino/cappuccino pval: 0.982509 rsq: 0.301721"
# [3] "Name: cappuccino/cappuccino pval: 0.309459 rsq: 0.301721"
# [4] "Name: cappuccino/cappuccino pval: 0.978726 rsq: 0.301721"
# [5] "Name: cappuccino/cappuccino pval: 0.266012 rsq: 0.301721"
# [6] "Name: cappuccino/cappuccino pval: 0.401309 rsq: 0.301721"
# [1] "Name: caskdata/cdap pval: 0.000000 rsq: 0.398879"
# [2] "Name: caskdata/cdap pval: 0.000010 rsq: 0.398879"
# [3] "Name: caskdata/cdap pval: 0.000034 rsq: 0.398879"
# [4] "Name: caskdata/cdap pval: 0.120545 rsq: 0.398879"
# [5] "Name: caskdata/cdap pval: 0.000025 rsq: 0.398879"
# [6] "Name: caskdata/cdap pval: 0.000001 rsq: 0.398879"
# [1] "Name: cfpb/cfgov-refresh pval: 0.000000 rsq: 0.365367"
# [2] "Name: cfpb/cfgov-refresh pval: 0.934542 rsq: 0.365367"
# [3] "Name: cfpb/cfgov-refresh pval: 0.676430 rsq: 0.365367"
# [4] "Name: cfpb/cfgov-refresh pval: 0.904296 rsq: 0.365367"
# [5] "Name: cfpb/cfgov-refresh pval: 0.677742 rsq: 0.365367"
# [6] "Name: cfpb/cfgov-refresh pval: 0.686528 rsq: 0.365367"
# [1] "Name: citation-style-language/styles pval: 0.237428 rsq: 0.485534"
# [2] "Name: citation-style-language/styles pval: 0.223548 rsq: 0.485534"
# [3] "Name: citation-style-language/styles pval: 0.191468 rsq: 0.485534"
# [4] "Name: citation-style-language/styles pval: 0.890663 rsq: 0.485534"
# [5] "Name: citation-style-language/styles pval: 0.216314 rsq: 0.485534"
# [6] "Name: citation-style-language/styles pval: 0.610225 rsq: 0.485534"
# [1] "Name: cocos2d/cocos2d-x pval: 0.002076 rsq: 0.159208"
# [2] "Name: cocos2d/cocos2d-x pval: 0.908804 rsq: 0.159208"
# [3] "Name: cocos2d/cocos2d-x pval: 0.500550 rsq: 0.159208"
# [4] "Name: cocos2d/cocos2d-x pval: 0.246833 rsq: 0.159208"
# [5] "Name: cocos2d/cocos2d-x pval: 0.724683 rsq: 0.159208"
# [6] "Name: cocos2d/cocos2d-x pval: 0.623782 rsq: 0.159208"
# [1] "Name: crate/crate pval: 0.000000 rsq: 0.428207"
# [2] "Name: crate/crate pval: 0.011720 rsq: 0.428207"
# [3] "Name: crate/crate pval: 0.000134 rsq: 0.428207"
# [4] "Name: crate/crate pval: 0.031778 rsq: 0.428207"
# [5] "Name: crate/crate pval: 0.510553 rsq: 0.428207"
# [6] "Name: crate/crate pval: 0.000028 rsq: 0.428207"
# [1] "Name: creationix/nvm pval: 0.122615 rsq: 0.284245"
# [2] "Name: creationix/nvm pval: 0.527977 rsq: 0.284245"
# [3] "Name: creationix/nvm pval: 0.780834 rsq: 0.284245"
# [4] "Name: creationix/nvm pval: 0.886717 rsq: 0.284245"
# [5] "Name: creationix/nvm pval: 0.398434 rsq: 0.284245"
# [6] "Name: creationix/nvm pval: 0.089460 rsq: 0.284245"
# [1] "Name: cvmfs/cvmfs pval: 0.000857 rsq: 0.422662"
# [2] "Name: cvmfs/cvmfs pval: 0.002634 rsq: 0.422662"
# [3] "Name: cvmfs/cvmfs pval: 0.504648 rsq: 0.422662"
# [4] "Name: cvmfs/cvmfs pval: 0.946158 rsq: 0.422662"
# [5] "Name: cvmfs/cvmfs pval: 0.454910 rsq: 0.422662"
# [6] "Name: cvmfs/cvmfs pval: 0.889235 rsq: 0.422662"
# [1] "Name: cylc/cylc pval: 0.000004 rsq: 0.368430"
# [2] "Name: cylc/cylc pval: 0.224368 rsq: 0.368430"
# [3] "Name: cylc/cylc pval: 0.857049 rsq: 0.368430"
# [4] "Name: cylc/cylc pval: 0.533008 rsq: 0.368430"
# [5] "Name: cylc/cylc pval: 0.758419 rsq: 0.368430"
# [6] "Name: cylc/cylc pval: 0.424177 rsq: 0.368430"
# [1] "Name: cython/cython pval: 0.359472 rsq: 0.417883"
# [2] "Name: cython/cython pval: 0.021060 rsq: 0.417883"
# [3] "Name: cython/cython pval: 0.056695 rsq: 0.417883"
# [4] "Name: cython/cython pval: 0.276433 rsq: 0.417883"
# [5] "Name: cython/cython pval: 0.955075 rsq: 0.417883"
# [6] "Name: cython/cython pval: 0.054446 rsq: 0.417883"
# [1] "Name: diaspora/diaspora pval: 0.000000 rsq: 0.382635"
# [2] "Name: diaspora/diaspora pval: 0.932114 rsq: 0.382635"
# [3] "Name: diaspora/diaspora pval: 0.537125 rsq: 0.382635"
# [4] "Name: diaspora/diaspora pval: 0.603844 rsq: 0.382635"
# [5] "Name: diaspora/diaspora pval: 0.002511 rsq: 0.382635"
# [6] "Name: diaspora/diaspora pval: 0.005388 rsq: 0.382635"
# [1] "Name: dimagi/commcare-hq pval: 0.784833 rsq: 0.604360"
# [2] "Name: dimagi/commcare-hq pval: 0.076692 rsq: 0.604360"
# [3] "Name: dimagi/commcare-hq pval: 0.023662 rsq: 0.604360"
# [4] "Name: dimagi/commcare-hq pval: 0.516071 rsq: 0.604360"
# [5] "Name: dimagi/commcare-hq pval: 0.315319 rsq: 0.604360"
# [6] "Name: dimagi/commcare-hq pval: 0.114856 rsq: 0.604360"
# [1] "Name: dimitri/el-get pval: 0.000143 rsq: 0.698318"
# [2] "Name: dimitri/el-get pval: 0.707568 rsq: 0.698318"
# [3] "Name: dimitri/el-get pval: 0.000552 rsq: 0.698318"
# [4] "Name: dimitri/el-get pval: 0.274654 rsq: 0.698318"
# [5] "Name: dimitri/el-get pval: 0.482061 rsq: 0.698318"
# [6] "Name: dimitri/el-get pval: 0.000546 rsq: 0.698318"
# [1] "Name: django-oscar/django-oscar pval: 0.237175 rsq: 0.563110"
# [2] "Name: django-oscar/django-oscar pval: 0.156259 rsq: 0.563110"
# [3] "Name: django-oscar/django-oscar pval: 0.184919 rsq: 0.563110"
# [4] "Name: django-oscar/django-oscar pval: 0.089788 rsq: 0.563110"
# [5] "Name: django-oscar/django-oscar pval: 0.968652 rsq: 0.563110"
# [6] "Name: django-oscar/django-oscar pval: 0.211664 rsq: 0.563110"
# [1] "Name: doctrine/doctrine2 pval: 0.000000 rsq: 0.319304"
# [2] "Name: doctrine/doctrine2 pval: 0.061023 rsq: 0.319304"
# [3] "Name: doctrine/doctrine2 pval: 0.846010 rsq: 0.319304"
# [4] "Name: doctrine/doctrine2 pval: 0.491031 rsq: 0.319304"
# [5] "Name: doctrine/doctrine2 pval: 0.562535 rsq: 0.319304"
# [6] "Name: doctrine/doctrine2 pval: 0.798825 rsq: 0.319304"
# [1] "Name: dogecoin/dogecoin pval: NaN rsq: 1.000000"
# [2] "Name: dogecoin/dogecoin pval: NaN rsq: 1.000000"
# [3] "Name: dogecoin/dogecoin pval: NaN rsq: 1.000000"
# [4] "Name: dogecoin/dogecoin pval: NaN rsq: 1.000000"
# [5] "Name: dogecoin/dogecoin pval: NaN rsq: 1.000000"
# [6] "Name: dogecoin/dogecoin pval: NaN rsq: 1.000000"
# [1] "Name: dropwizard/dropwizard pval: 0.001497 rsq: 0.277382"
# [2] "Name: dropwizard/dropwizard pval: 0.807153 rsq: 0.277382"
# [3] "Name: dropwizard/dropwizard pval: 0.341859 rsq: 0.277382"
# [4] "Name: dropwizard/dropwizard pval: 0.270864 rsq: 0.277382"
# [5] "Name: dropwizard/dropwizard pval: 0.980807 rsq: 0.277382"
# [6] "Name: dropwizard/dropwizard pval: 0.480391 rsq: 0.277382"
# [1] "Name: duckduckgo/zeroclickinfo-spice pval: 0.368937 rsq: 0.885484"
# [2] "Name: duckduckgo/zeroclickinfo-spice pval: 0.036004 rsq: 0.885484"
# [3] "Name: duckduckgo/zeroclickinfo-spice pval: 0.031598 rsq: 0.885484"
# [4] "Name: duckduckgo/zeroclickinfo-spice pval: 0.795544 rsq: 0.885484"
# [5] "Name: duckduckgo/zeroclickinfo-spice pval: 0.174340 rsq: 0.885484"
# [6] "Name: duckduckgo/zeroclickinfo-spice pval: 0.518537 rsq: 0.885484"
# [1] "Name: elastic/logstash pval: 0.039233 rsq: 0.300447"
# [2] "Name: elastic/logstash pval: 0.557786 rsq: 0.300447"
# [3] "Name: elastic/logstash pval: 0.915705 rsq: 0.300447"
# [4] "Name: elastic/logstash pval: 0.742017 rsq: 0.300447"
# [5] "Name: elastic/logstash pval: 0.318458 rsq: 0.300447"
# [6] "Name: elastic/logstash pval: 0.571061 rsq: 0.300447"
# [1] "Name: enyojs/enyo pval: 0.088036 rsq: 0.525186"
# [2] "Name: enyojs/enyo pval: 0.617422 rsq: 0.525186"
# [3] "Name: enyojs/enyo pval: 0.709949 rsq: 0.525186"
# [4] "Name: enyojs/enyo pval: 0.876369 rsq: 0.525186"
# [5] "Name: enyojs/enyo pval: 0.821972 rsq: 0.525186"
# [6] "Name: enyojs/enyo pval: 0.773259 rsq: 0.525186"
# [1] "Name: erlang/otp pval: 0.020397 rsq: 0.145230"
# [2] "Name: erlang/otp pval: 0.351462 rsq: 0.145230"
# [3] "Name: erlang/otp pval: 0.612410 rsq: 0.145230"
# [4] "Name: erlang/otp pval: 0.531677 rsq: 0.145230"
# [5] "Name: erlang/otp pval: 0.244728 rsq: 0.145230"
# [6] "Name: erlang/otp pval: 0.527805 rsq: 0.145230"
# [1] "Name: espressomd/espresso pval: 0.283018 rsq: 0.487249"
# [2] "Name: espressomd/espresso pval: 0.166925 rsq: 0.487249"
# [3] "Name: espressomd/espresso pval: 0.857972 rsq: 0.487249"
# [4] "Name: espressomd/espresso pval: 0.298429 rsq: 0.487249"
# [5] "Name: espressomd/espresso pval: 0.295249 rsq: 0.487249"
# [6] "Name: espressomd/espresso pval: 0.939371 rsq: 0.487249"
# [1] "Name: ether/etherpad-lite pval: 0.373617 rsq: 0.376212"
# [2] "Name: ether/etherpad-lite pval: 0.223260 rsq: 0.376212"
# [3] "Name: ether/etherpad-lite pval: 0.260182 rsq: 0.376212"
# [4] "Name: ether/etherpad-lite pval: 0.039158 rsq: 0.376212"
# [5] "Name: ether/etherpad-lite pval: 0.807612 rsq: 0.376212"
# [6] "Name: ether/etherpad-lite pval: 0.508144 rsq: 0.376212"
# [1] "Name: ezsystems/ezpublish-kernel pval: 0.000311 rsq: 0.319089"
# [2] "Name: ezsystems/ezpublish-kernel pval: 0.982417 rsq: 0.319089"
# [3] "Name: ezsystems/ezpublish-kernel pval: 0.216984 rsq: 0.319089"
# [4] "Name: ezsystems/ezpublish-kernel pval: 0.378796 rsq: 0.319089"
# [5] "Name: ezsystems/ezpublish-kernel pval: 0.111094 rsq: 0.319089"
# [6] "Name: ezsystems/ezpublish-kernel pval: 0.654411 rsq: 0.319089"
# [1] "Name: ezsystems/ezpublish-legacy pval: 0.000005 rsq: 0.284182"
# [2] "Name: ezsystems/ezpublish-legacy pval: 0.426425 rsq: 0.284182"
# [3] "Name: ezsystems/ezpublish-legacy pval: 0.627273 rsq: 0.284182"
# [4] "Name: ezsystems/ezpublish-legacy pval: 0.459356 rsq: 0.284182"
# [5] "Name: ezsystems/ezpublish-legacy pval: 0.938602 rsq: 0.284182"
# [6] "Name: ezsystems/ezpublish-legacy pval: 0.353018 rsq: 0.284182"
# [1] "Name: fog/fog pval: 0.068998 rsq: 0.216029"
# [2] "Name: fog/fog pval: 0.122406 rsq: 0.216029"
# [3] "Name: fog/fog pval: 0.322347 rsq: 0.216029"
# [4] "Name: fog/fog pval: 0.707115 rsq: 0.216029"
# [5] "Name: fog/fog pval: 0.907812 rsq: 0.216029"
# [6] "Name: fog/fog pval: 0.795163 rsq: 0.216029"
# [1] "Name: forcedotcom/SalesforceMobileSDK-Android pval: 0.001923 rsq: 0.333479"
# [2] "Name: forcedotcom/SalesforceMobileSDK-Android pval: 0.820678 rsq: 0.333479"
# [3] "Name: forcedotcom/SalesforceMobileSDK-Android pval: 0.576994 rsq: 0.333479"
# [4] "Name: forcedotcom/SalesforceMobileSDK-Android pval: 0.243148 rsq: 0.333479"
# [5] "Name: forcedotcom/SalesforceMobileSDK-Android pval: 0.522854 rsq: 0.333479"
# [6] "Name: forcedotcom/SalesforceMobileSDK-Android pval: 0.001704 rsq: 0.333479"
# [1] "Name: forcedotcom/SalesforceMobileSDK-iOS pval: 0.000000 rsq: 0.363654"
# [2] "Name: forcedotcom/SalesforceMobileSDK-iOS pval: 0.961293 rsq: 0.363654"
# [3] "Name: forcedotcom/SalesforceMobileSDK-iOS pval: 0.820974 rsq: 0.363654"
# [4] "Name: forcedotcom/SalesforceMobileSDK-iOS pval: 0.936821 rsq: 0.363654"
# [5] "Name: forcedotcom/SalesforceMobileSDK-iOS pval: 0.704537 rsq: 0.363654"
# [6] "Name: forcedotcom/SalesforceMobileSDK-iOS pval: 0.563814 rsq: 0.363654"
# [1] "Name: frappe/erpnext pval: 0.737951 rsq: 0.667055"
# [2] "Name: frappe/erpnext pval: 0.569598 rsq: 0.667055"
# [3] "Name: frappe/erpnext pval: 0.446328 rsq: 0.667055"
# [4] "Name: frappe/erpnext pval: 0.909196 rsq: 0.667055"
# [5] "Name: frappe/erpnext pval: 0.889938 rsq: 0.667055"
# [6] "Name: frappe/erpnext pval: 0.736559 rsq: 0.667055"
# [1] "Name: frappe/frappe pval: NaN rsq: 1.000000"
# [2] "Name: frappe/frappe pval: NaN rsq: 1.000000"
# [3] "Name: frappe/frappe pval: NaN rsq: 1.000000"
# [4] "Name: frappe/frappe pval: NaN rsq: 1.000000"
# [5] "Name: frappe/frappe pval: NaN rsq: 1.000000"
# [6] "Name: frappe/frappe pval: NaN rsq: 1.000000"
# [1] "Name: geonetwork/core-geonetwork pval: 0.239185 rsq: 0.478452"
# [2] "Name: geonetwork/core-geonetwork pval: 0.904131 rsq: 0.478452"
# [3] "Name: geonetwork/core-geonetwork pval: 0.208099 rsq: 0.478452"
# [4] "Name: geonetwork/core-geonetwork pval: 0.042561 rsq: 0.478452"
# [5] "Name: geonetwork/core-geonetwork pval: 0.491150 rsq: 0.478452"
# [6] "Name: geonetwork/core-geonetwork pval: 0.438981 rsq: 0.478452"
# [1] "Name: geoserver/geoserver pval: 0.035474 rsq: 0.480307"
# [2] "Name: geoserver/geoserver pval: 0.137814 rsq: 0.480307"
# [3] "Name: geoserver/geoserver pval: 0.916128 rsq: 0.480307"
# [4] "Name: geoserver/geoserver pval: 0.155721 rsq: 0.480307"
# [5] "Name: geoserver/geoserver pval: 0.155960 rsq: 0.480307"
# [6] "Name: geoserver/geoserver pval: 0.254155 rsq: 0.480307"
# [1] "Name: geotools/geotools pval: 0.036693 rsq: 0.462135"
# [2] "Name: geotools/geotools pval: 0.439419 rsq: 0.462135"
# [3] "Name: geotools/geotools pval: 0.734074 rsq: 0.462135"
# [4] "Name: geotools/geotools pval: 0.865383 rsq: 0.462135"
# [5] "Name: geotools/geotools pval: 0.518513 rsq: 0.462135"
# [6] "Name: geotools/geotools pval: 0.707758 rsq: 0.462135"
# [1] "Name: ggreer/the_silver_searcher pval: 0.515611 rsq: 0.452802"
# [2] "Name: ggreer/the_silver_searcher pval: 0.197959 rsq: 0.452802"
# [3] "Name: ggreer/the_silver_searcher pval: 0.724826 rsq: 0.452802"
# [4] "Name: ggreer/the_silver_searcher pval: 0.198489 rsq: 0.452802"
# [5] "Name: ggreer/the_silver_searcher pval: 0.389161 rsq: 0.452802"
# [6] "Name: ggreer/the_silver_searcher pval: 0.788810 rsq: 0.452802"
# [1] "Name: gitextensions/gitextensions pval: 0.000002 rsq: 0.329590"
# [2] "Name: gitextensions/gitextensions pval: 0.077244 rsq: 0.329590"
# [3] "Name: gitextensions/gitextensions pval: 0.303520 rsq: 0.329590"
# [4] "Name: gitextensions/gitextensions pval: 0.336402 rsq: 0.329590"
# [5] "Name: gitextensions/gitextensions pval: 0.113505 rsq: 0.329590"
# [6] "Name: gitextensions/gitextensions pval: 0.207591 rsq: 0.329590"
# [1] "Name: grails/grails-core pval: 0.278764 rsq: 0.491799"
# [2] "Name: grails/grails-core pval: 0.541445 rsq: 0.491799"
# [3] "Name: grails/grails-core pval: 0.224495 rsq: 0.491799"
# [4] "Name: grails/grails-core pval: 0.813171 rsq: 0.491799"
# [5] "Name: grails/grails-core pval: 0.849095 rsq: 0.491799"
# [6] "Name: grails/grails-core pval: 0.192678 rsq: 0.491799"
# [1] "Name: gravitystorm/openstreetmap-carto pval: 0.124107 rsq: 0.484355"
# [2] "Name: gravitystorm/openstreetmap-carto pval: 0.860209 rsq: 0.484355"
# [3] "Name: gravitystorm/openstreetmap-carto pval: 0.385289 rsq: 0.484355"
# [4] "Name: gravitystorm/openstreetmap-carto pval: 0.832593 rsq: 0.484355"
# [5] "Name: gravitystorm/openstreetmap-carto pval: 0.303887 rsq: 0.484355"
# [6] "Name: gravitystorm/openstreetmap-carto pval: 0.900868 rsq: 0.484355"
# [1] "Name: halide/Halide pval: 0.000000 rsq: 0.449740"
# [2] "Name: halide/Halide pval: 0.381122 rsq: 0.449740"
# [3] "Name: halide/Halide pval: 0.108781 rsq: 0.449740"
# [4] "Name: halide/Halide pval: 0.947261 rsq: 0.449740"
# [5] "Name: halide/Halide pval: 0.557108 rsq: 0.449740"
# [6] "Name: halide/Halide pval: 0.112449 rsq: 0.449740"
# [1] "Name: haskell/cabal pval: 0.019324 rsq: 0.463597"
# [2] "Name: haskell/cabal pval: 0.901086 rsq: 0.463597"
# [3] "Name: haskell/cabal pval: 0.438571 rsq: 0.463597"
# [4] "Name: haskell/cabal pval: 0.840426 rsq: 0.463597"
# [5] "Name: haskell/cabal pval: 0.845486 rsq: 0.463597"
# [6] "Name: haskell/cabal pval: 0.819227 rsq: 0.463597"
# [1] "Name: honestbleeps/Reddit-Enhancement-Suite pval: 0.000000 rsq: 0.312522"
# [2] "Name: honestbleeps/Reddit-Enhancement-Suite pval: 0.023967 rsq: 0.312522"
# [3] "Name: honestbleeps/Reddit-Enhancement-Suite pval: 0.086812 rsq: 0.312522"
# [4] "Name: honestbleeps/Reddit-Enhancement-Suite pval: 0.242139 rsq: 0.312522"
# [5] "Name: honestbleeps/Reddit-Enhancement-Suite pval: 0.502862 rsq: 0.312522"
# [6] "Name: honestbleeps/Reddit-Enhancement-Suite pval: 0.040140 rsq: 0.312522"
# [1] "Name: honza/vim-snippets pval: 0.147378 rsq: 0.390199"
# [2] "Name: honza/vim-snippets pval: 0.874750 rsq: 0.390199"
# [3] "Name: honza/vim-snippets pval: 0.874536 rsq: 0.390199"
# [4] "Name: honza/vim-snippets pval: 0.906229 rsq: 0.390199"
# [5] "Name: honza/vim-snippets pval: 0.174575 rsq: 0.390199"
# [6] "Name: honza/vim-snippets pval: 0.652677 rsq: 0.390199"
# [1] "Name: hrydgard/ppsspp pval: 0.000000 rsq: 0.228311"
# [2] "Name: hrydgard/ppsspp pval: 0.005361 rsq: 0.228311"
# [3] "Name: hrydgard/ppsspp pval: 0.021977 rsq: 0.228311"
# [4] "Name: hrydgard/ppsspp pval: 0.139763 rsq: 0.228311"
# [5] "Name: hrydgard/ppsspp pval: 0.391007 rsq: 0.228311"
# [6] "Name: hrydgard/ppsspp pval: 0.204821 rsq: 0.228311"
# [1] "Name: ipa320/cob_robots pval: 0.003896 rsq: 0.356325"
# [2] "Name: ipa320/cob_robots pval: 0.089961 rsq: 0.356325"
# [3] "Name: ipa320/cob_robots pval: 0.240795 rsq: 0.356325"
# [4] "Name: ipa320/cob_robots pval: 0.001342 rsq: 0.356325"
# [5] "Name: ipa320/cob_robots pval: 0.866610 rsq: 0.356325"
# [6] "Name: ipa320/cob_robots pval: 0.047178 rsq: 0.356325"
# [1] "Name: ipython/ipython pval: 0.000071 rsq: 0.324980"
# [2] "Name: ipython/ipython pval: 0.655254 rsq: 0.324980"
# [3] "Name: ipython/ipython pval: 0.654534 rsq: 0.324980"
# [4] "Name: ipython/ipython pval: 0.526282 rsq: 0.324980"
# [5] "Name: ipython/ipython pval: 0.012364 rsq: 0.324980"
# [6] "Name: ipython/ipython pval: 0.476565 rsq: 0.324980"
# [1] "Name: jashkenas/backbone pval: 0.022549 rsq: 0.424302"
# [2] "Name: jashkenas/backbone pval: 0.609095 rsq: 0.424302"
# [3] "Name: jashkenas/backbone pval: 0.004589 rsq: 0.424302"
# [4] "Name: jashkenas/backbone pval: 0.040733 rsq: 0.424302"
# [5] "Name: jashkenas/backbone pval: 0.175763 rsq: 0.424302"
# [6] "Name: jashkenas/backbone pval: 0.961817 rsq: 0.424302"
# [1] "Name: jashkenas/underscore pval: 0.003742 rsq: 0.291307"
# [2] "Name: jashkenas/underscore pval: 0.624397 rsq: 0.291307"
# [3] "Name: jashkenas/underscore pval: 0.306203 rsq: 0.291307"
# [4] "Name: jashkenas/underscore pval: 0.229550 rsq: 0.291307"
# [5] "Name: jashkenas/underscore pval: 0.562707 rsq: 0.291307"
# [6] "Name: jashkenas/underscore pval: 0.643992 rsq: 0.291307"
# [1] "Name: libgit2/libgit2 pval: 0.001067 rsq: 0.229379"
# [2] "Name: libgit2/libgit2 pval: 0.614096 rsq: 0.229379"
# [3] "Name: libgit2/libgit2 pval: 0.522434 rsq: 0.229379"
# [4] "Name: libgit2/libgit2 pval: 0.915055 rsq: 0.229379"
# [5] "Name: libgit2/libgit2 pval: 0.095529 rsq: 0.229379"
# [6] "Name: libgit2/libgit2 pval: 0.111222 rsq: 0.229379"
# [1] "Name: livecode/livecode pval: 0.001602 rsq: 0.232098"
# [2] "Name: livecode/livecode pval: 0.048088 rsq: 0.232098"
# [3] "Name: livecode/livecode pval: 0.224587 rsq: 0.232098"
# [4] "Name: livecode/livecode pval: 0.014518 rsq: 0.232098"
# [5] "Name: livecode/livecode pval: 0.878614 rsq: 0.232098"
# [6] "Name: livecode/livecode pval: 0.023131 rsq: 0.232098"
# [1] "Name: magnumripper/JohnTheRipper pval: 0.000150 rsq: 0.539307"
# [2] "Name: magnumripper/JohnTheRipper pval: 0.087108 rsq: 0.539307"
# [3] "Name: magnumripper/JohnTheRipper pval: 0.008071 rsq: 0.539307"
# [4] "Name: magnumripper/JohnTheRipper pval: 0.392451 rsq: 0.539307"
# [5] "Name: magnumripper/JohnTheRipper pval: 0.205751 rsq: 0.539307"
# [6] "Name: magnumripper/JohnTheRipper pval: 0.339149 rsq: 0.539307"
# [1] "Name: matplotlib/matplotlib pval: 0.000000 rsq: 0.390265"
# [2] "Name: matplotlib/matplotlib pval: 0.341673 rsq: 0.390265"
# [3] "Name: matplotlib/matplotlib pval: 0.051947 rsq: 0.390265"
# [4] "Name: matplotlib/matplotlib pval: 0.437133 rsq: 0.390265"
# [5] "Name: matplotlib/matplotlib pval: 0.213710 rsq: 0.390265"
# [6] "Name: matplotlib/matplotlib pval: 0.003982 rsq: 0.390265"
# [1] "Name: mne-tools/mne-python pval: 0.000000 rsq: 0.540889"
# [2] "Name: mne-tools/mne-python pval: 0.617358 rsq: 0.540889"
# [3] "Name: mne-tools/mne-python pval: 0.713728 rsq: 0.540889"
# [4] "Name: mne-tools/mne-python pval: 0.737516 rsq: 0.540889"
# [5] "Name: mne-tools/mne-python pval: 0.571406 rsq: 0.540889"
# [6] "Name: mne-tools/mne-python pval: 0.000907 rsq: 0.540889"
# [1] "Name: modxcms/revolution pval: 0.001299 rsq: 0.338706"
# [2] "Name: modxcms/revolution pval: 0.291760 rsq: 0.338706"
# [3] "Name: modxcms/revolution pval: 0.268629 rsq: 0.338706"
# [4] "Name: modxcms/revolution pval: 0.267149 rsq: 0.338706"
# [5] "Name: modxcms/revolution pval: 0.099658 rsq: 0.338706"
# [6] "Name: modxcms/revolution pval: 0.735987 rsq: 0.338706"
# [1] "Name: mozilla/addons-server pval: 0.000010 rsq: 0.449036"
# [2] "Name: mozilla/addons-server pval: 0.190889 rsq: 0.449036"
# [3] "Name: mozilla/addons-server pval: 0.056083 rsq: 0.449036"
# [4] "Name: mozilla/addons-server pval: 0.178033 rsq: 0.449036"
# [5] "Name: mozilla/addons-server pval: 0.996168 rsq: 0.449036"
# [6] "Name: mozilla/addons-server pval: 0.133313 rsq: 0.449036"
# [1] "Name: mozilla/pdf.js pval: 0.000000 rsq: 0.262893"
# [2] "Name: mozilla/pdf.js pval: 0.037174 rsq: 0.262893"
# [3] "Name: mozilla/pdf.js pval: 0.849519 rsq: 0.262893"
# [4] "Name: mozilla/pdf.js pval: 0.088695 rsq: 0.262893"
# [5] "Name: mozilla/pdf.js pval: 0.457593 rsq: 0.262893"
# [6] "Name: mozilla/pdf.js pval: 0.048077 rsq: 0.262893"
# [1] "Name: mozilla/shumway pval: 0.904491 rsq: 0.289853"
# [2] "Name: mozilla/shumway pval: 0.942023 rsq: 0.289853"
# [3] "Name: mozilla/shumway pval: 0.351282 rsq: 0.289853"
# [4] "Name: mozilla/shumway pval: 0.574596 rsq: 0.289853"
# [5] "Name: mozilla/shumway pval: 0.890145 rsq: 0.289853"
# [6] "Name: mozilla/shumway pval: 0.185443 rsq: 0.289853"
# [1] "Name: mozilla/zamboni pval: 0.000000 rsq: 0.326606"
# [2] "Name: mozilla/zamboni pval: 0.004711 rsq: 0.326606"
# [3] "Name: mozilla/zamboni pval: 0.640168 rsq: 0.326606"
# [4] "Name: mozilla/zamboni pval: 0.016865 rsq: 0.326606"
# [5] "Name: mozilla/zamboni pval: 0.163812 rsq: 0.326606"
# [6] "Name: mozilla/zamboni pval: 0.426007 rsq: 0.326606"
# [1] "Name: mxe/mxe pval: 0.613705 rsq: 0.268231"
# [2] "Name: mxe/mxe pval: 0.322305 rsq: 0.268231"
# [3] "Name: mxe/mxe pval: 0.879209 rsq: 0.268231"
# [4] "Name: mxe/mxe pval: 0.067799 rsq: 0.268231"
# [5] "Name: mxe/mxe pval: 0.043448 rsq: 0.268231"
# [6] "Name: mxe/mxe pval: 0.914255 rsq: 0.268231"
# [1] "Name: naparuba/shinken pval: 0.802928 rsq: 0.321278"
# [2] "Name: naparuba/shinken pval: 0.705492 rsq: 0.321278"
# [3] "Name: naparuba/shinken pval: 0.859674 rsq: 0.321278"
# [4] "Name: naparuba/shinken pval: 0.536838 rsq: 0.321278"
# [5] "Name: naparuba/shinken pval: 0.828831 rsq: 0.321278"
# [6] "Name: naparuba/shinken pval: 0.855706 rsq: 0.321278"
# [1] "Name: nim-lang/Nim pval: 0.000000 rsq: 0.308167"
# [2] "Name: nim-lang/Nim pval: 0.070224 rsq: 0.308167"
# [3] "Name: nim-lang/Nim pval: 0.646837 rsq: 0.308167"
# [4] "Name: nim-lang/Nim pval: 0.028522 rsq: 0.308167"
# [5] "Name: nim-lang/Nim pval: 0.230357 rsq: 0.308167"
# [6] "Name: nim-lang/Nim pval: 0.029376 rsq: 0.308167"
# [1] "Name: nipy/nipype pval: 0.000422 rsq: 0.249893"
# [2] "Name: nipy/nipype pval: 0.765291 rsq: 0.249893"
# [3] "Name: nipy/nipype pval: 0.976165 rsq: 0.249893"
# [4] "Name: nipy/nipype pval: 0.635215 rsq: 0.249893"
# [5] "Name: nipy/nipype pval: 0.407231 rsq: 0.249893"
# [6] "Name: nipy/nipype pval: 0.759779 rsq: 0.249893"
# [1] "Name: ocaml/opam-repository pval: 0.003168 rsq: 0.254781"
# [2] "Name: ocaml/opam-repository pval: 0.400360 rsq: 0.254781"
# [3] "Name: ocaml/opam-repository pval: 0.710842 rsq: 0.254781"
# [4] "Name: ocaml/opam-repository pval: 0.807206 rsq: 0.254781"
# [5] "Name: ocaml/opam-repository pval: 0.739005 rsq: 0.254781"
# [6] "Name: ocaml/opam-repository pval: 0.361733 rsq: 0.254781"
# [1] "Name: octobercms/october pval: 0.664687 rsq: 0.562658"
# [2] "Name: octobercms/october pval: 0.750062 rsq: 0.562658"
# [3] "Name: octobercms/october pval: 0.648266 rsq: 0.562658"
# [4] "Name: octobercms/october pval: 0.503608 rsq: 0.562658"
# [5] "Name: octobercms/october pval: 0.141006 rsq: 0.562658"
# [6] "Name: octobercms/october pval: 0.540291 rsq: 0.562658"
# [1] "Name: ofiwg/fabtests pval: 0.001562 rsq: 0.325233"
# [2] "Name: ofiwg/fabtests pval: 0.869389 rsq: 0.325233"
# [3] "Name: ofiwg/fabtests pval: 0.645300 rsq: 0.325233"
# [4] "Name: ofiwg/fabtests pval: 0.306467 rsq: 0.325233"
# [5] "Name: ofiwg/fabtests pval: 0.353741 rsq: 0.325233"
# [6] "Name: ofiwg/fabtests pval: 0.762801 rsq: 0.325233"
# [1] "Name: openframeworks/openFrameworks pval: 0.183556 rsq: 0.252265"
# [2] "Name: openframeworks/openFrameworks pval: 0.684095 rsq: 0.252265"
# [3] "Name: openframeworks/openFrameworks pval: 0.683142 rsq: 0.252265"
# [4] "Name: openframeworks/openFrameworks pval: 0.758341 rsq: 0.252265"
# [5] "Name: openframeworks/openFrameworks pval: 0.449203 rsq: 0.252265"
# [6] "Name: openframeworks/openFrameworks pval: 0.249084 rsq: 0.252265"
# [1] "Name: openmicroscopy/openmicroscopy pval: 0.719400 rsq: 0.370049"
# [2] "Name: openmicroscopy/openmicroscopy pval: 0.918226 rsq: 0.370049"
# [3] "Name: openmicroscopy/openmicroscopy pval: 0.008066 rsq: 0.370049"
# [4] "Name: openmicroscopy/openmicroscopy pval: 0.149533 rsq: 0.370049"
# [5] "Name: openmicroscopy/openmicroscopy pval: 0.167806 rsq: 0.370049"
# [6] "Name: openmicroscopy/openmicroscopy pval: 0.965334 rsq: 0.370049"
# [1] "Name: openshift/vagrant-openshift pval: 0.105657 rsq: 0.385564"
# [2] "Name: openshift/vagrant-openshift pval: 0.996433 rsq: 0.385564"
# [3] "Name: openshift/vagrant-openshift pval: 0.137442 rsq: 0.385564"
# [4] "Name: openshift/vagrant-openshift pval: 0.705398 rsq: 0.385564"
# [5] "Name: openshift/vagrant-openshift pval: 0.384709 rsq: 0.385564"
# [6] "Name: openshift/vagrant-openshift pval: 0.161358 rsq: 0.385564"
# [1] "Name: otwcode/otwarchive pval: 0.000000 rsq: 0.369833"
# [2] "Name: otwcode/otwarchive pval: 0.944194 rsq: 0.369833"
# [3] "Name: otwcode/otwarchive pval: 0.896018 rsq: 0.369833"
# [4] "Name: otwcode/otwarchive pval: 0.441702 rsq: 0.369833"
# [5] "Name: otwcode/otwarchive pval: 0.630326 rsq: 0.369833"
# [6] "Name: otwcode/otwarchive pval: 0.000000 rsq: 0.369833"
# [1] "Name: paparazzi/paparazzi pval: 0.002500 rsq: 0.330037"
# [2] "Name: paparazzi/paparazzi pval: 0.060761 rsq: 0.330037"
# [3] "Name: paparazzi/paparazzi pval: 0.398220 rsq: 0.330037"
# [4] "Name: paparazzi/paparazzi pval: 0.159011 rsq: 0.330037"
# [5] "Name: paparazzi/paparazzi pval: 0.009571 rsq: 0.330037"
# [6] "Name: paparazzi/paparazzi pval: 0.777230 rsq: 0.330037"
# [1] "Name: phpDocumentor/phpDocumentor2 pval: 0.772110 rsq: 0.442136"
# [2] "Name: phpDocumentor/phpDocumentor2 pval: 0.921785 rsq: 0.442136"
# [3] "Name: phpDocumentor/phpDocumentor2 pval: 0.805193 rsq: 0.442136"
# [4] "Name: phpDocumentor/phpDocumentor2 pval: 0.821271 rsq: 0.442136"
# [5] "Name: phpDocumentor/phpDocumentor2 pval: 0.524260 rsq: 0.442136"
# [6] "Name: phpDocumentor/phpDocumentor2 pval: 0.584515 rsq: 0.442136"
# [1] "Name: phpbb/phpbb pval: 0.000000 rsq: 0.577111"
# [2] "Name: phpbb/phpbb pval: 0.737903 rsq: 0.577111"
# [3] "Name: phpbb/phpbb pval: 0.033442 rsq: 0.577111"
# [4] "Name: phpbb/phpbb pval: 0.332688 rsq: 0.577111"
# [5] "Name: phpbb/phpbb pval: 0.982085 rsq: 0.577111"
# [6] "Name: phpbb/phpbb pval: 0.501726 rsq: 0.577111"
# [1] "Name: puppetlabs/puppet pval: 0.000000 rsq: 0.276415"
# [2] "Name: puppetlabs/puppet pval: 0.092072 rsq: 0.276415"
# [3] "Name: puppetlabs/puppet pval: 0.448574 rsq: 0.276415"
# [4] "Name: puppetlabs/puppet pval: 0.598843 rsq: 0.276415"
# [5] "Name: puppetlabs/puppet pval: 0.231976 rsq: 0.276415"
# [6] "Name: puppetlabs/puppet pval: 0.380548 rsq: 0.276415"
# [1] "Name: puppetlabs/puppetdb pval: 0.000000 rsq: 0.414576"
# [2] "Name: puppetlabs/puppetdb pval: 0.584162 rsq: 0.414576"
# [3] "Name: puppetlabs/puppetdb pval: 0.711012 rsq: 0.414576"
# [4] "Name: puppetlabs/puppetdb pval: 0.653105 rsq: 0.414576"
# [5] "Name: puppetlabs/puppetdb pval: 0.989205 rsq: 0.414576"
# [6] "Name: puppetlabs/puppetdb pval: 0.304647 rsq: 0.414576"
# [1] "Name: pydanny/cookiecutter-django pval: NaN rsq: 1.000000"
# [2] "Name: pydanny/cookiecutter-django pval: NaN rsq: 1.000000"
# [3] "Name: pydanny/cookiecutter-django pval: NaN rsq: 1.000000"
# [4] "Name: pydanny/cookiecutter-django pval: NaN rsq: 1.000000"
# [5] "Name: pydanny/cookiecutter-django pval: NaN rsq: 1.000000"
# [6] "Name: pydanny/cookiecutter-django pval: NaN rsq: 1.000000"
# [1] "Name: pyinstaller/pyinstaller pval: 0.093480 rsq: 0.464838"
# [2] "Name: pyinstaller/pyinstaller pval: 0.534640 rsq: 0.464838"
# [3] "Name: pyinstaller/pyinstaller pval: 0.230602 rsq: 0.464838"
# [4] "Name: pyinstaller/pyinstaller pval: 0.622063 rsq: 0.464838"
# [5] "Name: pyinstaller/pyinstaller pval: 0.205192 rsq: 0.464838"
# [6] "Name: pyinstaller/pyinstaller pval: 0.072817 rsq: 0.464838"
# [1] "Name: qgis/QGIS pval: 0.000006 rsq: 0.257503"
# [2] "Name: qgis/QGIS pval: 0.735051 rsq: 0.257503"
# [3] "Name: qgis/QGIS pval: 0.673382 rsq: 0.257503"
# [4] "Name: qgis/QGIS pval: 0.955089 rsq: 0.257503"
# [5] "Name: qgis/QGIS pval: 0.674357 rsq: 0.257503"
# [6] "Name: qgis/QGIS pval: 0.427521 rsq: 0.257503"
# [1] "Name: qgis/QGIS-Documentation pval: 0.002373 rsq: 0.413540"
# [2] "Name: qgis/QGIS-Documentation pval: 0.393756 rsq: 0.413540"
# [3] "Name: qgis/QGIS-Documentation pval: 0.026469 rsq: 0.413540"
# [4] "Name: qgis/QGIS-Documentation pval: 0.797378 rsq: 0.413540"
# [5] "Name: qgis/QGIS-Documentation pval: 0.078167 rsq: 0.413540"
# [6] "Name: qgis/QGIS-Documentation pval: 0.749415 rsq: 0.413540"
# [1] "Name: rabbitmq/rabbitmq-server pval: 0.007655 rsq: 0.579341"
# [2] "Name: rabbitmq/rabbitmq-server pval: 0.550682 rsq: 0.579341"
# [3] "Name: rabbitmq/rabbitmq-server pval: 0.741246 rsq: 0.579341"
# [4] "Name: rabbitmq/rabbitmq-server pval: 0.814625 rsq: 0.579341"
# [5] "Name: rabbitmq/rabbitmq-server pval: 0.523505 rsq: 0.579341"
# [6] "Name: rabbitmq/rabbitmq-server pval: 0.863470 rsq: 0.579341"
# [1] "Name: rubinius/rubinius pval: 0.045226 rsq: 0.221541"
# [2] "Name: rubinius/rubinius pval: 0.025145 rsq: 0.221541"
# [3] "Name: rubinius/rubinius pval: 0.937947 rsq: 0.221541"
# [4] "Name: rubinius/rubinius pval: 0.492553 rsq: 0.221541"
# [5] "Name: rubinius/rubinius pval: 0.294989 rsq: 0.221541"
# [6] "Name: rubinius/rubinius pval: 0.318444 rsq: 0.221541"
# [1] "Name: scala/scala-lang pval: 0.000693 rsq: 0.532582"
# [2] "Name: scala/scala-lang pval: 0.735835 rsq: 0.532582"
# [3] "Name: scala/scala-lang pval: 0.003266 rsq: 0.532582"
# [4] "Name: scala/scala-lang pval: 0.177314 rsq: 0.532582"
# [5] "Name: scala/scala-lang pval: 0.969549 rsq: 0.532582"
# [6] "Name: scala/scala-lang pval: 0.046566 rsq: 0.532582"
# [1] "Name: scikit-image/scikit-image pval: 0.000087 rsq: 0.492635"
# [2] "Name: scikit-image/scikit-image pval: 0.998168 rsq: 0.492635"
# [3] "Name: scikit-image/scikit-image pval: 0.307767 rsq: 0.492635"
# [4] "Name: scikit-image/scikit-image pval: 0.419616 rsq: 0.492635"
# [5] "Name: scikit-image/scikit-image pval: 0.465481 rsq: 0.492635"
# [6] "Name: scikit-image/scikit-image pval: 0.065889 rsq: 0.492635"
# [1] "Name: scikit-learn/scikit-learn pval: 0.000000 rsq: 0.450578"
# [2] "Name: scikit-learn/scikit-learn pval: 0.485604 rsq: 0.450578"
# [3] "Name: scikit-learn/scikit-learn pval: 0.001365 rsq: 0.450578"
# [4] "Name: scikit-learn/scikit-learn pval: 0.276516 rsq: 0.450578"
# [5] "Name: scikit-learn/scikit-learn pval: 0.025271 rsq: 0.450578"
# [6] "Name: scikit-learn/scikit-learn pval: 0.696204 rsq: 0.450578"
# [1] "Name: senchalabs/connect pval: 0.758202 rsq: 0.190655"
# [2] "Name: senchalabs/connect pval: 0.549989 rsq: 0.190655"
# [3] "Name: senchalabs/connect pval: 0.775435 rsq: 0.190655"
# [4] "Name: senchalabs/connect pval: 0.398210 rsq: 0.190655"
# [5] "Name: senchalabs/connect pval: 0.503949 rsq: 0.190655"
# [6] "Name: senchalabs/connect pval: 0.622830 rsq: 0.190655"
# [1] "Name: servo/rust-mozjs pval: 0.117956 rsq: 0.864822"
# [2] "Name: servo/rust-mozjs pval: 0.026519 rsq: 0.864822"
# [3] "Name: servo/rust-mozjs pval: 0.376175 rsq: 0.864822"
# [4] "Name: servo/rust-mozjs pval: 0.329812 rsq: 0.864822"
# [5] "Name: servo/rust-mozjs pval: 0.054930 rsq: 0.864822"
# [6] "Name: servo/rust-mozjs pval: 0.885780 rsq: 0.864822"
# [1] "Name: silexphp/Silex pval: 0.000002 rsq: 0.370074"
# [2] "Name: silexphp/Silex pval: 0.527539 rsq: 0.370074"
# [3] "Name: silexphp/Silex pval: 0.804693 rsq: 0.370074"
# [4] "Name: silexphp/Silex pval: 0.110368 rsq: 0.370074"
# [5] "Name: silexphp/Silex pval: 0.676689 rsq: 0.370074"
# [6] "Name: silexphp/Silex pval: 0.859929 rsq: 0.370074"
# [1] "Name: silverstripe/silverstripe-cms pval: 0.020781 rsq: 0.136483"
# [2] "Name: silverstripe/silverstripe-cms pval: 0.779101 rsq: 0.136483"
# [3] "Name: silverstripe/silverstripe-cms pval: 0.097303 rsq: 0.136483"
# [4] "Name: silverstripe/silverstripe-cms pval: 0.949169 rsq: 0.136483"
# [5] "Name: silverstripe/silverstripe-cms pval: 0.473479 rsq: 0.136483"
# [6] "Name: silverstripe/silverstripe-cms pval: 0.160638 rsq: 0.136483"
# [1] "Name: sunpy/sunpy pval: 0.740743 rsq: 0.388579"
# [2] "Name: sunpy/sunpy pval: 0.876735 rsq: 0.388579"
# [3] "Name: sunpy/sunpy pval: 0.035492 rsq: 0.388579"
# [4] "Name: sunpy/sunpy pval: 0.982340 rsq: 0.388579"
# [5] "Name: sunpy/sunpy pval: 0.790544 rsq: 0.388579"
# [6] "Name: sunpy/sunpy pval: 0.103419 rsq: 0.388579"
# [1] "Name: supercollider/supercollider pval: 0.102491 rsq: 0.574262"
# [2] "Name: supercollider/supercollider pval: 0.927491 rsq: 0.574262"
# [3] "Name: supercollider/supercollider pval: 0.459256 rsq: 0.574262"
# [4] "Name: supercollider/supercollider pval: 0.863584 rsq: 0.574262"
# [5] "Name: supercollider/supercollider pval: 0.198830 rsq: 0.574262"
# [6] "Name: supercollider/supercollider pval: 0.806966 rsq: 0.574262"
# [1] "Name: symfony/symfony-docs pval: 0.000000 rsq: 0.412056"
# [2] "Name: symfony/symfony-docs pval: 0.692705 rsq: 0.412056"
# [3] "Name: symfony/symfony-docs pval: 0.991818 rsq: 0.412056"
# [4] "Name: symfony/symfony-docs pval: 0.073115 rsq: 0.412056"
# [5] "Name: symfony/symfony-docs pval: 0.199608 rsq: 0.412056"
# [6] "Name: symfony/symfony-docs pval: 0.351256 rsq: 0.412056"
# [1] "Name: sympy/sympy pval: 0.000000 rsq: 0.312885"
# [2] "Name: sympy/sympy pval: 0.097042 rsq: 0.312885"
# [3] "Name: sympy/sympy pval: 0.285713 rsq: 0.312885"
# [4] "Name: sympy/sympy pval: 0.268630 rsq: 0.312885"
# [5] "Name: sympy/sympy pval: 0.055627 rsq: 0.312885"
# [6] "Name: sympy/sympy pval: 0.711690 rsq: 0.312885"
# [1] "Name: ultrabug/py3status pval: 0.015678 rsq: 0.400302"
# [2] "Name: ultrabug/py3status pval: 0.216672 rsq: 0.400302"
# [3] "Name: ultrabug/py3status pval: 0.277609 rsq: 0.400302"
# [4] "Name: ultrabug/py3status pval: 0.960180 rsq: 0.400302"
# [5] "Name: ultrabug/py3status pval: 0.192871 rsq: 0.400302"
# [6] "Name: ultrabug/py3status pval: 0.424467 rsq: 0.400302"
# [1] "Name: voidlinux/void-packages pval: 0.065332 rsq: 0.299627"
# [2] "Name: voidlinux/void-packages pval: 0.913190 rsq: 0.299627"
# [3] "Name: voidlinux/void-packages pval: 0.604380 rsq: 0.299627"
# [4] "Name: voidlinux/void-packages pval: 0.415905 rsq: 0.299627"
# [5] "Name: voidlinux/void-packages pval: 0.439699 rsq: 0.299627"
# [6] "Name: voidlinux/void-packages pval: 0.438748 rsq: 0.299627"
# [1] "Name: w3c/csswg-test pval: 0.050939 rsq: 0.248870"
# [2] "Name: w3c/csswg-test pval: 0.545941 rsq: 0.248870"
# [3] "Name: w3c/csswg-test pval: 0.350555 rsq: 0.248870"
# [4] "Name: w3c/csswg-test pval: 0.357718 rsq: 0.248870"
# [5] "Name: w3c/csswg-test pval: 0.889703 rsq: 0.248870"
# [6] "Name: w3c/csswg-test pval: 0.536348 rsq: 0.248870"
# [1] "Name: yast/yast-installation pval: 0.000000 rsq: 0.564006"
# [2] "Name: yast/yast-installation pval: 0.070878 rsq: 0.564006"
# [3] "Name: yast/yast-installation pval: 0.482951 rsq: 0.564006"
# [4] "Name: yast/yast-installation pval: 0.598394 rsq: 0.564006"
# [5] "Name: yast/yast-installation pval: 0.173082 rsq: 0.564006"
# [6] "Name: yast/yast-installation pval: 0.266974 rsq: 0.564006"
# [1] "Name: yast/yast-yast2 pval: 0.000000 rsq: 0.507139"
# [2] "Name: yast/yast-yast2 pval: 0.745368 rsq: 0.507139"
# [3] "Name: yast/yast-yast2 pval: 0.734579 rsq: 0.507139"
# [4] "Name: yast/yast-yast2 pval: 0.215124 rsq: 0.507139"
# [5] "Name: yast/yast-yast2 pval: 0.472918 rsq: 0.507139"
# [6] "Name: yast/yast-yast2 pval: 0.145111 rsq: 0.507139"
# [1] "Name: yesodweb/yesod pval: 0.560364 rsq: 0.532065"
# [2] "Name: yesodweb/yesod pval: 0.657638 rsq: 0.532065"
# [3] "Name: yesodweb/yesod pval: 0.711033 rsq: 0.532065"
# [4] "Name: yesodweb/yesod pval: 0.192888 rsq: 0.532065"
# [5] "Name: yesodweb/yesod pval: 0.760597 rsq: 0.532065"
# [6] "Name: yesodweb/yesod pval: 0.816213 rsq: 0.532065"
# [1] "Name: yui/yui3 pval: 0.049306 rsq: 0.372665"
# [2] "Name: yui/yui3 pval: 0.285348 rsq: 0.372665"
# [3] "Name: yui/yui3 pval: 0.294982 rsq: 0.372665"
# [4] "Name: yui/yui3 pval: 0.272024 rsq: 0.372665"
# [5] "Name: yui/yui3 pval: 0.906227 rsq: 0.372665"
# [6] "Name: yui/yui3 pval: 0.725527 rsq: 0.372665"
# [1] "Name: zeromq/libzmq pval: 0.271756 rsq: 0.370299"
# [2] "Name: zeromq/libzmq pval: 0.367925 rsq: 0.370299"
# [3] "Name: zeromq/libzmq pval: 0.661783 rsq: 0.370299"
# [4] "Name: zeromq/libzmq pval: 0.369389 rsq: 0.370299"
# [5] "Name: zeromq/libzmq pval: 0.483193 rsq: 0.370299"
# [6] "Name: zeromq/libzmq pval: 0.604807 rsq: 0.370299"
# [1] "Name: zurb/foundation-sites pval: 0.740477 rsq: 0.456869"
# [2] "Name: zurb/foundation-sites pval: 0.618054 rsq: 0.456869"
# [3] "Name: zurb/foundation-sites pval: 0.166423 rsq: 0.456869"
# [4] "Name: zurb/foundation-sites pval: 0.733905 rsq: 0.456869"
# [5] "Name: zurb/foundation-sites pval: 0.495752 rsq: 0.456869"
# [6] "Name: zurb/foundation-sites pval: 0.699992 rsq: 0.456869"
