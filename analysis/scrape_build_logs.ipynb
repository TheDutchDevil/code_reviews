# %% [markdown]
# # Introduction
#
# Notebook that for select projects in certain languages will try and scrape build logs to find whether certain tools are used in the build flow of the projects.

# %%
# Imports
# %load_ext autoreload
# %autoreload 2

from pymongo import MongoClient

import travis.scrape_build_logs as build_scraper

import analysis_utilities
import random
import re

# %%
mongo_client = MongoClient()

database = mongo_client["graduation"]
pull_requests_collection = database["pull_requests"]
projects_collection = database["projects"]
commits_collection = database["commits"]

# %% [markdown]
# ## Project selection
#
# We only select certain projects, as tool names differ per language / environment. For now we focus on Python

# %%
projects_list = list(projects_collection.find({'succeeded' : True, 'travis_is_oldest_ci': True, 'language': 'Python'}))

print("{} Python projects".format(len(projects_list)))

for project in projects_list:
    split_slug = project["full_name"].split("/")
    
    prs = list(pull_requests_collection.find(
                { 
                    'project_name' : split_slug[1],
                    'project_owner': split_slug[0]
                }
            ))
    
    pr_before, pr_after = analysis_utilities.split_prs_on_build_date(project, prs, True, "status_travis_date")
    
    project["travis_prs"] = pr_after
# Out:
# 127 Python projects

# %%
def process_project(project):
    
    if len(project["travis_prs"]) < 20:
        return None
    
    print(project["full_name"])

    sample_prs = random.sample(project["travis_prs"],  20)

    sample_commits = [sha for commits in [pr["commits"] for pr in sample_prs] for sha in commits]

    sample_commits = random.sample(sample_commits, 15)
    
    target_urls = []
    
    for sha in sample_commits:
        commit = commits_collection.find_one({'sha':sha, 'statuses' : {'$exists': True}})
        if commit is None:
            continue
            
        if "statuses" in commit:
            for status in commit["statuses"]:
                if "target_url" in status and status["target_url"] is not None:
                    if "builds" in status["target_url"] and \
                        "travis-ci.org" in status["target_url"]:
                        target_urls.append(status["target_url"])
    
            
    #target_urls = [status["target_url"] for statuses in [commits_collection.find_one({'sha':sha, 'statuses' : {'$exists': True}})["statuses"] for sha in sample_commits] for status in statuses if "target_url" in status and  "builds" in status["target_url"] and "travis-ci.org" in status["target_url"]]

    build_ids = list(set([build_scraper.retrieve_build_identifier_from_travis_url(url) for url in target_urls]))
    
    if len(build_ids) > 7:
        build_ids = random.sample(build_ids, 7)

    logs = build_scraper.build_logs_for_identifiers(build_ids)
    
    process_logs(logs)

# %%
def process_logs(logs):
    has_linter = False
    has_coverage = False
    
    lint_lines = []
    coverage_lines = []
    
    for log in logs:
        lines = log.split("\n")
        
        for line in lines:
            if "lint" in line:
                has_linter = True
                lint_lines.append(line)
                
            if "codecov" in line or "coverage" in line or "Pytest-cov" in line or "coveralls" in line:
                has_coverage = True
                coverage_lines.append(line)
                
    print("\tLint status is {}, coverage status is {}".format(has_linter, has_coverage))
    for line in coverage_lines[:10]:
        print(line)

# %%
for project in projects_list:
    process_project(project)
# Out:
# OP2/PyOP2
# 	Lint status is False, coverage status is False
# OSU-Net/cyder
# 	Lint status is False, coverage status is False
# Theano/Theano
# 	Lint status is True, coverage status is False
# ansible/ansible-modules-core
# 	Lint status is False, coverage status is False
# ansible/ansible-modules-extras
# 	Lint status is False, coverage status is False
# Pylons/pyramid
# 	Lint status is True, coverage status is True
# Searching for coverage
# Reading https://pypi.python.org/simple/coverage/
# Best match: coverage 4.0a5
# Downloading https://pypi.python.org/packages/source/c/coverage/coverage-4.0a5.zip#md5=8a59799b1c1740d211346d6e88990815
# Processing coverage-4.0a5.zip
# Writing /tmp/easy_install-szsqgf/coverage-4.0a5/setup.cfg
# Running coverage-4.0a5/setup.py -q bdist_egg --dist-dir /tmp/easy_install-szsqgf/coverage-4.0a5/egg-dist-tmp-Fh3Ikz
# creating /home/travis/virtualenv/python2.6.9/lib/python2.6/site-packages/coverage-4.0a5-py2.6-linux-x86_64.egg
# Extracting coverage-4.0a5-py2.6-linux-x86_64.egg to /home/travis/virtualenv/python2.6.9/lib/python2.6/site-packages
# Adding coverage 4.0a5 to easy-install.pth file
# Vauxoo/addons-vauxoo
# 	Lint status is True, coverage status is True
#     from coverage.cmdline import main as coverage_main
# ImportError: No module named coverage.cmdline
# pip install coveralls  # ToDo: Add to main image because in travis is installed
# Collecting coveralls
#   Downloading coveralls-1.1-py2.py3-none-any.whl
# Collecting docopt>=0.6.1 (from coveralls)
# Collecting coverage>=3.6 (from coveralls)
#   Downloading coverage-4.0.3.tar.gz (354kB)
# Collecting requests>=1.0.0 (from coveralls)
# Installing collected packages: requests, coverage, docopt, coveralls
# bokeh/bokeh
# 	Lint status is True, coverage status is True
#     coverage-3.7.1             |           py33_0         143 KB
#     coverage:                 3.7.1-py33_0
# +DEPS_TEST='graphviz sphinx>=1.3.1 pygments sphinx-bootstrap-theme sphinxcontrib-httpdomain beautiful-soup colorama pyyaml pdiff jinja2 nose mock coverage websocket-client ipython ipython-notebook gulp flake8 scipy matplotlib sympy ggplot seaborn==0.5.1 icalendar'
# +conda install --yes graphviz 'sphinx>=1.3.1' pygments sphinx-bootstrap-theme sphinxcontrib-httpdomain beautiful-soup colorama pyyaml pdiff jinja2 nose mock coverage websocket-client ipython ipython-notebook gulp flake8 scipy matplotlib sympy ggplot seaborn==0.5.1 icalendar
#     coverage:                 3.7.1-py33_0
# [      COMPLETE      ]|###################################################| 100%
# $ if [[ -z "$TRAVIS_TAG" ]]; then nosetests --with-coverage --cover-package=bokeh; fi
# The command "if [[ -z "$TRAVIS_TAG" ]]; then nosetests --with-coverage --cover-package=bokeh; fi" exited with 1.
#     coverage-3.7.1             |           py34_0         143 KB
#     coverage:                 3.7.1-py34_0
# boto/boto
# 	Lint status is False, coverage status is True
# Downloading/unpacking coverage==3.7.1 (from -r requirements.txt (line 9))
#   Downloading coverage-3.7.1.tar.gz (284kB): 284kB downloaded
#   Running setup.py (path:/home/travis/virtualenv/python2.6.9/build/coverage/setup.py) egg_info for package coverage
# Installing collected packages: nose, requests, rsa, simplejson, httpretty, paramiko, PyYAML, coverage, pyasn1, urllib3, pycrypto, ecdsa
#   Running setup.py install for coverage
#     building 'coverage.tracer' extension
#     gcc -pthread -fno-strict-aliasing -g -fstack-protector --param=ssp-buffer-size=4 -Wformat -Werror=format-security -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/opt/python/2.6.9/include/python2.6 -c coverage/tracer.c -o build/temp.linux-x86_64-2.6/coverage/tracer.o
#     gcc -pthread -shared build/temp.linux-x86_64-2.6/coverage/tracer.o -L/opt/python/2.6.9/lib -lpython2.6 -o build/lib.linux-x86_64-2.6/coverage/tracer.so
#     Installing coverage2 script to /home/travis/virtualenv/python2.6.9/bin
#     Installing coverage-2.6 script to /home/travis/virtualenv/python2.6.9/bin
# astropy/astropy
# 	Lint status is True, coverage status is True
# $ if [[ $SETUP_CMD == 'test --coverage' ]]; then $PIP_WHEEL_COMMAND "coverage" ; fi
# $ if [[ $SETUP_CMD == 'test --coverage' ]]; then $PIP_WHEEL_COMMAND "coveralls"; fi
# $ if [[ $SETUP_CMD == 'test --coverage' ]]; then coveralls; fi
# $ if [[ $SETUP_CMD == 'test --coverage' ]]; then $PIP_WHEEL_COMMAND "coverage" ; fi
# $ if [[ $SETUP_CMD == 'test --coverage' ]]; then $PIP_WHEEL_COMMAND "coveralls"; fi
# $ if [[ $SETUP_CMD == 'test --coverage' ]]; then coveralls; fi
# $ if [[ $SETUP_CMD == 'test --coverage' ]]; then $PIP_WHEEL_COMMAND "coverage" ; fi
# $ if [[ $SETUP_CMD == 'test --coverage' ]]; then $PIP_WHEEL_COMMAND "coveralls"; fi
# $ if [[ $SETUP_CMD == 'test --coverage' ]]; then coveralls; fi
# $ if [[ $SETUP_CMD == 'test --coverage' ]]; then $PIP_WHEEL_COMMAND "coverage" ; fi
# buildbot/buildbot
# 	Lint status is True, coverage status is True
# $ pip install codecov
# Collecting codecov
#   Using cached codecov-2.0.5-py2.py3-none-any.whl
# Collecting argparse (from codecov)
# Collecting requests>=2.0.0 (from codecov)
# Collecting coverage (from codecov)
#   Using cached coverage-4.3.4-cp27-cp27mu-manylinux1_x86_64.whl
# Installing collected packages: argparse, requests, coverage, codecov
# Successfully installed argparse-1.4.0 codecov-2.0.5 coverage-4.3.4 requests-2.13.0
# $ if [ $TESTS = trial -o $TESTS = coverage -o $TESTS = lint -o $TESTS = js ]; then
# cfpb/cfgov-refresh
# 	Lint status is True, coverage status is True
# ++curl -s https://codecov.io/bash
#     Yaml found at: codecov.yml
# ==> Python coveragepy not found
# ==> Searching for coverage reports in:
#     + ./test/unit_test_coverage/coverage-final.json bytes=820473
#     + ./test/unit_test_coverage/lcov.info bytes=123870
#     + ./test/unit_test_coverage/clover.xml bytes=299897
#     http://docs.codecov.io/docs/fixing-reports
#     url: https://codecov.io
#     -> View reports at https://codecov.io/github/cfpb/cfgov-refresh/commit/0ed5517087d5849194e6de7f293980fda87a6ecd
# cylc/cylc
# 	Lint status is False, coverage status is False
# cython/cython
# 	Lint status is False, coverage status is True
#    run.coverage_api
#    run.coverage_cmd
#    run.coverage_nogil
#    run.coverage_api
#    run.coverage_cmd
#    run.coverage_nogil
#    run.coverage_api
#    run.coverage_cmd
#    run.coverage_nogil
#    run.coverage_api
# honza/vim-snippets
# 	Lint status is False, coverage status is False
# frappe/erpnext
# 	Lint status is False, coverage status is False
# ipa320/cob_robots
# 	Lint status is True, coverage status is True
#   openmpi-checkpoint python-coverage python-nose-doc python-numpy-dbg
#   openmpi-checkpoint python-coverage python-nose-doc python-numpy-dbg
# frappe/frappe
# 	Lint status is False, coverage status is False
# ipython/ipython
# 	Lint status is True, coverage status is True
# $ pip install -f travis-wheels/wheelhouse -r requirements.txt -e file://$PWD#egg=ipython[test] coveralls
# Collecting coveralls
# Collecting docopt>=0.6.1 (from coveralls)
# Collecting coverage<3.999,>=3.6 (from coveralls)
# Collecting PyYAML>=3.10 (from coveralls)
# Installing collected packages: path.py, PyYAML, coverage, docopt, ipython, requests, pexpect, simplegeneric, pickleshare, decorator, traitlets, ipython-genutils, coveralls
# Successfully installed PyYAML-3.11 coverage-3.7.1 coveralls-0.5 decorator-3.4.2 docopt-0.6.2 ipython ipython-genutils path.py-7.3 pexpect-3.3 pickleshare-0.5 requests-2.6.0 simplegeneric-0.8.1 traitlets
# $ cd /tmp && iptest --coverage xml && cd -
# The command "cd /tmp && iptest --coverage xml && cd -" exited with 0.
# $ cp /tmp/ipy_coverage.xml ./
# lisa-lab/pylearn2
# 	Lint status is True, coverage status is True
#   --with-coverage       Enable plugin Coverage:  Activate a coverage report
#                         using Ned Batchelder's coverage module.
#                         Restrict coverage output to selected packages
#   --cover-erase         Erase previously collected coverage statistics before
#   --cover-tests         Include test modules in coverage report
#                         coverage report.  Useful for discovering holes in test
#                         coverage if not all files are imported by the test
#   --cover-html          Produce HTML coverage information
#   --cover-html-dir=DIR  Produce HTML coverage information in dir
#                         the coverage plugin, or in any other case where module
# matplotlib/matplotlib
# 	Lint status is True, coverage status is True
#   pip install $PRE python-dateutil $NUMPY pyparsing!=2.1.6 $PANDAS pep8 cycler coveralls coverage $MOCK
#   # support for python36 and suport for coverage output suppressing
# Collecting coveralls
#   Using cached coveralls-1.1-py2.py3-none-any.whl
# Collecting coverage
#   Downloading coverage-4.3.4-cp27-cp27mu-manylinux1_x86_64.whl (189kB)
# Collecting requests>=1.0.0 (from coveralls)
# Collecting docopt>=0.6.1 (from coveralls)
# Installing collected packages: six, python-dateutil, numpy, pyparsing, pep8, cycler, requests, coverage, docopt, coveralls, funcsigs, pbr, mock
# Successfully installed coverage-4.3.4 coveralls-1.1 cycler-0.10.0 docopt-0.6.2 funcsigs-1.0.2 mock-2.0.0 numpy-1.7.1 pbr-1.10.0 pep8-1.7.0 pyparsing-2.1.10 python-dateutil-2.6.0 requests-2.12.5 six-1.10.0
# mozilla/zamboni
# 	Lint status is False, coverage status is True
# Downloading/unpacking coverage==3.7.1 (from -r requirements/test.txt (line 5))
#   Downloading coverage-3.7.1.tar.gz (284kB): 284kB downloaded
#   Running setup.py (path:/home/travis/virtualenv/python2.6.9/build/coverage/setup.py) egg_info for package coverage
# Installing collected packages: amqp, anyjson, babel, basket-client, billiard, bleach, boto, cef, celery, celery-tasktree, certifi, chardet, commonware, cssutils, curling, defusedxml, dennis, Django, dj-database-url, django-aesfield, django-browserid, django-cache-nuggets, django-celery, django-cronjobs, django-csp, django-extensions, django-filter, django-memcached-pool, django-multidb-router, django-mysql-pymysql, django-nose, django-quieter-formset, django-pymemcache, django-raven-heka, djangorestframework, django-statsd-mozilla, django-storages, django-waffle, drf-compound-fields, easy-thumbnails, elasticsearch, email-reply-parser, fastchardet, feedparser, fudge, GitPython, google-api-python-client, gunicorn, html5lib, httplib2, importlib-no-failure, jingo, kombu, heka-py, heka-py-cef, heka-py-raven, marketplace-constants, monolith.client, mozilla-logger, mozpay, m2secret, ndg-httpsclient, newrelic, oauth2, oauthlib, ordereddict, polib, protobuf, pyasn1, PyBrowserID, PyJWT-mozilla, PyMySQL, pymemcache, pyquery, python-dateutil, python-gflags, python-memcached, pytz, raven, receipts, redis, requests, requests-oauthlib, schematic, signing-clients, six, slumber, SQLAlchemy, statsd, suds, urllib3, app-validator, django-queryset-transform, happyforms, elasticsearch-dsl, jingo-minify, nuggets, test-utils, django-session-csrf, django-cache-machine, django-uuidfield, django-mysql-pool, tower, coverage, psutil, nose-blockage, nosenicedots
#   Running setup.py install for coverage
#     building 'coverage.tracer' extension
#     gcc -pthread -fno-strict-aliasing -g -fstack-protector --param=ssp-buffer-size=4 -Wformat -Werror=format-security -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/opt/python/2.6.9/include/python2.6 -c coverage/tracer.c -o build/temp.linux-x86_64-2.6/coverage/tracer.o
#     gcc -pthread -shared build/temp.linux-x86_64-2.6/coverage/tracer.o -L/opt/python/2.6.9/lib -lpython2.6 -o build/lib.linux-x86_64-2.6/coverage/tracer.so
#     Installing coverage2 script to /home/travis/virtualenv/python2.6.9/bin
#     Installing coverage-2.6 script to /home/travis/virtualenv/python2.6.9/bin
# metomi/rose
# 	Lint status is False, coverage status is False
# mne-tools/mne-python
# 	Lint status is False, coverage status is True
# $ export PIP_DEPENDENCIES="codecov pytest-faulthandler pytest-sugar"
# $ export PIP_DEPENDENCIES="flake8 numpydoc codespell git+git://github.com/PyCQA/pydocstyle.git codecov check-manifest pytest-sugar"
#     coverage-4.5.1             |   py36h14c3975_0         211 KB
#     coverage:                 4.5.1-py36h14c3975_0
# Collecting codecov
#   Downloading https://files.pythonhosted.org/packages/8b/28/4c1950a61c3c5786f0f34d643d0d28ec832433c9a7c0bd157690d4eb1d5f/codecov-2.0.15-py2.py3-none-any.whl
# Requirement already satisfied: requests>=2.7.9 in /home/travis/miniconda/envs/test/lib/python3.6/site-packages (from codecov) (2.19.1)
# Requirement already satisfied: coverage in /home/travis/miniconda/envs/test/lib/python3.6/site-packages (from codecov) (4.5.1)
# Requirement already satisfied: idna<2.8,>=2.5 in /home/travis/miniconda/envs/test/lib/python3.6/site-packages (from requests>=2.7.9->codecov) (2.7)
# Requirement already satisfied: urllib3<1.24,>=1.21.1 in /home/travis/miniconda/envs/test/lib/python3.6/site-packages (from requests>=2.7.9->codecov) (1.23)
# naparuba/shinken
# 	Lint status is True, coverage status is True
# Collecting coveralls==0.5 (from -r test/requirements.txt (line 5))
#   Downloading coveralls-0.5.zip
#     /tmp/pip-build-IAvBLS/coveralls/setup.py:12: DeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
# Collecting coverage==3.7.1 (from -r test/requirements.txt (line 7))
#   Downloading coverage-3.7.1.tar.gz (284kB)
#     /tmp/pip-build-IAvBLS/coverage/setup.py:12: DeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#       tracker are on `Bitbucket <http://bitbucket.org/ned/coveragepy>`_, with a
# Collecting PyYAML>=3.10 (from coveralls==0.5->-r test/requirements.txt (line 5))
# Collecting docopt>=0.6.1 (from coveralls==0.5->-r test/requirements.txt (line 5))
# Collecting requests>=1.0.0 (from coveralls==0.5->-r test/requirements.txt (line 5))
# mozilla/addons-server
# 	Lint status is True, coverage status is True
# $ pip install --upgrade pip wheel coverage codecov
# Collecting coverage
#   Using cached coverage-4.0.3.tar.gz
# Collecting codecov
#   Using cached codecov-2.0.3-py2.py3-none-any.whl
# Collecting requests>=2.0.0 (from codecov)
# Installing collected packages: requests, codecov, coverage, wheel, pip
#   Running setup.py install for coverage
#     building 'coverage.tracer' extension
#     gcc -pthread -fno-strict-aliasing -g -fstack-protector --param=ssp-buffer-size=4 -Wformat -Werror=format-security -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/opt/python/2.7.9/include/python2.7 -c coverage/ctracer/datastack.c -o build/temp.linux-x86_64-2.7/coverage/ctracer/datastack.o
# nipy/nipype
# Could not retrieve build log from Travis, status code is 404
# 	Lint status is False, coverage status is True
# Collecting codecov (from nipype==1.0.0.dev0+g68181b42)
#   Downloading codecov-2.0.9-py2.py3-none-any.whl
# Collecting coverage>=3.7.1 (from pytest-cov->nipype==1.0.0.dev0+g68181b42)
#   Downloading coverage-4.4.2-cp27-cp27mu-manylinux1_x86_64.whl (194kB)
# Installing collected packages: imagesize, Pygments, sphinxcontrib-websupport, alabaster, snowballstemmer, docutils, typing, pytz, babel, MarkupSafe, Jinja2, Sphinx, cycler, subprocess32, backports.functools-lru-cache, matplotlib, psutil, coverage, pytest-cov, codecov, nipype
# Successfully installed Jinja2-2.10 MarkupSafe-1.0 Pygments-2.2.0 Sphinx-1.6.5 alabaster-0.7.10 babel-2.5.1 backports.functools-lru-cache-1.4 codecov-2.0.9 coverage-4.4.2 cycler-0.10.0 docutils-0.14 imagesize-0.7.1 matplotlib-2.1.0 nipype psutil-5.4.1 pytest-cov-2.5.1 pytz-2017.3 snowballstemmer-1.2.1 sphinxcontrib-websupport-1.0.1 subprocess32-3.2.7 typing-3.6.2
# Collecting codecov (from nipype==1.0.0.dev0+g68181b42)
#   Downloading codecov-2.0.9-py2.py3-none-any.whl
# Collecting coverage>=3.7.1 (from pytest-cov->nipype==1.0.0.dev0+g68181b42)
#   Downloading coverage-4.4.2-cp27-cp27mu-manylinux1_x86_64.whl (194kB)
# sunpy/sunpy
# 	Lint status is True, coverage status is True
# $ pip install $PIP_WHEEL_COMMAND coveralls pytest-cov pytest-xdist
# Collecting coveralls
#   Downloading coveralls-0.5.zip
#     /tmp/pip-build-P1ij_9/coveralls/setup.py:12: DeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
# Collecting PyYAML>=3.10 (from coveralls)
# Collecting docopt>=0.6.1 (from coveralls)
# Collecting coverage<3.999,>=3.6 (from coveralls)
#   Downloading http://sunpy.cadair.com/wheelhouse/coverage-3.7.1-cp26-none-linux_x86_64.whl (123kB)
# Collecting requests>=1.0.0 (from coveralls)
# Installing collected packages: execnet, cov-core, requests, coverage, docopt, PyYAML, pytest-xdist, pytest-cov, coveralls
# wbond/package_control_channel
# 	Lint status is True, coverage status is False
# dimagi/commcare-hq
# 	Lint status is False, coverage status is True
# Step 8 : RUN pip install     -r requirements/requirements.txt     -r requirements/dev-requirements.txt     coveralls     --user     && rm -rf /root/.cache/pip
# Collecting coveralls
#   Downloading coveralls-1.1-py2.py3-none-any.whl
# Requirement already satisfied (use --upgrade to upgrade): coverage in /vendor/lib/python2.7/site-packages (from -r requirements/test-requirements.txt (line 1))
# Collecting docopt>=0.6.1 (from coveralls)
# Installing collected packages: docopt, coveralls, pyzxcvbn
# Successfully installed coveralls-1.1 docopt-0.6.2 pyzxcvbn-0.5.0
# $ coverage report
# coverage: command not found
# $ coveralls
# django-oscar/django-oscar
# 	Lint status is True, coverage status is True
# $ pip install codecov
# Collecting codecov
#   Using cached codecov-1.4.1.tar.gz
# Collecting requests>=2.0.0 (from codecov)
# Collecting coverage (from codecov)
#   Using cached coverage-4.0.tar.gz
# Installing collected packages: coverage, requests, codecov
#   Running setup.py install for coverage
#     building 'coverage.tracer' extension
#     gcc -pthread -fno-strict-aliasing -g -fstack-protector --param=ssp-buffer-size=4 -Wformat -Werror=format-security -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/opt/python/2.7.9/include/python2.7 -c coverage/ctracer/datastack.c -o build/temp.linux-x86_64-2.7/coverage/ctracer/datastack.o
# sympy/sympy
# Could not retrieve build log from Travis, status code is 404
# Could not retrieve build log from Travis, status code is 404
# Could not retrieve build log from Travis, status code is 404
# Could not retrieve build log from Travis, status code is 404
# 	Lint status is True, coverage status is False
# ultrabug/py3status
# 	Lint status is False, coverage status is False
# pydanny/cookiecutter-django
# 	Lint status is False, coverage status is True
# Collecting coverage==4.1 (from -r /requirements/local.txt (line 3))
#   Downloading coverage-4.1.tar.gz (370kB)
# Collecting django-coverage-plugin==1.3.1 (from -r /requirements/local.txt (line 4))
#   Downloading django_coverage_plugin-1.3.1.tar.gz
# Installing collected packages: wheel, django, six, django-environ, whitenoise, django-braces, django-crispy-forms, django-floppyforms, django-model-utils, Pillow, defusedxml, python3-openid, oauthlib, requests, requests-oauthlib, django-allauth, psycopg2, unidecode, unicode-slugify, django-autoslug, pytz, redis, django-redis, coverage, django-coverage-plugin, snowballstemmer, docutils, imagesize, babel, MarkupSafe, Jinja2, alabaster, Pygments, Sphinx, django-extensions, Werkzeug, django-test-plus, python-dateutil, fake-factory, factory-boy, sqlparse, django-debug-toolbar, ptyprocess, pexpect, simplegeneric, wcwidth, prompt-toolkit, decorator, ipython-genutils, traitlets, pickleshare, ipython, ipdb, py, pytest, pytest-django, termcolor, pytest-sugar
#   Running setup.py install for coverage: started
#     Running setup.py install for coverage: finished with status 'done'
#   Running setup.py install for django-coverage-plugin: started
#     Running setup.py install for django-coverage-plugin: finished with status 'done'
# Successfully installed Jinja2-2.8 MarkupSafe-0.23 Pillow-3.3.0 Pygments-2.1.3 Sphinx-1.4.5 Werkzeug-0.11.10 alabaster-0.7.9 babel-2.3.4 coverage-4.1 decorator-4.0.10 defusedxml-0.4.1 django-1.9.8 django-allauth-0.26.1 django-autoslug-1.9.3 django-braces-1.9.0 django-coverage-plugin-1.3.1 django-crispy-forms-1.6.0 django-debug-toolbar-1.5 django-environ-0.4.0 django-extensions-1.6.7 django-floppyforms-1.6.2 django-model-utils-2.5 django-redis-4.4.4 django-test-plus-1.0.14 docutils-0.12 factory-boy-2.7.0 fake-factory-0.5.9 imagesize-0.7.1 ipdb-0.10.1 ipython-5.0.0 ipython-genutils-0.1.0 oauthlib-1.1.2 pexpect-4.2.0 pickleshare-0.7.3 prompt-toolkit-1.0.3 psycopg2-2.6.2 ptyprocess-0.5.1 py-1.4.31 pytest-2.9.2 pytest-django-2.9.1 pytest-sugar-0.7.1 python-dateutil-2.5.3 python3-openid-3.0.10 pytz-2016.6.1 redis-2.10.5 requests-2.10.0 requests-oauthlib-0.6.2 simplegeneric-0.8.1 six-1.10.0 snowballstemmer-1.2.1 sqlparse-0.2.0 termcolor-1.1.0 traitlets-4.2.2 unicode-slugify-0.1.3 unidecode-0.4.19 wcwidth-0.1.7 wheel-0.29.0 whitenoise-3.2
# pyinstaller/pyinstaller
# 	Lint status is True, coverage status is True
#   warning: no previously-included files matching '.coverage' found under directory 'src/greentest'
#     warning: no previously-included files matching '.coverage' found under directory 'src/greentest'
#   warning: no previously-included files matching '.coverage' found under directory 'src/greentest'
#     warning: no previously-included files matching '.coverage' found under directory 'src/greentest'
#   warning: no previously-included files matching '.coverage' found under directory 'src/greentest'
#     warning: no previously-included files matching '.coverage' found under directory 'src/greentest'
#   warning: no previously-included files matching '.coverage' found under directory 'src/greentest'
#     warning: no previously-included files matching '.coverage' found under directory 'src/greentest'
# scikit-image/scikit-image
# 	Lint status is True, coverage status is True
# +++retry pip install wheel flake8 coveralls nose
# +++pip install wheel flake8 coveralls nose
# Downloading/unpacking coveralls
#   Downloading coveralls-0.5.zip
#   Running setup.py (path:/home/travis/venv/build/coveralls/setup.py) egg_info for package coveralls
# Downloading/unpacking PyYAML>=3.10 (from coveralls)
# Downloading/unpacking docopt>=0.6.1 (from coveralls)
# Downloading/unpacking coverage>=3.6,<3.999 (from coveralls)
#   Downloading coverage-3.7.1.tar.gz (284kB): 284kB downloaded
#   Running setup.py (path:/home/travis/venv/build/coverage/setup.py) egg_info for package coverage
# scikit-learn/scikit-learn
# 	Lint status is False, coverage status is True
# Collecting coverage>=3.7.1 (from pytest-cov)
#   Using cached https://files.pythonhosted.org/packages/31/22/724704999cf994b590db9421b5ef1b5122ea485d67d56f9ecf34f2f721ad/coverage-4.5.1-cp27-cp27mu-manylinux1_x86_64.whl
# Installing collected packages: pluggy, attrs, six, more-itertools, py, funcsigs, atomicwrites, pytest, coverage, pytest-cov, cython
# Successfully installed atomicwrites-1.1.5 attrs-18.1.0 coverage-4.5.1 cython-0.23.5 funcsigs-1.0.2 more-itertools-4.2.0 pluggy-0.6.0 py-1.5.3 pytest-3.6.0 pytest-cov-2.5.1 six-1.11.0
# Requirement already satisfied: coverage in ./testvenv/lib/python2.7/site-packages (4.5.1)
# Collecting codecov
#   Using cached https://files.pythonhosted.org/packages/8b/28/4c1950a61c3c5786f0f34d643d0d28ec832433c9a7c0bd157690d4eb1d5f/codecov-2.0.15-py2.py3-none-any.whl
# Collecting requests>=2.7.9 (from codecov)
# Collecting urllib3<1.23,>=1.21.1 (from requests>=2.7.9->codecov)
# Collecting idna<2.7,>=2.5 (from requests>=2.7.9->codecov)
# pallets/flask
# 	Lint status is True, coverage status is True
# $ export TOXENV=py,simplejson,devel,lowest,codecov
# py installdeps: pytest>=3, coverage, greenlet, blinker, python-dotenv
# py installed: atomicwrites==1.1.5,attrs==18.1.0,blinker==1.4,click==6.7,coverage==4.5.1,Flask==1.1.dev0,greenlet==0.4.13,itsdangerous==0.24,Jinja2==2.10,MarkupSafe==1.0,more-itertools==4.2.0,pluggy==0.6.0,py==1.5.4,pytest==3.6.3,python-dotenv==0.8.2,six==1.11.0,Werkzeug==0.14.1
# py runtests: commands[2] | coverage run -p -m pytest tests examples
# simplejson installdeps: pytest>=3, coverage, greenlet, blinker, python-dotenv, simplejson
# simplejson installed: atomicwrites==1.1.5,attrs==18.1.0,blinker==1.4,click==6.7,coverage==4.5.1,Flask==1.1.dev0,greenlet==0.4.13,itsdangerous==0.24,Jinja2==2.10,MarkupSafe==1.0,more-itertools==4.2.0,pluggy==0.6.0,py==1.5.4,pytest==3.6.3,python-dotenv==0.8.2,simplejson==3.16.0,six==1.11.0,Werkzeug==0.14.1
# simplejson runtests: commands[2] | coverage run -p -m pytest tests examples
# devel installdeps: pytest>=3, coverage, greenlet, blinker, python-dotenv, https://github.com/pallets/werkzeug/archive/master.tar.gz, https://github.com/pallets/markupsafe/archive/master.tar.gz, https://github.com/pallets/jinja/archive/master.tar.gz, https://github.com/pallets/itsdangerous/archive/master.tar.gz, https://github.com/pallets/click/archive/master.tar.gz
# devel installed: atomicwrites==1.1.5,attrs==18.1.0,blinker==1.4,click==7.0.dev0,coverage==4.5.1,Flask==1.1.dev0,greenlet==0.4.13,itsdangerous==1.0.dev20180711,Jinja2==2.11.dev0,MarkupSafe==1.1.dev0,more-itertools==4.2.0,pluggy==0.6.0,py==1.5.4,pytest==3.6.3,python-dotenv==0.8.2,six==1.11.0,Werkzeug==0.15.dev0
# devel runtests: commands[2] | coverage run -p -m pytest tests examples
# praekelt/vumi
# 	Lint status is False, coverage status is True
# $ pip install coveralls
# Collecting coveralls
#   Downloading coveralls-1.1-py2.py3-none-any.whl
# Requirement already satisfied: requests>=1.0.0 in /home/travis/virtualenv/python2.7.9/lib/python2.7/site-packages (from coveralls)
# Collecting coverage>=3.6 (from coveralls)
#   Downloading coverage-4.3.1.tar.gz (372kB)
# Collecting docopt>=0.6.1 (from coveralls)
# Building wheels for collected packages: coverage, docopt
#   Running setup.py bdist_wheel for coverage ... done
# Successfully built coverage docopt
# praekelt/vumi-go
# 	Lint status is False, coverage status is True
# Downloading/unpacking coverage==3.4 (from -r requirements.pip (line 8))
#   Downloading coverage-3.4.tar.gz (92kB): 92kB downloaded
#   Running setup.py egg_info for package coverage
# Installing collected packages: Django, django-nose, nose, gunicorn, pep8, pyflakes, supervisor, coverage, South, psycopg2, Fabric, celery, django-celery, django-celery-email, vumi-dev, vxpolls-dev, Markdown, django-registration, lesscpy, xlrd, django-bootstrap-dev, vumi-wikipedia-dev, requests, raven, django-debug-toolbar, kombu, librabbitmq, hiredis, django-pipeline, pycrypto, paramiko, importlib, anyjson, python-dateutil, ordereddict, django-picklefield, ply, amqp, futures
#   Running setup.py install for coverage
#     building 'coverage.tracer' extension
#     gcc -pthread -fno-strict-aliasing -DNDEBUG -g -fwrapv -O2 -Wall -Wstrict-prototypes -fPIC -I/usr/include/python2.6 -c coverage/tracer.c -o build/temp.linux-x86_64-2.6/coverage/tracer.o
#     gcc -pthread -shared -Wl,-O1 -Wl,-Bsymbolic-functions build/temp.linux-x86_64-2.6/coverage/tracer.o -o build/lib.linux-x86_64-2.6/coverage/tracer.so
#     Installing coverage script to /home/travis/virtualenv/python2.6/bin
# Successfully installed Django django-nose nose gunicorn pep8 pyflakes supervisor coverage South psycopg2 Fabric celery django-celery django-celery-email vumi-dev vxpolls-dev Markdown django-registration lesscpy xlrd django-bootstrap-dev vumi-wikipedia-dev requests raven django-debug-toolbar kombu librabbitmq hiredis django-pipeline pycrypto paramiko importlib anyjson python-dateutil ordereddict django-picklefield ply amqp futures
# riptano/cassandra-dtest
# 	Lint status is False, coverage status is False
# psychopy/psychopy
# 	Lint status is False, coverage status is True
# coverage-4.5.1       | 234 KB    | ##################################### | 100%
# coveralls-1.5.0      | 11 KB     | ##################################### | 100%
# codecov-2.0.15       | 11 KB     | ##################################### | 100%
# $ pytest --cov-config .travis_coveragerc --cov=psychopy -v -s -m "not needs_sound" psychopy
# ---------- coverage: platform linux2, python 2.7.15-final-0 ----------
# The command "pytest --cov-config .travis_coveragerc --cov=psychopy -v -s -m "not needs_sound" psychopy" exited with 0.
# $ coveralls
# Submitting coverage to coveralls.io...
# https://coveralls.io/jobs/40165774
# $ codecov
# ros/rosdistro
# 	Lint status is True, coverage status is True
# $ pip install rosdistro nose coverage
# Downloading/unpacking coverage
#   Downloading coverage-3.7.1.tar.gz (284kB): 284kB downloaded
#   Running setup.py (path:/home/travis/virtualenv/python2.7.8/build/coverage/setup.py) egg_info for package coverage
# Installing collected packages: rosdistro, coverage, catkin-pkg, rospkg, docutils, python-dateutil, six
#   Running setup.py install for coverage
#     building 'coverage.tracer' extension
#     gcc -pthread -fno-strict-aliasing -g -fstack-protector --param=ssp-buffer-size=4 -Wformat -Werror=format-security -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/opt/python/2.7.8/include/python2.7 -c coverage/tracer.c -o build/temp.linux-x86_64-2.7/coverage/tracer.o
#     gcc -pthread -shared -L/opt/python/2.7.8/lib -Wl,-rpath=/opt/python/2.7.8/lib build/temp.linux-x86_64-2.7/coverage/tracer.o -L/opt/python/2.7.8/lib -lpython2.7 -o build/lib.linux-x86_64-2.7/coverage/tracer.so
#     Installing coverage2 script to /home/travis/virtualenv/python2.7.8/bin
# kivy/kivy
# 	Lint status is True, coverage status is True
# $ if [ "${TRAVIS_OS_NAME}" == "linux" ]; then if [ "${RUN}" != "pep8" ]; then yes | sudo add-apt-repository ppa:zoogie/sdl2-snapshots; yes | sudo add-apt-repository ppa:gstreamer-developers/ppa; sudo apt-get update; sudo apt-get -y install libsdl2-dev libsdl2-ttf-dev libsdl2-image-dev libsdl2-mixer-dev; sudo apt-get -y install libgstreamer1.0-dev gstreamer1.0-alsa gstreamer1.0-plugins-base; sudo apt-get -y install python-dev libsmpeg-dev libswscale-dev libavformat-dev libavcodec-dev libjpeg-dev libtiff4-dev libX11-dev libmtdev-dev; sudo apt-get -y install python-setuptools build-essential libgl1-mesa-dev libgles2-mesa-dev; sudo apt-get -y install xvfb pulseaudio; pip install --upgrade cython pillow nose coveralls; fi; if [ "${RUN}" == "docs" ]; then pip install --upgrade sphinxcontrib-blockdiag sphinxcontrib-seqdiag sphinxcontrib-actdiag sphinxcontrib-nwdiag; fi; fi;
# Collecting coveralls
#   Downloading coveralls-1.1-py2.py3-none-any.whl
# Collecting docopt>=0.6.1 (from coveralls)
# Collecting coverage>=3.6 (from coveralls)
#   Downloading coverage-4.2.tar.gz (359kB)
# Collecting requests>=1.0.0 (from coveralls)
# Building wheels for collected packages: docopt, coverage
#   Running setup.py bdist_wheel for coverage ... done
# Successfully built docopt coverage
# scrapy/scrapy
# 	Lint status is True, coverage status is True
# $ pip install -U tox twine wheel codecov
# Collecting codecov
#   Using cached https://files.pythonhosted.org/packages/8b/28/4c1950a61c3c5786f0f34d643d0d28ec832433c9a7c0bd157690d4eb1d5f/codecov-2.0.15-py2.py3-none-any.whl
# Collecting coverage (from codecov)
#   Using cached https://files.pythonhosted.org/packages/31/22/724704999cf994b590db9421b5ef1b5122ea485d67d56f9ecf34f2f721ad/coverage-4.5.1-cp27-cp27mu-manylinux1_x86_64.whl
# Installing collected packages: py, pluggy, virtualenv, setuptools, tox, pkginfo, tqdm, certifi, chardet, urllib3, idna, requests, requests-toolbelt, twine, wheel, coverage, codecov
# Successfully installed certifi-2018.8.13 chardet-3.0.4 codecov-2.0.15 coverage-4.5.1 idna-2.7 pkginfo-1.4.2 pluggy-0.7.1 py-1.5.4 requests-2.19.1 requests-toolbelt-0.8.0 setuptools-40.2.0 tox-3.2.1 tqdm-4.25.0 twine-1.11.0 urllib3-1.23 virtualenv-16.0.0 wheel-0.31.1
# py27 installed: asn1crypto==0.24.0,attrs==18.1.0,Automat==0.7.0,backports.shutil-get-terminal-size==1.0.0,blessings==1.7,botocore==1.10.82,bpython==0.17.1,brotlipy==0.7.0,cachetools==2.1.0,certifi==2018.8.13,cffi==1.11.5,chardet==3.0.4,click==6.7,constantly==15.1.0,coverage==4.5.1,cryptography==2.3.1,cssselect==1.0.3,curtsies==0.3.0,decorator==4.3.0,docutils==0.14,enum34==1.1.6,Flask==1.0.2,funcsigs==1.0.2,functools32==3.2.3.post2,futures==3.2.0,google-api-core==1.3.0,google-auth==1.5.1,google-cloud-core==0.28.1,google-cloud-storage==1.10.0,google-resumable-media==0.3.1,googleapis-common-protos==1.5.3,greenlet==0.4.14,hyperlink==18.0.0,idna==2.7,incremental==17.5.0,ipaddress==1.0.22,ipython==5.8.0,ipython-genutils==0.2.0,itsdangerous==0.24,Jinja2==2.10,jmespath==0.9.3,leveldb==0.194,lxml==4.2.4,MarkupSafe==1.0,mitmproxy==0.10.1,mock==2.0.0,netlib==0.10.1,parsel==1.5.0,pathlib2==2.3.2,pbr==4.2.0,pexpect==4.6.0,pickleshare==0.7.4,Pillow==5.2.0,prompt-toolkit==1.0.15,protobuf==3.6.1,ptyprocess==0.6.0,py==1.5.4,pyasn1==0.4.4,pyasn1-modules==0.2.2,pycparser==2.18,PyDispatcher==2.0.5,Pygments==2.2.0,PyHamcrest==1.9.0,pyOpenSSL==18.0.0,pytest==2.9.2,pytest-cov==2.2.1,pytest-twisted==1.8,python-dateutil==2.7.3,pytz==2018.5,queuelib==1.5.0,requests==2.19.1,rsa==3.4.2,scandir==1.9.0,Scrapy==1.5.0,service-identity==17.0.0,simplegeneric==0.8.1,six==1.11.0,testfixtures==6.2.0,traitlets==4.3.2,Twisted==18.7.0,typing==3.6.4,urllib3==1.23,urwid==2.0.1,w3lib==1.19.0,wcwidth==0.1.7,Werkzeug==0.14.1,zope.interface==4.5.0
# $ codecov
#     Generating coverage xml reports for Python
# statsmodels/statsmodels
# 	Lint status is True, coverage status is True
# $ if [ ${COVERAGE} = true ]; then pip install coverage coveralls; fi
# copying statsmodels/tests/coverage_sm.py -> build/lib.linux-x86_64-2.6/statsmodels/tests
# copying statsmodels/tsa/statespace/tests/results/results_sarimax_coverage.csv -> build/lib.linux-x86_64-2.6/statsmodels/tsa/statespace/tests/results
# copying build/lib.linux-x86_64-2.6/statsmodels/tests/coverage_sm.py -> build/bdist.linux-x86_64/egg/statsmodels/tests
# copying build/lib.linux-x86_64-2.6/statsmodels/tsa/statespace/tests/results/results_sarimax_coverage.csv -> build/bdist.linux-x86_64/egg/statsmodels/tsa/statespace/tests/results
# byte-compiling build/bdist.linux-x86_64/egg/statsmodels/tests/coverage_sm.py to coverage_sm.pyc
# copying build/lib.linux-x86_64-2.6/statsmodels/tests/coverage_sm.py -> build/bdist.linux-x86_64/egg/statsmodels/tests
# copying build/lib.linux-x86_64-2.6/statsmodels/tsa/statespace/tests/results/results_sarimax_coverage.csv -> build/bdist.linux-x86_64/egg/statsmodels/tsa/statespace/tests/results
# byte-compiling build/bdist.linux-x86_64/egg/statsmodels/tests/coverage_sm.py to coverage_sm.pyc
# $ if [ ${COVERAGE} = true ]; then coverage run --rcfile=${SRCDIR}/.travis_coveragerc test.py; else python test.py; fi
# fabric/fabric
# 	Lint status is False, coverage status is False
# pennersr/django-allauth
# 	Lint status is False, coverage status is True
# $ pip install coverage
# Collecting coverage
#   Downloading coverage-3.7.1.tar.gz (284kB)
#     /tmp/pip-build-00qyt6/coverage/setup.py:12: DeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#       tracker are on `Bitbucket <http://bitbucket.org/ned/coveragepy>`_, with a
# Installing collected packages: coverage
#   Running setup.py install for coverage
#     building 'coverage.tracer' extension
#     gcc -pthread -fno-strict-aliasing -g -fstack-protector --param=ssp-buffer-size=4 -Wformat -Werror=format-security -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/opt/python/2.6.9/include/python2.6 -c coverage/tracer.c -o build/temp.linux-x86_64-2.6/coverage/tracer.o
#     gcc -pthread -shared build/temp.linux-x86_64-2.6/coverage/tracer.o -L/opt/python/2.6.9/lib -lpython2.6 -o build/lib.linux-x86_64-2.6/coverage/tracer.so
# spesmilo/electrum
# 	Lint status is True, coverage status is True
# Collecting python-coveralls (from -r contrib/requirements/requirements-travis.txt (line 2))
#   Using cached https://files.pythonhosted.org/packages/2f/4a/0f776edd7d985e5fc456a8430bde69ce0701f6b6bae17586c74a309f89ae/python_coveralls-2.9.1-py2.py3-none-any.whl
# Collecting coverage==4.0.3 (from python-coveralls->-r contrib/requirements/requirements-travis.txt (line 2))
# Collecting requests (from python-coveralls->-r contrib/requirements/requirements-travis.txt (line 2))
# Collecting PyYAML (from python-coveralls->-r contrib/requirements/requirements-travis.txt (line 2))
# Collecting urllib3<1.24,>=1.21.1 (from requests->python-coveralls->-r contrib/requirements/requirements-travis.txt (line 2))
# Collecting idna<2.8,>=2.5 (from requests->python-coveralls->-r contrib/requirements/requirements-travis.txt (line 2))
# Collecting certifi>=2017.4.17 (from requests->python-coveralls->-r contrib/requirements/requirements-travis.txt (line 2))
# Collecting chardet<3.1.0,>=3.0.2 (from requests->python-coveralls->-r contrib/requirements/requirements-travis.txt (line 2))
# Installing collected packages: virtualenv, tox, coverage, urllib3, idna, certifi, chardet, requests, PyYAML, python-coveralls, tox-travis
# Yelp/mrjob
# 	Lint status is False, coverage status is False
# rg3/youtube-dl
# 	Lint status is True, coverage status is False
# allegro/ralph
# 	Lint status is False, coverage status is True
# $ pip install coveralls
# Downloading/unpacking coveralls
#   Downloading coveralls-0.4.2-py2.py3-none-any.whl
# Downloading/unpacking docopt>=0.6.1 (from coveralls)
# Downloading/unpacking coverage>=3.6 (from coveralls)
#   Downloading coverage-3.7.1.tar.gz (284kB): 284kB downloaded
#   Running setup.py (path:/home/travis/virtualenv/python2.7.6/build/coverage/setup.py) egg_info for package coverage
# Downloading/unpacking requests>=1.0.0 (from coveralls)
# Downloading/unpacking PyYAML>=3.10 (from coveralls)
# Installing collected packages: coveralls, docopt, coverage, requests, PyYAML
# beetbox/beets
# Could not retrieve build log from Travis, status code is 404
# Could not retrieve build log from Travis, status code is 404
# 	Lint status is False, coverage status is True
# $ [ ! -z $COVERAGE ] && travis_retry pip install coveralls || true
# $ [ ! -z $COVERAGE ] && coveralls || true
# $ [ ! -z $COVERAGE ] && travis_retry pip install coveralls || true
# Downloading/unpacking coveralls
#   Downloading coveralls-0.5.zip
#   Running setup.py (path:/home/travis/virtualenv/python2.7.9/build/coveralls/setup.py) egg_info for package coveralls
# Downloading/unpacking PyYAML>=3.10 (from coveralls)
# Downloading/unpacking docopt>=0.6.1 (from coveralls)
# Downloading/unpacking coverage>=3.6,<3.999 (from coveralls)
#   Downloading coverage-3.7.1.tar.gz (284kB): 284kB downloaded
# networkx/networkx
